# %% [markdown]
# ## Run a pipeline

# %% [markdown]
# This process will run the entire pipeline described in a configuration file

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline
import matplotlib.pyplot as plt

# %%
pipeline = Pipeline(config_file_path="../config_files/config_benthic_ifdo.yaml")
# Out:
# Checking files have unique names 99/99

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square" style="float:left; cursor: pointer; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#
#             <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Color_correction</h2>
#                     <h2 style="font-size:13px;">Type: Color</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_1" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_1')">
#                     <h2 style="font-size:20px;">Datetime</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_2" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_2')">
#                     <h2 style="font-size:20px;">Overlapping</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_3" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_3')">
#                     <h2 style="font-size:20px;">Color_correction</h2>
#                     <h2 style="font-size:13px;">Type: Color</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#                 <div style="clear:both;"></div>
#                 <div id="step_4" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_4')">
#                     <h2 style="font-size:20px;">Sharpen</h2>
#                     <h2 style="font-size:13px;">Type: Color</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_5" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_5')">
#                     <h2 style="font-size:20px;">Contrast</h2>
#                     <h2 style="font-size:13px;">Type: Color</h2>
#                 </div>
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#                 <div id="parameters_step_0" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "color_correction",
#     "step_name": "color",
#     "mode": "grayscale",
#     "test": false
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_1" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "datetime",
#     "step_name": "sampling",
#     "mode": "datetime",
#     "test": false,
#     "params": {
#         "min": "2016-05-11 04:14:00",
#         "max": "2016-05-11 09:27:00"
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_2" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "overlapping",
#     "step_name": "sampling",
#     "mode": "overlapping",
#     "test": false,
#     "params": {
#         "omega": 57,
#         "theta": 40,
#         "threshold": 0.5,
#         "camera_distance": 1.12
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_3" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "color_correction",
#     "step_name": "color",
#     "mode": "gaussian_blur",
#     "test": false,
#     "params": {
#         "sigma": 1.0
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_4" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "sharpen",
#     "step_name": "color",
#     "mode": "sharpen",
#     "test": false,
#     "params": {
#         "alpha": 1.5,
#         "beta": -0.5
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_5" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "contrast",
#     "step_name": "color",
#     "mode": "contrast",
#     "test": false
# }</pre>
#                 </div>
#
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "name": "raw",
#     "step_name": "open",
#     "input_path": "/home/tobfer/.paidiverpy_cache/benthic_ifdo/images",
#     "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_ifdo/metadata/metadata_benthic_ifdo.json",
#     "metadata_type": "IFDO",
#     "image_type": "JPG",
#     "output_path": "output",
#     "n_jobs": 8,
#     "rename": null,
#     "sampling": [
#         {
#             "name": "sampling",
#             "step_name": "sampling",
#             "mode": "percent",
#             "test": false,
#             "params": {
#                 "value": 0.2
#             }
#         }
#     ],
#     "convert": [
#         {
#             "name": "convert",
#             "step_name": "convert",
#             "mode": "bits",
#             "test": false,
#             "params": {
#                 "output_bits": 8
#             }
#         }
#     ]
# }</pre>
#             </div>
#         </div>
#         <script>
#             function showParameters(id) {
#                 // Hide all parameter sections
#                 var currentTarget = document.getElementById(id);
#                 var square = document.getElementsByClassName('square');
#                 var allParams = document.getElementsByClassName('parameters');
#                 var selectedParams = document.getElementById('parameters_' + id);
#                 var idWasVisible = false;
#                 if (selectedParams) {
#                     var idWasVisible = selectedParams.style.display === 'block';
#                 }
#                 for (var i = 0; i < square.length; i++) {
#                     square[i].style.color =

# %%
# See the pipeline steps in json format
# pipeline.steps

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:40 | Running step 0: raw - OpenLayer
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:40 | Processing images using 8 cores
# [########################################] | 100% Completed | 3.41 sms
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:44 | Processing images using 8 cores
# [########################################] | 100% Completed | 2.24 sms
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:47 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:47 | Step 0 saved
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:47 | Running step 1: color_correction - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:47 | Processing images using 8 cores
# [########################################] | 100% Completed | 219.08 ms
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Step 1 saved
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Running step 2: datetime - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Number of photos to be removed: 0
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Step 2 saved
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Running step 3: overlapping - ResampleLayer
# ☁ paidiverpy ☁  |      ERROR | 2024-09-26 10:50:48 | Error in resample layer: 'pitch_deg'
# ☁ paidiverpy ☁  |      ERROR | 2024-09-26 10:50:48 | Resample layer step will be skipped.
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Step 3 saved
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Running step 4: color_correction - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Processing images using 8 cores
# [########################################] | 100% Completed | 203.00 ms
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Step 4 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Step 4 saved
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Running step 5: sharpen - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:48 | Processing images using 8 cores
# [########################################] | 100% Completed | 6.45 sms
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:55 | Step 5 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:55 | Step 5 saved
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:55 | Running step 6: contrast - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:50:55 | Processing images using 8 cores
# [########################################] | 100% Completed | 16.59 ss
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:51:12 | Step 6 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-26 10:51:12 | Step 6 saved

# %%
# See the images output
pipeline.images
# Out:
# Step: raw
# Image: dask.array<array, shape=(10344, 1928, 3), dtype=uint8, chunksize=(10344, 1928, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361, 3), dtype=uint8, chunksize=(9241, 2361, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865, 3), dtype=uint8, chunksize=(15615, 2865, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10179, 2423, 3), dtype=uint8, chunksize=(10179, 2423, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8560, 2319, 3), dtype=uint8, chunksize=(8560, 2319, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357, 3), dtype=uint8, chunksize=(10388, 2357, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10460, 2688, 3), dtype=uint8, chunksize=(10460, 2688, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10180, 2278, 3), dtype=uint8, chunksize=(10180, 2278, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10316, 2584, 3), dtype=uint8, chunksize=(10316, 2584, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(22917, 2596, 3), dtype=uint8, chunksize=(17233, 2596, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10554, 2787, 3), dtype=uint8, chunksize=(10554, 2787, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660, 3), dtype=uint8, chunksize=(10485, 2660, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429, 3), dtype=uint8, chunksize=(10507, 2429, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12519, 2311, 3), dtype=uint8, chunksize=(12519, 2311, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398, 3), dtype=uint8, chunksize=(10251, 2398, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354, 3), dtype=uint8, chunksize=(10532, 2354, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28584, 2522, 3), dtype=uint8, chunksize=(17739, 2522, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8729, 2496, 3), dtype=uint8, chunksize=(8729, 2496, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10272, 2412, 3), dtype=uint8, chunksize=(10272, 2412, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(16047, 2192, 3), dtype=uint8, chunksize=(16047, 2192, 3), chunktype=numpy.ndarray>
# Step: color_correction
# Image: dask.array<array, shape=(10344, 1928), dtype=uint8, chunksize=(10344, 1928), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10179, 2423), dtype=uint8, chunksize=(10179, 2423), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8560, 2319), dtype=uint8, chunksize=(8560, 2319), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10460, 2688), dtype=uint8, chunksize=(10460, 2688), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10180, 2278), dtype=uint8, chunksize=(10180, 2278), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10316, 2584), dtype=uint8, chunksize=(10316, 2584), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(22917, 2596), dtype=uint8, chunksize=(22917, 2596), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10554, 2787), dtype=uint8, chunksize=(10554, 2787), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660), dtype=uint8, chunksize=(10485, 2660), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12519, 2311), dtype=uint8, chunksize=(12519, 2311), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354), dtype=uint8, chunksize=(10532, 2354), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28584, 2522), dtype=uint8, chunksize=(28584, 2522), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8729, 2496), dtype=uint8, chunksize=(8729, 2496), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10272, 2412), dtype=uint8, chunksize=(10272, 2412), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(16047, 2192), dtype=uint8, chunksize=(16047, 2192), chunktype=numpy.ndarray>
# Step: datetime
# Image: dask.array<array, shape=(10344, 1928), dtype=uint8, chunksize=(10344, 1928), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10179, 2423), dtype=uint8, chunksize=(10179, 2423), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8560, 2319), dtype=uint8, chunksize=(8560, 2319), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10460, 2688), dtype=uint8, chunksize=(10460, 2688), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10180, 2278), dtype=uint8, chunksize=(10180, 2278), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10316, 2584), dtype=uint8, chunksize=(10316, 2584), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(22917, 2596), dtype=uint8, chunksize=(22917, 2596), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10554, 2787), dtype=uint8, chunksize=(10554, 2787), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660), dtype=uint8, chunksize=(10485, 2660), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12519, 2311), dtype=uint8, chunksize=(12519, 2311), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354), dtype=uint8, chunksize=(10532, 2354), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28584, 2522), dtype=uint8, chunksize=(28584, 2522), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8729, 2496), dtype=uint8, chunksize=(8729, 2496), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10272, 2412), dtype=uint8, chunksize=(10272, 2412), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(16047, 2192), dtype=uint8, chunksize=(16047, 2192), chunktype=numpy.ndarray>
# Step: overlapping
# Image: dask.array<array, shape=(10344, 1928), dtype=uint8, chunksize=(10344, 1928), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10179, 2423), dtype=uint8, chunksize=(10179, 2423), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8560, 2319), dtype=uint8, chunksize=(8560, 2319), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10460, 2688), dtype=uint8, chunksize=(10460, 2688), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10180, 2278), dtype=uint8, chunksize=(10180, 2278), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10316, 2584), dtype=uint8, chunksize=(10316, 2584), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(22917, 2596), dtype=uint8, chunksize=(22917, 2596), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10554, 2787), dtype=uint8, chunksize=(10554, 2787), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660), dtype=uint8, chunksize=(10485, 2660), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12519, 2311), dtype=uint8, chunksize=(12519, 2311), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354), dtype=uint8, chunksize=(10532, 2354), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28584, 2522), dtype=uint8, chunksize=(28584, 2522), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8729, 2496), dtype=uint8, chunksize=(8729, 2496), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10272, 2412), dtype=uint8, chunksize=(10272, 2412), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(16047, 2192), dtype=uint8, chunksize=(16047, 2192), chunktype=numpy.ndarray>
# Step: color_correction
# Image: dask.array<array, shape=(10344, 1928), dtype=uint8, chunksize=(10344, 1928), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10179, 2423), dtype=uint8, chunksize=(10179, 2423), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8560, 2319), dtype=uint8, chunksize=(8560, 2319), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10460, 2688), dtype=uint8, chunksize=(10460, 2688), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10180, 2278), dtype=uint8, chunksize=(10180, 2278), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10316, 2584), dtype=uint8, chunksize=(10316, 2584), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(22917, 2596), dtype=uint8, chunksize=(22917, 2596), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10554, 2787), dtype=uint8, chunksize=(10554, 2787), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660), dtype=uint8, chunksize=(10485, 2660), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12519, 2311), dtype=uint8, chunksize=(12519, 2311), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354), dtype=uint8, chunksize=(10532, 2354), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28584, 2522), dtype=uint8, chunksize=(28584, 2522), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8729, 2496), dtype=uint8, chunksize=(8729, 2496), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10272, 2412), dtype=uint8, chunksize=(10272, 2412), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(16047, 2192), dtype=uint8, chunksize=(16047, 2192), chunktype=numpy.ndarray>
# Step: sharpen
# Image: dask.array<array, shape=(10344, 1928), dtype=uint8, chunksize=(10344, 1928), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10179, 2423), dtype=uint8, chunksize=(10179, 2423), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8560, 2319), dtype=uint8, chunksize=(8560, 2319), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10460, 2688), dtype=uint8, chunksize=(10460, 2688), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10180, 2278), dtype=uint8, chunksize=(10180, 2278), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10316, 2584), dtype=uint8, chunksize=(10316, 2584), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(22917, 2596), dtype=uint8, chunksize=(22917, 2596), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10554, 2787), dtype=uint8, chunksize=(10554, 2787), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660), dtype=uint8, chunksize=(10485, 2660), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12519, 2311), dtype=uint8, chunksize=(12519, 2311), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354), dtype=uint8, chunksize=(10532, 2354), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28584, 2522), dtype=uint8, chunksize=(28584, 2522), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8729, 2496), dtype=uint8, chunksize=(8729, 2496), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10272, 2412), dtype=uint8, chunksize=(10272, 2412), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(16047, 2192), dtype=uint8, chunksize=(16047, 2192), chunktype=numpy.ndarray>
# Step: contrast
# Image: dask.array<array, shape=(10344, 1928), dtype=uint8, chunksize=(10344, 1928), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10179, 2423), dtype=uint8, chunksize=(10179, 2423), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8560, 2319), dtype=uint8, chunksize=(8560, 2319), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10460, 2688), dtype=uint8, chunksize=(10460, 2688), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10180, 2278), dtype=uint8, chunksize=(10180, 2278), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10316, 2584), dtype=uint8, chunksize=(10316, 2584), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(22917, 2596), dtype=uint8, chunksize=(22917, 2596), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10554, 2787), dtype=uint8, chunksize=(10554, 2787), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660), dtype=uint8, chunksize=(10485, 2660), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12519, 2311), dtype=uint8, chunksize=(12519, 2311), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354), dtype=uint8, chunksize=(10532, 2354), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28584, 2522), dtype=uint8, chunksize=(28584, 2522), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(8729, 2496), dtype=uint8, chunksize=(8729, 2496), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10272, 2412), dtype=uint8, chunksize=(10272, 2412), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(16047, 2192), dtype=uint8, chunksize=(16047, 2192), chunktype=numpy.ndarray>

# %%
# You can also rerun your processing from a specific step
pipeline.run(from_step=2)

# %%
pipeline.images
# Out:
# Step: raw
# Image: [[[ 91  78  96 255]
#   [ 88  75  97 255]
#   [ 89  77  99 255]
#   ...
#   [ 49  51  94 255]
#   [ 50  52  95 255]
#   [ 50  52  96 255]]
#
#  [[ 88  76  94 255]
#   [ 88  75  96 255]
#   [ 87  75  94 255]
#   ...
#   [ 49  52  93 255]
#   [ 49  53  93 255]
#   [ 50  52  93 255]]
#
#  [[ 87  76  92 255]
#   [ 86  75  92 255]
#   [ 86  75  95 255]
#   ...
#   [ 49  51  94 255]
#   [ 48  52  90 255]
#   [ 48  52  93 255]]
#
#  ...
#
#  [[ 64  62  83 255]
#   [ 62  63  84 255]
#   [ 64  62  84 255]
#   ...
#   [ 43  47  88 255]
#   [ 43  47  84 255]
#   [ 45  48  89 255]]
#
#  [[ 64  62  84 255]
#   [ 63  60  82 255]
#   [ 64  62  88 255]
#   ...
#   [ 42  48  87 255]
#   [ 42  47  85 255]
#   [ 40  49  85 255]]
#
#  [[ 64  61  84 255]
#   [ 61  62  82 255]
#   [ 60  60  84 255]
#   ...
#   [ 42  48  86 255]
#   [ 41  47  86 255]
#   [ 44  50  86 255]]]
# Image: [[[ 65  56  87 255]
#   [ 65  56  85 255]
#   [ 68  58  88 255]
#   ...
#   [ 55  56  95 255]
#   [ 55  57  98 255]
#   [ 55  56  95 255]]
#
#  [[ 63  57  83 255]
#   [ 65  57  84 255]
#   [ 64  59  82 255]
#   ...
#   [ 55  57  97 255]
#   [ 53  55  93 255]
#   [ 54  58  96 255]]
#
#  [[ 63  57  84 255]
#   [ 64  56  83 255]
#   [ 64  56  83 255]
#   ...
#   [ 54  56  95 255]
#   [ 56  58  97 255]
#   [ 54  56  95 255]]
#
#  ...
#
#  [[ 67  64  88 255]
#   [ 64  65  89 255]
#   [ 64  65  87 255]
#   ...
#   [ 50  53  88 255]
#   [ 50  53  86 255]
#   [ 49  53  85 255]]
#
#  [[ 67  65  88 255]
#   [ 65  65  87 255]
#   [ 67  66  89 255]
#   ...
#   [ 50  53  87 255]
#   [ 48  53  85 255]
#   [ 49  54  86 255]]
#
#  [[ 67  65  88 255]
#   [ 64  64  88 255]
#   [ 64  65  88 255]
#   ...
#   [ 51  54  87 255]
#   [ 50  53  88 255]
#   [ 48  53  85 255]]]
# Image: [[[ 68  54  80 255]
#   [ 65  53  77 255]
#   [ 65  53  79 255]
#   ...
#   [ 51  48  86 255]
#   [ 50  48  85 255]
#   [ 51  49  84 255]]
#
#  [[ 65  54  79 255]
#   [ 64  54  78 255]
#   [ 63  54  77 255]
#   ...
#   [ 50  49  83 255]
#   [ 49  49  83 255]
#   [ 50  50  83 255]]
#
#  [[ 63  53  78 255]
#   [ 61  55  77 255]
#   [ 65  54  75 255]
#   ...
#   [ 50  49  83 255]
#   [ 50  49  83 255]
#   [ 50  49  81 255]]
#
#  ...
#
#  [[ 56  53  75 255]
#   [ 55  54  76 255]
#   [ 57  55  77 255]
#   ...
#   [ 57  55  81 255]
#   [ 58  54  83 255]
#   [ 57  55  82 255]]
#
#  [[ 56  55  76 255]
#   [ 55  54  75 255]
#   [ 54  53  76 255]
#   ...
#   [ 55  55  82 255]
#   [ 55  55  81 255]
#   [ 55  55  81 255]]
#
#  [[ 58  55  77 255]
#   [ 55  56  77 255]
#   [ 54  55  76 255]
#   ...
#   [ 57  56  80 255]
#   [ 59  56  82 255]
#   [ 55  55  81 255]]]
# Image: [[[ 77  61  80 255]
#   [ 71  56  75 255]
#   [ 74  59  80 255]
#   ...
#   [ 54  49  82 255]
#   [ 54  48  83 255]
#   [ 55  48  82 255]]
#
#  [[ 75  62  77 255]
#   [ 69  58  76 255]
#   [ 69  57  75 255]
#   ...
#   [ 50  49  81 255]
#   [ 54  50  82 255]
#   [ 51  50  81 255]]
#
#  [[ 76  62  78 255]
#   [ 78  61  79 255]
#   [ 74  61  78 255]
#   ...
#   [ 52  49  80 255]
#   [ 52  49  80 255]
#   [ 51  50  81 255]]
#
#  ...
#
#  [[ 69  65  82 255]
#   [ 71  64  82 255]
#   [ 69  65  82 255]
#   ...
#   [ 60  58  82 255]
#   [ 62  58  83 255]
#   [ 61  58  84 255]]
#
#  [[ 70  62  83 255]
#   [ 68  63  78 255]
#   [ 67  64  83 255]
#   ...
#   [ 61  58  82 255]
#   [ 62  58  84 255]
#   [ 61  57  83 255]]
#
#  [[ 69  63  84 255]
#   [ 68  64  81 255]
#   [ 67  65  83 255]
#   ...
#   [ 63  61  85 255]
#   [ 62  59  82 255]
#   [ 62  58  81 255]]]
# Image: [[[113  91 101 255]
#   [114  91 103 255]
#   [112  90 102 255]
#   ...
#   [103  80  98 255]
#   [103  81  97 255]
#   [103  81  97 255]]
#
#  [[111  89 102 255]
#   [112  92 103 255]
#   [110  91 100 255]
#   ...
#   [100  79  95 255]
#   [105  81  96 255]
#   [100  80  95 255]]
#
#  [[113  90 103 255]
#   [111  91 100 255]
#   [110  89  98 255]
#   ...
#   [102  80  95 255]
#   [103  82  96 255]
#   [100  81  97 255]]
#
#  ...
#
#  [[ 94  84  93 255]
#   [ 92  83  92 255]
#   [ 89  80  89 255]
#   ...
#   [ 70  60  77 255]
#   [ 71  60  76 255]
#   [ 71  60  74 255]]
#
#  [[ 94  82  92 255]
#   [ 91  81  91 255]
#   [ 88  80  90 255]
#   ...
#   [ 71  58  75 255]
#   [ 69  58  74 255]
#   [ 73  62  76 255]]
#
#  [[ 92  82  93 255]
#   [ 88  83  92 255]
#   [ 87  80  90 255]
#   ...
#   [ 71  60  76 255]
#   [ 69  59  75 255]
#   [ 71  60  74 255]]]
# Image: [[[144 114 122 255]
#   [147 113 122 255]
#   [150 114 122 255]
#   ...
#   [110  86  96 255]
#   [109  86  98 255]
#   [111  85  98 255]]
#
#  [[146 115 122 255]
#   [145 114 120 255]
#   [146 115 121 255]
#   ...
#   [109  87 100 255]
#   [111  89 100 255]
#   [110  88  98 255]]
#
#  [[146 113 121 255]
#   [147 115 122 255]
#   [142 113 121 255]
#   ...
#   [108  86  98 255]
#   [111  88 101 255]
#   [107  86  98 255]]
#
#  ...
#
#  [[128 112 119 255]
#   [127 110 118 255]
#   [120 109 116 255]
#   ...
#   [129 106 114 255]
#   [123 101 109 255]
#   [119  99 106 255]]
#
#  [[129 111 118 255]
#   [122 109 117 255]
#   [109 106 115 255]
#   ...
#   [126 103 111 255]
#   [122  99 109 255]
#   [121  99 104 255]]
#
#  [[129 112 119 255]
#   [118 109 117 255]
#   [102 102 114 255]
#   ...
#   [129 106 113 255]
#   [124 101 108 255]
#   [123 100 106 255]]]
# Image: [[[202 160 164 255]
#   [201 160 164 255]
#   [204 162 165 255]
#   ...
#   [154 125 135 255]
#   [164 132 138 255]
#   [172 137 142 255]]
#
#  [[203 162 163 255]
#   [202 163 165 255]
#   [196 162 163 255]
#   ...
#   [170 136 141 255]
#   [175 140 145 255]
#   [166 132 138 255]]
#
#  [[199 160 162 255]
#   [201 161 163 255]
#   [199 160 163 255]
#   ...
#   [177 140 145 255]
#   [166 134 139 255]
#   [165 135 140 255]]
#
#  ...
#
#  [[200 170 172 255]
#   [198 173 171 255]
#   [187 168 168 255]
#   ...
#   [161 128 129 255]
#   [162 127 129 255]
#   [168 134 134 255]]
#
#  [[199 170 169 255]
#   [195 168 166 255]
#   [134 141 144 255]
#   ...
#   [165 129 130 255]
#   [161 129 128 255]
#   [164 129 130 255]]
#
#  [[203 173 172 255]
#   [178 168 167 255]
#   [110 125 133 255]
#   ...
#   [161 128 129 255]
#   [161 126 126 255]
#   [163 128 128 255]]]
# Image: [[[235 189 195 255]
#   [232 193 198 255]
#   [234 191 196 255]
#   ...
#   [220 177 186 255]
#   [221 176 186 255]
#   [222 176 186 255]]
#
#  [[232 190 194 255]
#   [235 192 198 255]
#   [234 193 196 255]
#   ...
#   [219 178 187 255]
#   [219 179 187 255]
#   [220 178 184 255]]
#
#  [[236 191 195 255]
#   [240 192 198 255]
#   [235 192 197 255]
#   ...
#   [221 180 187 255]
#   [222 179 187 255]
#   [225 178 186 255]]
#
#  ...
#
#  [[242 210 214 255]
#   [241 208 210 255]
#   [229 210 211 255]
#   ...
#   [237 198 204 255]
#   [235 198 200 255]
#   [237 200 200 255]]
#
#  [[241 207 209 255]
#   [241 207 211 255]
#   [145 162 168 255]
#   ...
#   [231 199 199 255]
#   [231 197 198 255]
#   [237 199 201 255]]
#
#  [[242 210 213 255]
#   [207 206 208 255]
#   [118 138 147 255]
#   ...
#   [234 198 200 255]
#   [235 202 203 255]
#   [237 201 201 255]]]
# Image: [[[234 188 194 255]
#   [232 186 196 255]
#   [232 190 196 255]
#   ...
#   [223 177 186 255]
#   [224 177 184 255]
#   [227 178 182 255]]
#
#  [[234 189 195 255]
#   [236 189 195 255]
#   [233 190 197 255]
#   ...
#   [223 178 186 255]
#   [225 176 182 255]
#   [224 177 184 255]]
#
#  [[237 187 194 255]
#   [235 189 196 255]
#   [237 189 195 255]
#   ...
#   [218 175 182 255]
#   [223 174 180 255]
#   [225 178 184 255]]
#
#  ...
#
#  [[246 214 215 255]
#   [245 213 214 255]
#   [233 213 211 255]
#   ...
#   [240 202 204 255]
#   [236 202 200 255]
#   [243 203 204 255]]
#
#  [[244 212 215 255]
#   [245 214 215 255]
#   [148 164 171 255]
#   ...
#   [238 203 203 255]
#   [239 205 202 255]
#   [239 204 202 255]]
#
#  [[245 211 211 255]
#   [206 207 209 255]
#   [118 137 148 255]
#   ...
#   [239 203 204 255]
#   [242 203 204 255]
#   [241 204 204 255]]]
# Image: [[[234 186 192 255]
#   [229 183 189 255]
#   [233 185 191 255]
#   ...
#   [215 170 179 255]
#   [216 169 178 255]
#   [216 167 176 255]]
#
#  [[230 182 189 255]
#   [232 187 192 255]
#   [232 186 191 255]
#   ...
#   [215 169 179 255]
#   [212 171 175 255]
#   [215 171 178 255]]
#
#  [[231 185 192 255]
#   [230 183 186 255]
#   [232 187 193 255]
#   ...
#   [212 170 176 255]
#   [212 167 176 255]
#   [215 168 176 255]]
#
#  ...
#
#  [[245 209 213 255]
#   [247 211 213 255]
#   [231 210 210 255]
#   ...
#   [234 199 200 255]
#   [237 198 201 255]
#   [237 199 201 255]]
#
#  [[246 210 211 255]
#   [241 208 210 255]
#   [151 167 173 255]
#   ...
#   [239 202 204 255]
#   [232 200 203 255]
#   [237 202 202 255]]
#
#  [[244 214 215 255]
#   [209 211 210 255]
#   [114 136 148 255]
#   ...
#   [236 200 202 255]
#   [238 202 204 255]
#   [236 201 202 255]]]
# Image: [[[234 185 192 255]
#   [232 183 189 255]
#   [229 179 186 255]
#   ...
#   [216 172 181 255]
#   [221 175 185 255]
#   [222 177 189 255]]
#
#  [[230 184 191 255]
#   [228 182 190 255]
#   [228 182 188 255]
#   ...
#   [218 176 185 255]
#   [216 175 183 255]
#   [218 172 180 255]]
#
#  [[230 184 190 255]
#   [228 181 187 255]
#   [232 185 190 255]
#   ...
#   [221 177 184 255]
#   [214 172 181 255]
#   [215 173 180 255]]
#
#  ...
#
#  [[246 212 213 255]
#   [244 212 212 255]
#   [234 213 212 255]
#   ...
#   [234 196 199 255]
#   [235 197 199 255]
#   [240 199 201 255]]
#
#  [[243 211 211 255]
#   [244 214 212 255]
#   [152 166 173 255]
#   ...
#   [236 200 200 255]
#   [235 200 202 255]
#   [241 201 204 255]]
#
#  [[246 212 215 255]
#   [213 210 211 255]
#   [115 136 146 255]
#   ...
#   [237 199 201 255]
#   [235 196 198 255]
#   [240 199 200 255]]]
# Image: [[[235 188 197 255]
#   [229 187 191 255]
#   [236 188 194 255]
#   ...
#   [225 180 186 255]
#   [221 175 184 255]
#   [222 177 186 255]]
#
#  [[235 186 195 255]
#   [237 190 196 255]
#   [234 191 193 255]
#   ...
#   [223 178 187 255]
#   [220 178 183 255]
#   [221 175 185 255]]
#
#  [[237 188 193 255]
#   [229 185 190 255]
#   [237 188 193 255]
#   ...
#   [223 178 184 255]
#   [223 178 185 255]
#   [220 180 187 255]]
#
#  ...
#
#  [[241 211 214 255]
#   [245 211 212 255]
#   [236 211 213 255]
#   ...
#   [237 200 200 255]
#   [227 189 189 255]
#   [235 200 200 255]]
#
#  [[243 210 211 255]
#   [242 213 213 255]
#   [155 165 173 255]
#   ...
#   [240 202 204 255]
#   [239 201 202 255]
#   [232 199 200 255]]
#
#  [[246 210 212 255]
#   [218 212 213 255]
#   [116 135 142 255]
#   ...
#   [239 200 202 255]
#   [238 199 202 255]
#   [239 202 201 255]]]
# Image: [[[229 182 191   1]
#   [233 182 191   1]
#   [231 186 194   1]
#   ...
#   [216 170 183   1]
#   [215 171 184   1]
#   [216 170 180   1]]
#
#  [[227 182 191   1]
#   [230 183 190   1]
#   [228 182 188   1]
#   ...
#   [206 165 177   1]
#   [210 167 177   1]
#   [210 169 179   1]]
#
#  [[229 182 190   1]
#   [228 185 192   1]
#   [227 183 190   1]
#   ...
#   [210 167 180   1]
#   [210 167 176   1]
#   [210 168 177   1]]
#
#  ...
#
#  [[243 209 210   1]
#   [239 209 209   1]
#   [236 210 212   1]
#   ...
#   [232 196 199   1]
#   [230 195 199   1]
#   [232 193 196   1]]
#
#  [[245 209 210   1]
#   [241 209 212   1]
#   [152 168 175   1]
#   ...
#   [232 197 202   1]
#   [232 198 198   1]
# Image: [[[237 195 201   1]
#   [235 193 199   1]
#   [234 191 198   1]
#   ...
#   [223 181 191   1]
#   [228 184 194   1]
#   [224 182 190   1]]
#
#  [[238 193 199   1]
#   [237 191 197   1]
#   [236 192 199   1]
#   ...
#   [221 180 187   1]
#   [225 178 189   1]
#   [224 178 187   1]]
#
#  [[232 191 199   1]
#   [235 192 197   1]
#   [237 192 197   1]
#   ...
#   [222 179 189   1]
#   [226 179 189   1]
#   [225 182 191   1]]
#
#  ...
#
#  [[247 215 216   1]
#   [248 215 216   1]
#   [224 211 217   1]
#   ...
#   [238 202 203   1]
#   [235 202 204   1]
#   [237 201 203   1]]
#
#  [[248 216 215   1]
#   [244 214 216   1]
#   [143 160 167   1]
#   ...
#   [238 203 203   1]
#   [239 201 203   1]
#   [233 203 206   1]]
#
#  [[248 215 217   1]
#   [208 208 210   1]
#   [119 138 148   1]
#   ...
#   [237 202 203   1]
#   [239 200 201   1]
#   [239 203 206   1]]]
# Step: color_correction
# Image: [[85 83 85 ... 64 65 65]
#  [83 83 82 ... 64 65 64]
#  [82 81 82 ... 64 63 64]
#  ...
#  [69 69 69 ... 59 58 60]
#  [69 67 70 ... 59 58 59]
#  [68 68 67 ... 59 58 60]]
# Image: [[66 66 68 ... 68 69 68]
#  [65 66 66 ... 69 66 69]
#  [66 65 65 ... 67 69 67]
#  ...
#  [72 72 71 ... 63 63 62]
#  [72 72 73 ... 63 62 63]
#  [72 71 72 ... 64 63 62]]
# Image: [[63 62 62 ... 60 59 60]
#  [63 62 62 ... 59 59 60]
#  [62 62 62 ... 59 59 59]
#  ...
#  [60 61 62 ... 63 63 63]
#  [61 60 60 ... 63 63 63]
#  [62 62 61 ... 63 64 63]]
# Image: [[69 63 67 ... 59 59 59]
#  [68 65 64 ... 59 60 59]
#  [68 68 68 ... 59 59 59]
#  ...
#  [71 70 71 ... 65 66 66]
#  [69 68 70 ... 66 66 65]
#  [70 70 71 ... 68 66 65]]
# Image: [[96 97 96 ... 88 88 88]
#  [95 98 96 ... 86 88 87]
#  [97 96 94 ... 87 89 88]
#  ...
#  [88 87 84 ... 66 66 65]
#  [86 85 84 ... 65 64 67]
#  [86 86 84 ... 66 65 65]]
# Image: [[120 120 120 ...  92  92  92]
#  [121 119 120 ...  93  95  93]
#  [119 121 119 ...  92  95  92]
#  ...
#  [116 114 112 ... 111 106 103]
#  [115 113 109 ... 108 105 103]
#  [116 112 106 ... 111 106 104]]
# Image: [[166 166 168 ... 131 137 142]
#  [167 168 166 ... 141 145 138]
#  [165 166 165 ... 146 139 140]
#  ...
#  [174 175 170 ... 132 132 138]
#  [173 170 141 ... 133 132 133]
#  [176 169 126 ... 132 130 132]]
# Image: [[196 199 197 ... 185 184 184]
#  [196 199 199 ... 185 186 185]
#  [197 199 198 ... 187 186 186]
#  ...
#  [215 212 212 ... 204 203 204]
#  [211 212 162 ... 203 201 204]
#  [215 207 138 ... 203 206 205]]
# Image: [[195 194 197 ... 185 184 185]
#  [196 196 197 ... 186 183 184]
#  [114 114 114 ...  60  60  60]
#  [108 108 114 ...  60  60  60]
#  [108 108 108 ...  67  60  60]]
# Image: [[101 101 101 ... 138 138 138]
#  [101 101 101 ... 138 138 138]
#  [101 101 101 ... 138 138 138]
#  ...
#  [166 166 166 ...  91  82  82]
#  [166 166 166 ...  91  82  82]
#  [165 165 165 ...  91  91  82]]
# Image: [[168 168 168 ... 113 113 113]
#  [168 168 168 ... 113 113 113]
#  [168 168 168 ... 113 113 113]
#  ...
#  [220 220 220 ... 189 189 189]
#  [220 220 220 ... 189 189 189]
#  [220 220 220 ... 189 189 189]]
# Image: [[255 255 255 ... 188 194 195]
#  [255 255 255 ... 188 194 195]
#  [255 255 255 ... 188 188 188]
#  ...
#  [193 193 185 ...  39  39  39]
#  [193 193 185 ...  39  39  39]
#  [193 193 185 ...  39  39  39]]
# Image: [[225 225 225 ...  70  70  70]
#  [225 225 225 ...  78  78  70]
#  [225 225 225 ...  78  78  78]
#  ...
#  [188 181 163 ... 149 143 136]
#  [188 176 157 ... 149 143 136]
#  [181 176 151 ... 149 143 136]]
# Image: [[194 194 194 ... 137 137 137]
#  [194 194 194 ... 140 140 140]
#  [194 194 194 ... 143 143 143]
#  ...
#  [209 196 167 ... 136 136 136]
#  [202 184 149 ... 136 136 136]
#  [196 176 140 ... 136 136 136]]
# Image: [[208 208 208 ... 191 191 191]
#  [208 208 208 ... 191 191 191]
#  [205 205 205 ... 191 191 191]
#  ...
#  [222 205 164 ... 221 221 221]
#  [214 188 146 ... 221 221 221]
#  [208 177 136 ... 221 222 222]]
# Image: [[209 209 209 ... 188 185 185]
#  [206 209 209 ... 185 185 185]
#  [206 206 206 ... 185 185 185]
#  ...
#  [239 222 178 ... 223 223 223]
#  [227 202 159 ... 223 223 223]
#  [221 189 148 ... 223 223 223]]
# Image: [[199 199 199 ... 180 180 180]
#  [199 199 199 ... 180 180 180]
#  [199 199 199 ... 180 177 177]
#  ...
#  [233 216 178 ... 218 218 218]
#  [224 196 157 ... 221 221 220]
#  [215 186 147 ... 221 221 221]]

# %%
pipeline.images.show(image_number=10)
# Out:
#         <style>
#         .step-header {
#             font-size: 1.2em;
#             font-weight: bold;
#             margin-top: 10px;
#             margin-bottom: 5px;
#         }
#         .metadata {
#             margin-left: 20px;
#             margin-bottom: 10px;
#         }
#         .image-container {
#             display: flex;
#             flex-wrap: wrap;
#             gap: 10px;
#             margin-left: 20px;
#         }
#         .image-container img {
#             max-width: 200px;
#             margin: 10px;
#         }
#         .toggle-arrow {
#             cursor: pointer;
#             margin-left: 5px;
#         }
#         .show-more-button, .hide-button {
#             margin-left: 20px;
#             background-color: #007bff;
#             color: white;
#             border: none;
#             padding: 5px 10px;
#             cursor: pointer;
#         }
#         </style>
#         <script>
#         function toggleMetadata(stepIndex) {
#             var x = document.getElementById("metadata-" + stepIndex);
#             var arrow = document.getElementById("arrow-" + stepIndex);
#             if (x.style.display === "none") {
#                 x.style.display = "block";
#                 arrow.innerHTML = "▼";
#             } else {
#                 x.style.display = "none";
#                 arrow.innerHTML = "►";
#             }
#         }
#         function toggleImage(imageId) {
#             var img = document.getElementById(imageId);
#             var arrow = document.getElementById("arrow-" + imageId);
#             if (img.style.display === "none") {
#                 img.style.display = "block";
#                 arrow.innerHTML = "▼";
#             } else {
#                 img.style.display = "none";
#                 arrow.innerHTML = "►";
#             }
#         }
#         function showMore(stepIndex) {
#             var moreImages = document.getElementById("more-images-" + stepIndex);
#             var showMoreButton = document.getElementById("show-more-button-" + stepIndex);
#             var hideButton = document.getElementById("hide-button-" + stepIndex);
#             moreImages.style.display = "flex";
#             showMoreButton.style.display = "none";
#             hideButton.style.display = "inline-block";
#         }
#         function hide(stepIndex) {
#             var moreImages = document.getElementById("more-images-" + stepIndex);
#             var showMoreButton = document.getElementById("show-more-button-" + stepIndex);
#             var hideButton = document.getElementById("hide-button-" + stepIndex);
#             moreImages.style.display = "none";
#             showMoreButton.style.display = "inline-block";
#             hideButton.style.display = "none";
#         }
#         </script>
#         <div class='step-header'>Step: raw <span id='arrow-0' class='toggle-arrow' onclick='toggleMetadata(0)'>►</span></div><div id='metadata-0' class='metadata' style='display:block;'><div class='image-container'><div><p onclick='toggleImage("image-0-0")' style='cursor:pointer;'>Image: 20180611041431.png <span id='arrow-image-0-0' class='toggle-arrow'>►</span></p><img id='image-0-0' src='data:image/png;base64,...' style='display:block;' /></div></div></div><div class='step-header'>Step: color_correction <span id='arrow-1' class='toggle-arrow' onclick='toggleMetadata(1)'>►</span></div><div id='metadata-1' class='metadata' style='display:block;'><div class='image-container'><div><p onclick='toggleImage("image-1-0")' style='cursor:pointer;'>Image: 20180611041431.png <span id='arrow-image-1-0' class='toggle-arrow'>►</span></p><img id='image-1-0' src='data:image/jpeg;base64,...' style='display:block;' /></div></div></div><div class='step-header'>Step: datetime <span id='arrow-2' class='toggle-arrow' onclick='toggleMetadata(2)'>►</span></div><div id='metadata-2' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div><div class='step-header'>Step: overlapping <span id='arrow-3' class='toggle-arrow' onclick='toggleMetadata(3)'>►</span></div><div id='metadata-3' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div><div class='step-header'>Step: color_correction <span id='arrow-4' class='toggle-arrow' onclick='toggleMetadata(4)'>►</span></div><div id='metadata-4' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div><div class='step-header'>Step: sharpen <span id='arrow-5' class='toggle-arrow' onclick='toggleMetadata(5)'>►</span></div><div id='metadata-5' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div><div class='step-header'>Step: contrast <span id='arrow-6' class='toggle-arrow' onclick='toggleMetadata(6)'>►</span></div><div id='metadata-6' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div>

# %% [markdown]
# # Export Images to file

# %%
pipeline.save_images(image_format="png")
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-09-25 10:58:33 | Saving images from step: last
# ☁ paidiverpy ☁  |       INFO | 2024-09-25 10:58:36 | Images are saved.
