# %% [markdown]
# ## Run a pipeline

# %% [markdown]
# This process will run the entire pipeline described in a configuration file

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline

# %%
pipeline = Pipeline(config_file_path="../config_files/config_benthic_ifdo.yaml")
# Out:
# Checking files have unique names 99/99

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square" style="float:left; cursor: pointer; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#
#             <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Color_correction</h2>
#                     <h2 style="font-size:13px;">Type: Color</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_1" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_1')">
#                     <h2 style="font-size:20px;">Datetime</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_2" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_2')">
#                     <h2 style="font-size:20px;">Overlapping</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_3" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_3')">
#                     <h2 style="font-size:20px;">Color_correction</h2>
#                     <h2 style="font-size:13px;">Type: Color</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#                 <div style="clear:both;"></div>
#                 <div id="step_4" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_4')">
#                     <h2 style="font-size:20px;">Sharpen</h2>
#                     <h2 style="font-size:13px;">Type: Color</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_5" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_5')">
#                     <h2 style="font-size:20px;">Contrast</h2>
#                     <h2 style="font-size:13px;">Type: Color</h2>
#                 </div>
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#                 <div id="parameters_step_0" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "color_correction",
#     "step_name": "color",
#     "mode": "grayscale",
#     "test": false
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_1" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "datetime",
#     "step_name": "sampling",
#     "mode": "datetime",
#     "test": false,
#     "params": {
#         "min": "2016-05-11 04:14:00",
#         "max": "2016-05-11 09:27:00"
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_2" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "overlapping",
#     "step_name": "sampling",
#     "mode": "overlapping",
#     "test": false,
#     "params": {
#         "omega": 57,
#         "theta": 40,
#         "threshold": 0.5,
#         "camera_distance": 1.12
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_3" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "color_correction",
#     "step_name": "color",
#     "mode": "gaussian_blur",
#     "test": false,
#     "params": {
#         "sigma": 1.0
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_4" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "sharpen",
#     "step_name": "color",
#     "mode": "sharpen",
#     "test": false,
#     "params": {
#         "alpha": 1.5,
#         "beta": -0.5
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_5" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "contrast",
#     "step_name": "color",
#     "mode": "contrast",
#     "test": false
# }</pre>
#                 </div>
#
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "name": "raw",
#     "step_name": "open",
#     "input_path": "/home/tobfer/.paidiverpy_cache/benthic_ifdo/images",
#     "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_ifdo/metadata/metadata_benthic_ifdo.json",
#     "metadata_type": "IFDO",
#     "image_type": "JPG",
#     "output_path": "output",
#     "n_jobs": 8,
#     "rename": null,
#     "sampling": [
#         {
#             "name": "sampling",
#             "step_name": "sampling",
#             "mode": "percent",
#             "test": false,
#             "params": {
#                 "value": 0.2
#             }
#         }
#     ],
#     "convert": [
#         {
#             "name": "convert",
#             "step_name": "convert",
#             "mode": "bits",
#             "test": false,
#             "params": {
#                 "output_bits": 8
#             }
#         }
#     ]
# }</pre>
#             </div>
#         </div>
#         <script>
#             function showParameters(id) {
#                 // Hide all parameter sections
#                 var currentTarget = document.getElementById(id);
#                 var square = document.getElementsByClassName('square');
#                 var allParams = document.getElementsByClassName('parameters');
#                 var selectedParams = document.getElementById('parameters_' + id);
#                 var idWasVisible = false;
#                 if (selectedParams) {
#                     var idWasVisible = selectedParams.style.display === 'block';
#                 }
#                 for (var i = 0; i < square.length; i++) {
#                     square[i].style.color = 'black';

# %%
pipeline.get_metadata()
# Out:
#     ID                   image-filename      image-datetime image-longitude  \
# 0    0  M58_10441297_12987744807147.jpg 2016-05-11 09:09:41       -7.712106
# 2    2  M58_10441297_12987744853552.jpg 2016-05-11 09:09:41       -7.712127
# 3    3  M58_10441297_12987744857927.jpg 2016-05-11 09:09:42       -7.712127
# 4    4  M58_10441297_12987744866443.jpg 2016-05-11 09:09:43       -7.712128
# 5    5  M58_10441297_12987744870740.jpg 2016-05-11 09:09:43       -7.712129
# ..  ..                              ...                 ...             ...
# 68  68  M58_10441297_12987745210189.jpg 2016-05-11 09:26:12       -7.712126
# 67  67  M58_10441297_12987745203643.jpg 2016-05-11 09:26:12       -7.712124
# 84  84  M58_10441297_12987745296126.jpg 2016-05-11 09:26:13       -7.712128
# 90  90  M58_10441297_12987745324485.jpg 2016-05-11 09:26:13       -7.712128
# 86  86  M58_10441297_12987745304704.jpg 2016-05-11 09:26:13       -7.712128
#
#    image-latitude                            image-uuid  \
# 0       50.394186  854D01B1-BA2E-487C-8B33-7C46AFD8F45F
# 2       50.393598  E0404921-BE11-44C3-A510-6BC19249FD72
# 3       50.393542  90180FAB-4ECD-4FD9-9910-D5777D7C6807
# 4       50.393434  6B2C533C-A4ED-4C1B-8E57-DF1E59178460
# 5       50.393379  1FAE580D-D517-41C6-91DF-43BF558EEB8C
# ..            ...                                   ...
# 68      50.389057  4F48B60A-763E-4944-9330-33BC8C7A6BBA
# 67      50.389139  4B8B7C4F-0B84-4275-8EC2-00AA7B26979C
# 84      50.387952  47C291CF-7946-4F1F-A81F-F653B0A2FBEC
# 90      50.387586  729B5E32-7789-432F-9A0F-CE972898098E
# 86      50.387841  BEE5CF1F-8E81-44FA-9CD6-9528FFCEEE29
#
#    image-area-square-meter image-media-type  flag  \
# 0                 9.944266             JPEG     0
# 2                  6.52818             JPEG     0
# 3                 5.396471             JPEG     0
# 4                 4.965196             JPEG     0
# 5                 5.758141             JPEG     0
# ..                     ...              ...   ...
# 68                6.608393             JPEG     0
# 67                6.561429             JPEG     0
# 84                7.280598             JPEG     0
# 90                8.073981             JPEG     0
# 86                7.671566             JPEG     0
#
#                               point
# 0   POINT (-7.71210609 50.39418572)
# 2   POINT (-7.71212678 50.39359794)
# 3    POINT (-7.71212745 50.3935421)
# 4   POINT (-7.71212845 50.39343391)
# 5   POINT (-7.71212869 50.39337918)
# ..                              ...
# 68  POINT (-7.71212552 50.38905667)
# 67  POINT (-7.71212437 50.38913914)
# 84  POINT (-7.71212751 50.38795235)
# 90  POINT (-7.71212792 50.38758626)
# 86  POINT (-7.71212782 50.38784142)
#
# [99 rows x 10 columns]

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:00 | Running step 0: raw - OpenLayer
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:00 | Processing images using 8 cores
# [########################################] | 100% Completed | 2.66 sms
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:03 | Processing images using 8 cores
# [########################################] | 100% Completed | 1.90 sms
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:06 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:06 | Running step 1: color_correction - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:06 | Processing images using 8 cores
# [########################################] | 100% Completed | 207.49 ms
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:07 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:07 | Running step 2: datetime - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:07 | Number of photos to be removed: 0
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:07 | Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:07 | Running step 3: overlapping - ResampleLayer
# ☁ paidiverpy ☁  |      ERROR | 2024-10-06 21:46:07 | Error in resample layer: 'pitch_deg'
# ☁ paidiverpy ☁  |      ERROR | 2024-10-06 21:46:07 | Resample layer step will be skipped.
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:07 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:07 | Running step 4: color_correction - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:07 | Processing images using 8 cores
# [########################################] | 100% Completed | 203.25 ms
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:08 | Step 4 completed
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:08 | Running step 5: sharpen - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:08 | Processing images using 8 cores
# [########################################] | 100% Completed | 5.59 sms
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:14 | Step 5 completed
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:14 | Running step 6: contrast - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:14 | Processing images using 8 cores
# [########################################] | 100% Completed | 16.40 ss
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:30 | Step 6 completed

# %%
# See the images output
pipeline.images
# Out:
# Step: raw
# Image: dask.array<array, shape=(10552, 2538, 3), dtype=uint8, chunksize=(10552, 2538, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361, 3), dtype=uint8, chunksize=(9241, 2361, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10373, 2168, 3), dtype=uint8, chunksize=(10373, 2168, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10533, 2383, 3), dtype=uint8, chunksize=(10533, 2383, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865, 3), dtype=uint8, chunksize=(15615, 2865, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357, 3), dtype=uint8, chunksize=(10388, 2357, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18539, 2382, 3), dtype=uint8, chunksize=(18539, 2382, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10420, 2265, 3), dtype=uint8, chunksize=(10420, 2265, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390, 3), dtype=uint8, chunksize=(10395, 2390, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636, 3), dtype=uint8, chunksize=(10439, 2636, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476, 3), dtype=uint8, chunksize=(10369, 2476, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10346, 2215, 3), dtype=uint8, chunksize=(10346, 2215, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10903, 2453, 3), dtype=uint8, chunksize=(10903, 2453, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429, 3), dtype=uint8, chunksize=(10507, 2429, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10895, 2351, 3), dtype=uint8, chunksize=(10895, 2351, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324, 3), dtype=uint8, chunksize=(10298, 2324, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25409, 2516, 3), dtype=uint8, chunksize=(17781, 2516, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10398, 2299, 3), dtype=uint8, chunksize=(10398, 2299, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411, 3), dtype=uint8, chunksize=(12256, 2411, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300, 3), dtype=uint8, chunksize=(10529, 2300, 3), chunktype=numpy.ndarray>
# Step: color_correction
# Image: dask.array<array, shape=(10552, 2538), dtype=uint8, chunksize=(10552, 2538), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10373, 2168), dtype=uint8, chunksize=(10373, 2168), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10533, 2383), dtype=uint8, chunksize=(10533, 2383), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18539, 2382), dtype=uint8, chunksize=(18539, 2382), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10420, 2265), dtype=uint8, chunksize=(10420, 2265), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636), dtype=uint8, chunksize=(10439, 2636), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476), dtype=uint8, chunksize=(10369, 2476), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10346, 2215), dtype=uint8, chunksize=(10346, 2215), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10903, 2453), dtype=uint8, chunksize=(10903, 2453), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10895, 2351), dtype=uint8, chunksize=(10895, 2351), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324), dtype=uint8, chunksize=(10298, 2324), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25409, 2516), dtype=uint8, chunksize=(25409, 2516), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10398, 2299), dtype=uint8, chunksize=(10398, 2299), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411), dtype=uint8, chunksize=(12256, 2411), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300), dtype=uint8, chunksize=(10529, 2300), chunktype=numpy.ndarray>
# Step: datetime
# Image: dask.array<array, shape=(10552, 2538), dtype=uint8, chunksize=(10552, 2538), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10373, 2168), dtype=uint8, chunksize=(10373, 2168), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10533, 2383), dtype=uint8, chunksize=(10533, 2383), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18539, 2382), dtype=uint8, chunksize=(18539, 2382), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10420, 2265), dtype=uint8, chunksize=(10420, 2265), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636), dtype=uint8, chunksize=(10439, 2636), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476), dtype=uint8, chunksize=(10369, 2476), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10346, 2215), dtype=uint8, chunksize=(10346, 2215), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10903, 2453), dtype=uint8, chunksize=(10903, 2453), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10895, 2351), dtype=uint8, chunksize=(10895, 2351), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324), dtype=uint8, chunksize=(10298, 2324), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25409, 2516), dtype=uint8, chunksize=(25409, 2516), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10398, 2299), dtype=uint8, chunksize=(10398, 2299), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411), dtype=uint8, chunksize=(12256, 2411), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300), dtype=uint8, chunksize=(10529, 2300), chunktype=numpy.ndarray>
# Step: overlapping
# Image: dask.array<array, shape=(10552, 2538), dtype=uint8, chunksize=(10552, 2538), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10373, 2168), dtype=uint8, chunksize=(10373, 2168), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10533, 2383), dtype=uint8, chunksize=(10533, 2383), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18539, 2382), dtype=uint8, chunksize=(18539, 2382), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10420, 2265), dtype=uint8, chunksize=(10420, 2265), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636), dtype=uint8, chunksize=(10439, 2636), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476), dtype=uint8, chunksize=(10369, 2476), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10346, 2215), dtype=uint8, chunksize=(10346, 2215), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10903, 2453), dtype=uint8, chunksize=(10903, 2453), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10895, 2351), dtype=uint8, chunksize=(10895, 2351), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324), dtype=uint8, chunksize=(10298, 2324), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25409, 2516), dtype=uint8, chunksize=(25409, 2516), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10398, 2299), dtype=uint8, chunksize=(10398, 2299), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411), dtype=uint8, chunksize=(12256, 2411), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300), dtype=uint8, chunksize=(10529, 2300), chunktype=numpy.ndarray>
# Step: color_correction
# Image: dask.array<array, shape=(10552, 2538), dtype=uint8, chunksize=(10552, 2538), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10373, 2168), dtype=uint8, chunksize=(10373, 2168), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10533, 2383), dtype=uint8, chunksize=(10533, 2383), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18539, 2382), dtype=uint8, chunksize=(18539, 2382), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10420, 2265), dtype=uint8, chunksize=(10420, 2265), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636), dtype=uint8, chunksize=(10439, 2636), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476), dtype=uint8, chunksize=(10369, 2476), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10346, 2215), dtype=uint8, chunksize=(10346, 2215), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10903, 2453), dtype=uint8, chunksize=(10903, 2453), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10895, 2351), dtype=uint8, chunksize=(10895, 2351), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324), dtype=uint8, chunksize=(10298, 2324), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25409, 2516), dtype=uint8, chunksize=(25409, 2516), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10398, 2299), dtype=uint8, chunksize=(10398, 2299), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411), dtype=uint8, chunksize=(12256, 2411), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300), dtype=uint8, chunksize=(10529, 2300), chunktype=numpy.ndarray>
# Step: sharpen
# Image: dask.array<array, shape=(10552, 2538), dtype=uint8, chunksize=(10552, 2538), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10373, 2168), dtype=uint8, chunksize=(10373, 2168), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10533, 2383), dtype=uint8, chunksize=(10533, 2383), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18539, 2382), dtype=uint8, chunksize=(18539, 2382), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10420, 2265), dtype=uint8, chunksize=(10420, 2265), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636), dtype=uint8, chunksize=(10439, 2636), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476), dtype=uint8, chunksize=(10369, 2476), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10346, 2215), dtype=uint8, chunksize=(10346, 2215), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10903, 2453), dtype=uint8, chunksize=(10903, 2453), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10895, 2351), dtype=uint8, chunksize=(10895, 2351), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324), dtype=uint8, chunksize=(10298, 2324), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25409, 2516), dtype=uint8, chunksize=(25409, 2516), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10398, 2299), dtype=uint8, chunksize=(10398, 2299), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411), dtype=uint8, chunksize=(12256, 2411), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300), dtype=uint8, chunksize=(10529, 2300), chunktype=numpy.ndarray>
# Step: contrast
# Image: dask.array<array, shape=(10552, 2538), dtype=uint8, chunksize=(10552, 2538), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9241, 2361), dtype=uint8, chunksize=(9241, 2361), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10373, 2168), dtype=uint8, chunksize=(10373, 2168), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10533, 2383), dtype=uint8, chunksize=(10533, 2383), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10388, 2357), dtype=uint8, chunksize=(10388, 2357), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18539, 2382), dtype=uint8, chunksize=(18539, 2382), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10420, 2265), dtype=uint8, chunksize=(10420, 2265), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636), dtype=uint8, chunksize=(10439, 2636), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476), dtype=uint8, chunksize=(10369, 2476), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10346, 2215), dtype=uint8, chunksize=(10346, 2215), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10903, 2453), dtype=uint8, chunksize=(10903, 2453), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10895, 2351), dtype=uint8, chunksize=(10895, 2351), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324), dtype=uint8, chunksize=(10298, 2324), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25409, 2516), dtype=uint8, chunksize=(25409, 2516), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10398, 2299), dtype=uint8, chunksize=(10398, 2299), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411), dtype=uint8, chunksize=(12256, 2411), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300), dtype=uint8, chunksize=(10529, 2300), chunktype=numpy.ndarray>

# %%
# You can also rerun your processing from a specific step
pipeline.run(from_step=2)
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:32 | Running step 3: overlapping - ResampleLayer
# ☁ paidiverpy ☁  |      ERROR | 2024-10-06 21:46:32 | Error in resample layer: 'pitch_deg'
# ☁ paidiverpy ☁  |      ERROR | 2024-10-06 21:46:32 | Resample layer step will be skipped.
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:32 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:32 | Running step 4: color_correction - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:32 | Processing images using 8 cores
# [########################################] | 100% Completed | 203.89 ms
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:33 | Step 4 completed
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:33 | Running step 5: sharpen - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:33 | Processing images using 8 cores
# [########################################] | 100% Completed | 5.85 sms
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:39 | Step 5 completed
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:39 | Running step 6: contrast - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-10-06 21:46:39 | Processing images using 8 cores
# [########################                ] | 60% Completed | 8.66 s ms

# %%
pipeline.images

# %%
pipeline.images.show(image_number=10)

# %% [markdown]
# # Export Images to file

# %%
pipeline.save_images(image_format="png")
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-10-04 01:18:12 | Saving images from step: last
# ☁ paidiverpy ☁  |       INFO | 2024-10-04 01:19:59 | Images are saved to: output
