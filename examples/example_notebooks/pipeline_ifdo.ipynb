# %% [markdown]
# ## Run a pipeline

# %% [markdown]
# This process will run the entire pipeline described in a configuration file

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pipeline = Pipeline(config_file_path="../config_files/config_benthic_ifdo.yaml")
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:23:54 | Downloading sample dataset: 'benthic_ifdo'
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:23:54 | Downloading benthic_ifdo files...
# Downloading benthic_ifdo files: 100%|██████████████████████| 269M/269M [00:51<00:00, 5.21MB/s]
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:48 | Downloaded and cached at /home/tobfer/.paidiverpy_cache/4698789dc3f7e2c4e688e2e5aaedd459b4b33a126e85c69cc3345a04529c72c3.zip
# Extracting benthic_ifdo files: 100%|██████████████████████| 103/103 [00:01<00:00, 93.22file/s]
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:49 | Extracted files to /home/tobfer/.paidiverpy_cache/benthic_ifdo
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:49 | Dataset 'benthic_ifdo' is available at: /home/tobfer/.paidiverpy_cache/benthic_ifdo
# Checking files have unique names 99/99

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square"
#             style="float:left; cursor: pointer; padding: 10px;
#             width: max-content; height: 80px; margin: 10px;
#             border: 1px solid #000; text-align: center; line-height: 80px;"
#             onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#         <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Colour_correction</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_1" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_1')">
#                     <h2 style="font-size:20px;">Datetime</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_2" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_2')">
#                     <h2 style="font-size:20px;">Overlapping</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_3" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_3')">
#                     <h2 style="font-size:20px;">Colour_correction</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#                 <div style="clear:both;"></div>
#                 <div id="step_4" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_4')">
#                     <h2 style="font-size:20px;">Sharpen</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_5" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_5')">
#                     <h2 style="font-size:20px;">Contrast</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#                 <div id="parameters_step_0" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "colour_correction",
#     "step_name": "colour",
#     "mode": "grayscale",
#     "test": false
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_1" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "datetime",
#     "step_name": "sampling",
#     "mode": "datetime",
#     "test": false,
#     "params": {
#         "min": "2016-05-11 04:14:00",
#         "max": "2016-05-11 09:27:00"
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_2" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "overlapping",
#     "step_name": "sampling",
#     "mode": "overlapping",
#     "test": false,
#     "params": {
#         "omega": 57,
#         "theta": 40,
#         "threshold": 0.5,
#         "camera_distance": 1.12
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_3" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "colour_correction",
#     "step_name": "colour",
#     "mode": "gaussian_blur",
#     "test": false,
#     "params": {
#         "sigma": 1.0
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_4" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "sharpen",
#     "step_name": "colour",
#     "mode": "sharpen",
#     "test": false,
#     "params": {
#         "alpha": 1.5,
#         "beta": -0.5
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_5" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "contrast",
#     "step_name": "colour",
#     "mode": "contrast",
#     "test": false
# }</pre>
#                 </div>
#
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "name": "raw",
#     "step_name": "open",
#     "sample_data": "benthic_ifdo",
#     "input_path": "/home/tobfer/.paidiverpy_cache/benthic_ifdo/images",
#     "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_ifdo/metadata/metadata_benthic_ifdo.json",
#     "metadata_type": "IFDO",
#     "image_type": "JPG",
#     "is_remote": false,
#     "output_is_remote": false,
#     "output_path": "output",
#     "n_jobs": 8,
#     "client": null,
#     "track_changes": true,
#     "rename": null,
#     "sampling": [
#         {
#             "name": "sampling",
#             "step_name": "sampling",
#             "mode": "fixed",
#             "test": false,
#             "params": {
#                 "value": 5
#             }
#         }
#     ],
#     "convert": [
#         {
#             "name": "convert",
#             "step_name":

# %%
pipeline.get_metadata()
# Out:
#     ID                   image-filename      image-datetime  image-longitude  \
# 0    0  M58_10441297_12987744807147.jpg 2016-05-11 09:09:41        -7.712106
# 2    2  M58_10441297_12987744853552.jpg 2016-05-11 09:09:41        -7.712127
# 3    3  M58_10441297_12987744857927.jpg 2016-05-11 09:09:42        -7.712127
# 4    4  M58_10441297_12987744866443.jpg 2016-05-11 09:09:43        -7.712128
# 5    5  M58_10441297_12987744870740.jpg 2016-05-11 09:09:43        -7.712129
# ..  ..                              ...                 ...              ...
# 18  18  M58_10441297_12987745210189.jpg 2016-05-11 09:26:12        -7.712126
# 17  17  M58_10441297_12987745203643.jpg 2016-05-11 09:26:12        -7.712124
# 34  34  M58_10441297_12987745296126.jpg 2016-05-11 09:26:13        -7.712128
# 40  40  M58_10441297_12987745324485.jpg 2016-05-11 09:26:13        -7.712128
# 36  36  M58_10441297_12987745304704.jpg 2016-05-11 09:26:13        -7.712128
#
#     image-latitude                            image-uuid  \
# 0        50.394186  854D01B1-BA2E-487C-8B33-7C46AFD8F45F
# 2        50.393598  E0404921-BE11-44C3-A510-6BC19249FD72
# 3        50.393542  90180FAB-4ECD-4FD9-9910-D5777D7C6807
# 4        50.393434  6B2C533C-A4ED-4C1B-8E57-DF1E59178460
# 5        50.393379  1FAE580D-D517-41C6-91DF-43BF558EEB8C
# ..             ...                                   ...
# 18       50.389057  4F48B60A-763E-4944-9330-33BC8C7A6BBA
# 17       50.389139  4B8B7C4F-0B84-4275-8EC2-00AA7B26979C
# 34       50.387952  47C291CF-7946-4F1F-A81F-F653B0A2FBEC
# 40       50.387586  729B5E32-7789-432F-9A0F-CE972898098E
# 36       50.387841  BEE5CF1F-8E81-44FA-9CD6-9528FFCEEE29
#
#     image-area-square-meter image-media-type  flag  \
# 0                  9.944266             JPEG     0
# 2                  6.528180             JPEG     0
# 3                  5.396471             JPEG     0
# 4                  4.965196             JPEG     0
# 5                  5.758141             JPEG     0
# ..                      ...              ...   ...
# 18                 6.608393             JPEG     0
# 17                 6.561429             JPEG     0
# 34                 7.280598             JPEG     0
# 40                 8.073981             JPEG     0
# 36                 7.671566             JPEG     0
#
#                               point
# 0   POINT (-7.71210609 50.39418572)
# 2   POINT (-7.71212678 50.39359794)
# 3    POINT (-7.71212745 50.3935421)
# 4   POINT (-7.71212845 50.39343391)
# 5   POINT (-7.71212869 50.39337918)
# ..                              ...
# 18  POINT (-7.71212552 50.38905667)
# 17  POINT (-7.71212437 50.38913914)
# 34  POINT (-7.71212751 50.38795235)
# 40  POINT (-7.71212792 50.38758626)
# 36  POINT (-7.71212782 50.38784142)
#
# [99 rows x 10 columns]

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:49 | Processing images using 8 cores
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:49 | Running step 0: raw - OpenLayer
# [########################################] | 100% Completed | 465.40 ms
# [########################################] | 100% Completed | 541.08 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:50 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:50 | Running step 1: colour_correction - ColourLayer
# [########################################] | 100% Completed | 102.42 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:51 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:51 | Running step 2: datetime - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:51 | Number of photos to be removed: 0
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:51 | Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:51 | Running step 3: overlapping - ResampleLayer
# ☁ paidiverpy ☁  |      ERROR | 2025-02-06 15:24:51 | Error in resample layer: 'pitch_deg'
# ☁ paidiverpy ☁  |      ERROR | 2025-02-06 15:24:51 | Resample layer step will be skipped.
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:51 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:51 | Running step 4: colour_correction - ColourLayer
# [########################################] | 100% Completed | 101.81 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:51 | Step 4 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:51 | Running step 5: sharpen - ColourLayer
# [########################################] | 100% Completed | 1.53 sms
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:53 | Step 5 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:53 | Running step 6: contrast - ColourLayer
# [########################################] | 100% Completed | 6.20 sms
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:24:59 | Step 6 completed

# %%
# See the images output
pipeline.images
# Out:
# Step: raw
# Image: dask.array<array, shape=(10463, 2131, 3), dtype=uint8, chunksize=(10463, 2131, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390, 3), dtype=uint8, chunksize=(10395, 2390, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465, 3), dtype=uint8, chunksize=(10918, 2465, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539, 3), dtype=uint8, chunksize=(17620, 2539, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398, 3), dtype=uint8, chunksize=(10251, 2398, 3), chunktype=numpy.ndarray>
# Step: colour_correction
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Step: datetime
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Step: overlapping
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Step: colour_correction
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Step: sharpen
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Step: contrast
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>

# %%
# You can also rerun your processing from a specific step
pipeline.run(from_step=2)
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:00 | Processing images using 8 cores
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:00 | Running step 3: overlapping - ResampleLayer
# ☁ paidiverpy ☁  |      ERROR | 2025-02-06 15:25:00 | Error in resample layer: 'pitch_deg'
# ☁ paidiverpy ☁  |      ERROR | 2025-02-06 15:25:00 | Resample layer step will be skipped.
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:00 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:00 | Running step 4: colour_correction - ColourLayer
# [########################################] | 100% Completed | 101.90 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:00 | Step 4 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:00 | Running step 5: sharpen - ColourLayer
# [########################################] | 100% Completed | 1.63 sms
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:02 | Step 5 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:02 | Running step 6: contrast - ColourLayer
# [########################################] | 100% Completed | 5.48 sms
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:08 | Step 6 completed

# %%
pipeline.images
# Out:
# Step: raw
# Image: dask.array<array, shape=(10463, 2131, 3), dtype=uint8, chunksize=(10463, 2131, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390, 3), dtype=uint8, chunksize=(10395, 2390, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465, 3), dtype=uint8, chunksize=(10918, 2465, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539, 3), dtype=uint8, chunksize=(17620, 2539, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398, 3), dtype=uint8, chunksize=(10251, 2398, 3), chunktype=numpy.ndarray>
# Step: colour_correction
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Step: datetime
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Step: overlapping
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Step: colour_correction
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Step: sharpen
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>
# Step: contrast
# Image: dask.array<array, shape=(10463, 2131), dtype=uint8, chunksize=(10463, 2131), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10918, 2465), dtype=uint8, chunksize=(10918, 2465), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10251, 2398), dtype=uint8, chunksize=(10251, 2398), chunktype=numpy.ndarray>

# %%
pipeline.images.show(image_number=10)
# Out:
#         <style>
#         .step-header {
#             font-size: 1.2em;
#             font-weight: bold;
#             margin-top: 10px;
#             margin-bottom: 5px;
#         }
#         .metadata {
#             margin-left: 20px;
#             margin-bottom: 10px;
#         }
#         .image-container {
#             display: flex;
#             flex-wrap: wrap;
#             gap: 10px;
#             margin-left: 20px;
#         }
#         .image-container img {
#             max-width: 200px;
#             margin: 10px;
#         }
#         .toggle-arrow {
#             cursor: pointer;
#             margin-left: 5px;
#         }
#         .show-more-button, .hide-button {
#             margin-left: 20px;
#             background-color: #007bff;
#             color: white;
#             border: none;
#             padding: 5px 10px;
#             cursor: pointer;
#         }
#         </style>
#         <script>
#         function toggleMetadata(stepIndex) {
#             var x = document.getElementById("metadata-" + stepIndex);
#             var arrow = document.getElementById("arrow-" + stepIndex);
#             if (x.style.display === "none") {
#                 x.style.display = "block";
#                 arrow.innerHTML = "▼";
#             } else {
#                 x.style.display = "none";
#                 arrow.innerHTML = "►";
#             }
#         }
#         function toggleImage(imageId) {
#             var img = document.getElementById(imageId);
#             var arrow = document.getElementById("arrow-" + imageId);
#             if (img.style.display === "none") {
#                 img.style.display = "block";
#                 arrow.innerHTML = "▼";
#             } else {
#                 img.style.display = "none";
#                 arrow.innerHTML = "►";
#             }
#         }
#         function showMore(stepIndex) {
#             var moreImages = document.getElementById("more-images-" + stepIndex);
#             var showMoreButton = document.getElementById("show-more-button-" + stepIndex);
#             var hideButton = document.getElementById("hide-button-" + stepIndex);
#             moreImages.style.display = "flex";
#             showMoreButton.style.display = "none";
#             hideButton.style.display = "inline-block";
#         }
#         function hide(stepIndex) {
#             var moreImages = document.getElementById("more-images-" + stepIndex);
#             var showMoreButton = document.getElementById("show-more-button-" + stepIndex);
#             var hideButton = document.getElementById("hide-button-" + stepIndex);
#             moreImages.style.display = "none";
#             showMoreButton.style.display = "inline-block";
#             hideButton.style.display = "none";
#         }
#         </script>
#
#                 <div class='step-header'>Step: raw <span id='arrow-0'
#                     class='toggle-arrow'
#                     onclick='toggleMetadata(0)'>►</span>
#                 </div>
#                 <div id='metadata-0' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div>
#                 <div class='step-header'>Step: colour_correction <span id='arrow-1'
#                     class='toggle-arrow'
#                     onclick='toggleMetadata(1)'>►</span>
#                 </div>
#                 <div id='metadata-1' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div>
#                 <div class='step-header'>Step: datetime <span id='arrow-2'
#                     class='toggle-arrow'
#                     onclick='toggleMetadata(2)'>►</span>
#                 </div>
#                 <div id='metadata-2' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div>
#                 <div class='step-header'>Step: overlapping <span id='arrow-3'
#                     class='toggle-arrow'
#                     onclick='toggleMetadata(3)'>►</span>
#                 </div>
#                 <div id='metadata-3' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div>
#                 <div class='step-header'>Step: colour_correction <span id='arrow-4'
#                     class='toggle-arrow'
#                     onclick='toggleMetadata(4)'>►</span>
#                 </div>
#                 <div id='metadata-4' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div>
#                 <div class='step-header'>Step: sharpen <span id='arrow-5'
#                     class='toggle-arrow'
#                     onclick='toggleMetadata(5)'>►</span>
#                 </div>
#                 <div id='metadata-5' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div>
#                 <div class='step-header'>Step: contrast <span id='arrow-6'
#                     class='toggle-arrow'
#                     onclick='toggleMetadata(6)'>►</span>
#                 </div>
#                 <div id='metadata-6' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div>

# %% [markdown]
# # Export Images to file

# %%
pipeline.save_images(image_format="png")
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:47 | Saving images from step: last
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:47 | Saving images using Dask
# [########################################] | 100% Completed | 7.36 sms
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 15:25:54 | Images are saved to: output
