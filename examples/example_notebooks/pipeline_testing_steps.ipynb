# %% [markdown]
# ## Run a pipeline with test inputs

# %% [markdown]
# This process will run the entire pipeline described in a configuration file and we will add some  test input to try some metrics

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline
from paidiverpy.resample_layer import ResampleLayer
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pipeline = Pipeline(config_file_path='../config_files/config_jen2.yaml')

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square" style="float:left; cursor: pointer; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#
#             <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Overlapping</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#                 <div id="parameters_step_0" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "overlapping",
#     "mode": "overlapping",
#     "limits": [
#         40,
#         57,
#         0.5
#     ],
#     "test": true,
#     "step_name": "sampling"
# }</pre>
#                 </div>
#
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "input_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen",
#     "output_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data",
#     "catalog_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/catalog/catalog_jen.csv",
#     "catalog_type": "CSV",
#     "append_data_to_catalog": "/mnt/code/code/noc/paidiver/paidiverpy/examples/catalog/scidata_20180610.csv",
#     "image_type": "JPG",
#     "sampling_mode": "percent",
#     "sampling_limits": 0.8,
#     "convert_autoscale": true,
#     "convert_bits": 8,
#     "convert_to": "RGB",
#     "convert_channel_selector": -1,
#     "name": "raw",
#     "step_name": "Open"
# }</pre>
#             </div>
#         </div>
#         <script>
#             function showParameters(id) {
#                 // Hide all parameter sections
#                 var currentTarget = document.getElementById(id);
#                 var square = document.getElementsByClassName('square');
#                 var allParams = document.getElementsByClassName('parameters');
#                 var selectedParams = document.getElementById('parameters_' + id);
#                 var idWasVisible = false;
#                 if (selectedParams) {
#                     var idWasVisible = selectedParams.style.display === 'block';
#                 }
#                 for (var i = 0; i < square.length; i++) {
#                     square[i].style.color = 'black';
#                 }
#                 for (var i = 0; i < allParams.length; i++) {
#                     allParams[i].style.display = 'none';
#                 }
#                 // Show the selected parameter section
#                 if (selectedParams) {
#                     if (idWasVisible) {
#                         selectedParams.style.display = 'none';
#                         currentTarget.style.color = 'black';
#                     } else {
#                         selectedParams.style.display = 'block';
#                         currentTarget.style.color = 'red';
#                     }
#                 }
#             }
#         </script>

# %%
# See the pipeline steps in json format. As you can see, the Overlapping step is on test mode
pipeline.steps
# Out:
# [('raw',
#   paidiverpy.open_layer.open_layer.OpenLayer,
#   {'input_path': PosixPath('/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen'),
#    'output_path': PosixPath('/mnt/code/code/noc/paidiver/paidiverpy/examples/data'),
#    'catalog_path': PosixPath('/mnt/code/code/noc/paidiver/paidiverpy/examples/catalog/catalog_jen.csv'),
#    'catalog_type': 'CSV',
#    'append_data_to_catalog': '/mnt/code/code/noc/paidiver/paidiverpy/examples/catalog/scidata_20180610.csv',
#    'image_type': 'JPG',
#    'sampling_mode': 'percent',
#    'sampling_limits': 0.8,
#    'convert_autoscale': True,
#    'convert_bits': 8,
#    'convert_to': 'RGB',
#    'convert_channel_selector': -1,
#    'name': 'raw',
#    'step_name': 'Open'}),
#  ('overlapping',
#   paidiverpy.resample_layer.resample_layer.ResampleLayer,
#   {'name': 'overlapping',
#    'mode': 'overlapping',
#    'limits': [40, 57, 0.5],
#    'test': True,
#    'step_name': 'sampling'})]

# %%
# Run the pipeline. You will see a plot of the overlapping.
# This plot will help you to decide if you are ok with the limits provided in the overlapping( theta = 40, omega - 80 and overlapping of 50%)
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:05:14 | Running step 0: raw - OpenLayer
# Processing Images: 100%|███████████████████████████████| 80/80 [00:36<00:00,  2.21it/s]
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:05:50 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:05:50 | Step 0 saved
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:05:50 | Running step 1: overlapping - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:05:50 | Number of photos to be removed: 22
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:05:51 | Step 1 completed

# %%
# See the images output.You can see that the step was not added to the images output
pipeline.images
# Out:
# Step: raw
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef48fe20b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4903fbf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed720>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4c1d5b0d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901efe20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed7e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed870>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f671f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed510>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b1f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b310>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b550>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ada0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ac20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ac80>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ab60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bac0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028af20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf70>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028baf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b790>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bc10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b8e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b910>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b850>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028be20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bbe0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b2b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b9a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bcd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bdf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ae60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bfa0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b6d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f67220>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba00>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902400d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902405b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240700>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240460>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ee0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240640>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902407f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240490>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240d30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240a60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240fd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240c10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902408e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240130>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240760>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241240>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240dc0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241540>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241420>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240eb0>

# %%
# Change the step to another limits: overlapping of 70%
pipeline.add_step('overlapping', ResampleLayer, {'mode': 'overlapping', 'limits': [40, 57, 0.7], 'test':True}, 1, substitute=True)

# %%
# Rerun the pipeline from the second step. It is still on test mode
pipeline.run(from_step=0)
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:27 | Running step 1: overlapping - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:27 | Number of photos to be removed: 9
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:28 | Step 1 completed

# %%
# I am happy with the new value. So now I can update the value on the overlapping step (test to false), and run again
pipeline.add_step('overlapping', ResampleLayer, {'mode': 'overlapping', 'limits': [40, 57, 0.7], 'test':False}, 1, substitute=True)
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:28 | Running step 1: overlapping - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:28 | Number of photos to be removed: 9
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:28 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:28 | Step 1 saved

# %%
# now the images were updated
pipeline.images
# Out:
# Step: raw
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef48fe20b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4903fbf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed720>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4c1d5b0d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901efe20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed7e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed870>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f671f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed510>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b1f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b310>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b550>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ada0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ac20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ac80>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ab60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bac0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028af20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf70>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028baf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b790>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bc10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b8e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b910>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b850>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028be20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bbe0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b2b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b9a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bcd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bdf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ae60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bfa0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b6d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f67220>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba00>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902400d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902405b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240700>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240460>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ee0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240640>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902407f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240490>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240d30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240a60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240fd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240c10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902408e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240130>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240760>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241240>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240dc0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241540>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241420>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240eb0>
# Step: trim_overlapping
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef48fe20b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4903fbf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4c1d5b0d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed7e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f671f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b1f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ab60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bac0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028af20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf70>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028baf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b790>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bc10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b8e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b910>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b850>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028be20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bbe0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b2b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b9a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bcd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bdf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ae60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bfa0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b6d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f67220>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba00>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902400d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902405b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240700>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240460>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ee0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240640>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902407f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240490>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240d30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240a60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240fd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240c10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902408e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240130>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240760>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241240>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240dc0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241540>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241420>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240eb0>

# %%
#Now I am adding a new step to resample based on obscure images. It is in test mode
pipeline.add_step('obscure', ResampleLayer, {'mode': 'obscure', 'limits': [50, 90], 'test':True})

# %%
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:29 | Running step 2: obscure - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:31 | Number of photos to be removed: 3
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:31 | Step 2 completed

# %%
# I am happy with the limits. So I will apply the changes and rerun
pipeline.add_step('obscure', ResampleLayer, {'mode': 'obscure', 'limits': [50, 90], 'test':False}, 2, substitute=True)
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:49 | Running step 2: obscure - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:50 | Number of photos to be removed: 3
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:50 | Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:03:50 | Step 2 saved

# %%
#Now the outputs were save to the images
pipeline.images
# Out:
# Step: raw
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef48fe20b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4903fbf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed720>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4c1d5b0d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901efe20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed7e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed870>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f671f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed510>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b1f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b310>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b550>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ada0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ac20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ac80>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ab60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bac0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028af20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf70>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028baf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b790>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bc10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b8e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b910>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b850>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028be20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bbe0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b2b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b9a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bcd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bdf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ae60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bfa0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b6d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f67220>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba00>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902400d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902405b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240700>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240460>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ee0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240640>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902407f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240490>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240d30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240a60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240fd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240c10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902408e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240130>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240760>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241240>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240dc0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241540>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241420>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240eb0>
# Step: trim_overlapping
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef48fe20b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4903fbf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4c1d5b0d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4901ed7e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f671f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b1f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ab60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bac0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028af20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf70>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028baf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b790>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bc10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b8e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b910>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b850>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028be20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bbe0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b2b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b9a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bcd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bdf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ae60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bfa0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b6d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f67220>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba00>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902400d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902405b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240700>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240460>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ee0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240640>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902407f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240490>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240d30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240a60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240fd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240c10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902408e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240130>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240760>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241240>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240dc0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241540>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241420>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240eb0>
# Step: trim_obscure
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef48fe20b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4903fbf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4c1d5b0d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b1f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b7f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ab60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bac0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028af20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf70>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028baf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bd60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b790>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bb20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bc10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b8e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b910>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b850>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028be20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bbe0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b2b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b9a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bcd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bdf0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ae60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bfa0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b6d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028bf40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028b610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490f67220>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef49028ba00>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902400d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902405b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240610>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240700>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902402e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902406d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240460>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ee0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240820>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240640>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902407f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240490>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240670>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240d30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240970>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240a60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240fd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240c10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef4902408e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240b20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240130>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240760>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241240>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240dc0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241540>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490241420>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240ca0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7ef490240eb0>
