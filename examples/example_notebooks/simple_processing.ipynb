# %% [markdown]
# ## Simple Processing

# %% [markdown]
# An example to proessing images without a proper pipeline

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.open_layer import OpenLayer
from paidiverpy.resample_layer import ResampleLayer
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Open the images

# %% [markdown]
# The first step will be always the load images step

# %%
# Instantiate the class
open_layer = OpenLayer(config_file_path='../config_files/config_1.yaml')

# %%
# See the configuration file
open_layer.config
# Out:
# {
#     "general": {
#         "name": "raw",
#         "step_name": "open",
#         "input_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen",
#         "output_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data",
#         "n_jobs": 1,
#         "catalog_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/catalog/catalog_jen.csv",
#         "catalog_type": "CSV",
#         "append_data_to_catalog": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen/waypoints/scidata_20180610.csv",
#         "image_type": "JPG",
#         "sampling": [
#             {
#                 "name": "sampling",
#                 "step_name": "sampling",
#                 "mode": "percent",
#                 "test": false,
#                 "params": {
#                     "value": 0.1
#                 }
#             }
#         ],
#         "convert": [
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "mode": "bits",
#                 "test": false,
#                 "params": {
#                     "output_bits": 8
#                 }
#             },
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "mode": "to",
#                 "test": false,
#                 "params": {
#                     "to": "gray",
#                     "channel_selector": 0
#                 }
#             }
#         ]
#     },
#     "steps": []
# }

# %%
# Run the open layer process. It will open the images from the input path, and save then as a ImagesLayer
open_layer.run()
# Out:
# Open Images: 100%|█████████████████████████████████████| 10/10 [00:02<00:00,  3.98it/s]

# %%
# See the images output
open_layer.images
# Out:
# Step: raw
# Image: [[[92]
#   [91]
#   [90]
#   ...
#   [93]
#   [93]
#   [92]]
#
#  [[92]
#   [91]
#   [90]
#   ...
#   [93]
#   [93]
#   [93]]
#
#  [[91]
#   [91]
#   [90]
#   ...
#   [96]
#   [96]
#   [95]]
#
#  ...
#
#  [[91]
#   [91]
#   [91]
#   ...
#   [83]
#   [81]
#   [82]]
#
#  [[92]
#   [91]
#   [91]
#   ...
#   [83]
#   [83]
#   [84]]
#
#  [[90]
#   [91]
#   [91]
#   ...
#   [84]
#   [85]
#   [85]]]
# Image: [[[156]
#   [154]
#   [153]
#   ...
#   [133]
#   [133]
#   [133]]
#
#  [[154]
#   [153]
#   [153]
#   ...
#   [132]
#   [132]
#   [132]]
#
#  [[154]
#   [154]
#   [154]
#   ...
#   [129]
#   [131]
#   [132]]
#
#  ...
#
#  [[152]
#   [151]
#   [152]
#   ...
#   [111]
#   [112]
#   [111]]
#
#  [[152]
#   [152]
#   [151]
#   ...
#   [111]
#   [113]
#   [112]]
#
#  [[151]
#   [151]
#   [152]
#   ...
#   [110]
#   [112]
#   [112]]]
# Image: [[[196]
#   [194]
#   [196]
#   ...
#   [180]
#   [181]
#   [182]]
#
#  [[198]
#   [196]
#   [195]
#   ...
#   [181]
#   [181]
#   [182]]
#
#  [[198]
#   [197]
#   [194]
#   ...
#   [181]
#   [182]
#   [180]]
#
#  ...
#
#  [[210]
#   [209]
#   [210]
#   ...
#   [195]
#   [195]
#   [197]]
#
#  [[211]
#   [210]
#   [209]
#   ...
#   [196]
#   [194]
#   [196]]
#
#  [[211]
#   [212]
#   [209]
#   ...
#   [198]
#   [195]
#   [197]]]
# Image: [[[195]
#   [194]
#   [193]
#   ...
#   [182]
#   [183]
#   [184]]
#
#  [[196]
#   [193]
#   [193]
#   ...
#   [182]
#   [183]
#   [184]]
#
#  [[194]
#   [193]
#   [191]
#   ...
#   [182]
#   [182]
#   [184]]
#
#  ...
#
#  [[212]
#   [214]
#   [211]
#   ...
#   [202]
#   [201]
#   [201]]
#
#  [[213]
#   [215]
#   [212]
#   ...
#   [204]
#   [201]
#   [202]]
#
#  [[214]
#   [214]
#   [212]
#   ...
#   [202]
#   [200]
#   [202]]]
# Image: [[[197]
#   [196]
#   [197]
#   ...
#   [185]
#   [185]
#   [184]]
#
#  [[195]
#   [196]
#   [197]
#   ...
#   [187]
#   [186]
#   [183]]
#
#  [[195]
#   [196]
#   [196]
#   ...
#   [186]
#   [184]
#   [182]]
#
#  ...
#
#  [[211]
#   [212]
#   [212]
#   ...
#   [198]
#   [198]
#   [199]]
#
#  [[214]
#   [215]
#   [213]
#   ...
#   [199]
#   [199]
#   [199]]
#
#  [[213]
#   [214]
#   [214]
#   ...
#   [199]
#   [198]
#   [198]]]
# Image: [[[204]
#   [203]
#   [203]
#   ...
#   [197]
#   [197]
#   [197]]
#
#  [[203]
#   [204]
#   [204]
#   ...
#   [198]
#   [200]
#   [199]]
#
#  [[202]
#   [205]
#   [206]
#   ...
#   [199]
#   [201]
#   [200]]
#
#  ...
#
#  [[217]
#   [219]
#   [217]
#   ...
#   [209]
#   [211]
#   [211]]
#
#  [[218]
#   [219]
#   [217]
#   ...
#   [207]
#   [210]
#   [211]]
#
#  [[217]
#   [217]
#   [217]
#   ...
#   [206]
#   [208]
#   [209]]]
# Image: [[[194]
#   [193]
#   [196]
#   ...
#   [189]
#   [189]
#   [187]]
#
#  [[197]
#   [196]
#   [197]
#   ...
#   [187]
#   [188]
#   [188]]
#
#  [[199]
#   [198]
#   [198]
#   ...
#   [187]
#   [187]
#   [187]]
#
#  ...
#
#  [[214]
#   [212]
#   [212]
#   ...
#   [202]
#   [203]
#   [203]]
#
#  [[216]
#   [215]
#   [212]
#   ...
#   [200]
#   [202]
#   [201]]
#
#  [[216]
#   [217]
#   [214]
#   ...
#   [200]
#   [201]
#   [201]]]
# Image: [[[206]
#   [204]
#   [203]
#   ...
#   [197]
#   [196]
#   [196]]
#
#  [[206]
#   [204]
#   [203]
#   ...
#   [196]
#   [197]
#   [197]]
#
#  [[206]
#   [204]
#   [203]
#   ...
#   [196]
#   [195]
#   [197]]
#
#  ...
#
#  [[220]
#   [220]
#   [220]
#   ...
#   [209]
#   [212]
#   [212]]
#
#  [[218]
#   [219]
#   [220]
#   ...
#   [208]
#   [210]
#   [211]]
#
#  [[217]
#   [218]
#   [219]
#   ...
#   [207]
#   [209]
#   [211]]]
# Image: [[[201]
#   [201]
#   [202]
#   ...
#   [192]
#   [190]
#   [191]]
#
#  [[199]
#   [199]
#   [202]
#   ...
#   [192]
#   [192]
#   [192]]
#
#  [[200]
#   [200]
#   [202]
#   ...
#   [192]
#   [192]
#   [192]]
#
#  ...
#
#  [[217]
#   [216]
#   [216]
#   ...
#   [204]
#   [206]
#   [206]]
#
#  [[217]
#   [216]
#   [218]
#   ...
#   [205]
#   [207]
#   [206]]
#
#  [[216]
#   [216]
#   [218]
#   ...
#   [206]
#   [206]
#   [205]]]
# Image: [[[202]
#   [202]
#   [202]
#   ...
#   [187]
#   [188]
#   [187]]
#
#  [[203]
#   [204]
#   [202]
#   ...
#   [187]
#   [188]
#   [187]]
#
#  [[201]
#   [203]
#   [201]
#   ...
#   [186]
#   [189]
#   [188]]
#
#  ...
#
#  [[212]
#   [212]
#   [211]
#   ...
#   [206]
#   [206]
#   [204]]
#
#  [[212]
#   [212]
#   [213]
#   ...
#   [206]
#   [205]
#   [203]]
#
#  [[213]
#   [213]
#   [214]
#   ...
#   [205]
#   [206]
#   [205]]]

# %%
# See a particular image
open_layer.images.show(index=5)

# %%
# See the first 5 lines of the catalog
open_layer.get_catalog().head(5)
# Out:
#     ID  Unnamed: 0_x            filename  XResolution_x  YResolution_x  \
# 0    0           430  20180611041421.JPG            300            300
# 26  26           456  20180611041841.JPG            300            300
# 33  33           463  20180611041951.JPG            300            300
# 36  36           466  20180611042021.JPG            300            300
# 37  37           467  20180611042031.JPG            300            300
#
#     ExposureTime  FNumber  ISO            datetime  MaxApertureValue  ...  \
# 0       0.016667        8  200 2018-06-11 04:14:21          2.828427  ...
# 26      0.016667        8  200 2018-06-11 04:18:41          2.828427  ...
# 33      0.016667        8  200 2018-06-11 04:19:51          2.828427  ...
# 36      0.016667        8  200 2018-06-11 04:20:21          2.828427  ...
# 37      0.016667        8  200 2018-06-11 04:20:31          2.828427  ...
#
#                  Make        Model   Software  Orientation  \
# 0   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 26  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 33  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 36  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 37  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
#
#                DateTime  YCbCrPositioning  YResolution_y  \
# 0   2018:06:11 04:14:21                 2          300.0
# 26  2018:06:11 04:18:41                 2          300.0
# 33  2018:06:11 04:19:51                 2          300.0
# 36  2018:06:11 04:20:21                 2          300.0
# 37  2018:06:11 04:20:31                 2          300.0
#
#                                             Copyright  XResolution_y  \
# 0                                                 ...          300.0
# 26                                                ...          300.0
# 33                                                ...          300.0
# 36                                                ...          300.0
# 37                                                ...          300.0
#
#                                   Artist
# 0
# 26
# 33
# 36
# 37
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Resample the images

# %% [markdown]
# The add a next step to your processing pipeline, you need to instantiate the ResampleLayer class and pass the OpenLayer class as an argument

# %%
# Set the parameters
parameters = {
    'name': 'datetime',
    'mode': 'datetime',
    'params': {
        'min': '2018-06-11 04:14:00',
        'max': '2018-06-11 04:20:00'
    }
}

# %%
# Instantiate the new class
resample = ResampleLayer(paidiverpy=open_layer, parameters=parameters)

# %%
# Run the process using the parameters provided
resample.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-09-18 18:05:02 | Number of photos to be removed: 7

# %%
# See the output images
resample.images
# Out:
# Step: raw
# Image: [[[92]
#   [91]
#   [90]
#   ...
#   [93]
#   [93]
#   [92]]
#
#  [[92]
#   [91]
#   [90]
#   ...
#   [93]
#   [93]
#   [93]]
#
#  [[91]
#   [91]
#   [90]
#   ...
#   [96]
#   [96]
#   [95]]
#
#  ...
#
#  [[91]
#   [91]
#   [91]
#   ...
#   [83]
#   [81]
#   [82]]
#
#  [[92]
#   [91]
#   [91]
#   ...
#   [83]
#   [83]
#   [84]]
#
#  [[90]
#   [91]
#   [91]
#   ...
#   [84]
#   [85]
#   [85]]]
# Image: [[[156]
#   [154]
#   [153]
#   ...
#   [133]
#   [133]
#   [133]]
#
#  [[154]
#   [153]
#   [153]
#   ...
#   [132]
#   [132]
#   [132]]
#
#  [[154]
#   [154]
#   [154]
#   ...
#   [129]
#   [131]
#   [132]]
#
#  ...
#
#  [[152]
#   [151]
#   [152]
#   ...
#   [111]
#   [112]
#   [111]]
#
#  [[152]
#   [152]
#   [151]
#   ...
#   [111]
#   [113]
#   [112]]
#
#  [[151]
#   [151]
#   [152]
#   ...
#   [110]
#   [112]
#   [112]]]
# Image: [[[196]
#   [194]
#   [196]
#   ...
#   [180]
#   [181]
#   [182]]
#
#  [[198]
#   [196]
#   [195]
#   ...
#   [181]
#   [181]
#   [182]]
#
#  [[198]
#   [197]
#   [194]
#   ...
#   [181]
#   [182]
#   [180]]
#
#  ...
#
#  [[210]
#   [209]
#   [210]
#   ...
#   [195]
#   [195]
#   [197]]
#
#  [[211]
#   [210]
#   [209]
#   ...
#   [196]
#   [194]
#   [196]]
#
#  [[211]
#   [212]
#   [209]
#   ...
#   [198]
#   [195]
#   [197]]]
# Image: [[[195]
#   [194]
#   [193]
#   ...
#   [182]
#   [183]
#   [184]]
#
#  [[196]
#   [193]
#   [193]
#   ...
#   [182]
#   [183]
#   [184]]
#
#  [[194]
#   [193]
#   [191]
#   ...
#   [182]
#   [182]
#   [184]]
#
#  ...
#
#  [[212]
#   [214]
#   [211]
#   ...
#   [202]
#   [201]
#   [201]]
#
#  [[213]
#   [215]
#   [212]
#   ...
#   [204]
#   [201]
#   [202]]
#
#  [[214]
#   [214]
#   [212]
#   ...
#   [202]
#   [200]
#   [202]]]
# Image: [[[197]
#   [196]
#   [197]
#   ...
#   [185]
#   [185]
#   [184]]
#
#  [[195]
#   [196]
#   [197]
#   ...
#   [187]
#   [186]
#   [183]]
#
#  [[195]
#   [196]
#   [196]
#   ...
#   [186]
#   [184]
#   [182]]
#
#  ...
#
#  [[211]
#   [212]
#   [212]
#   ...
#   [198]
#   [198]
#   [199]]
#
#  [[214]
#   [215]
#   [213]
#   ...
#   [199]
#   [199]
#   [199]]
#
#  [[213]
#   [214]
#   [214]
#   ...
#   [199]
#   [198]
#   [198]]]
# Image: [[[204]
#   [203]
#   [203]
#   ...
#   [197]
#   [197]
#   [197]]
#
#  [[203]
#   [204]
#   [204]
#   ...
#   [198]
#   [200]
#   [199]]
#
#  [[202]
#   [205]
#   [206]
#   ...
#   [199]
#   [201]
#   [200]]
#
#  ...
#
#  [[217]
#   [219]
#   [217]
#   ...
#   [209]
#   [211]
#   [211]]
#
#  [[218]
#   [219]
#   [217]
#   ...
#   [207]
#   [210]
#   [211]]
#
#  [[217]
#   [217]
#   [217]
#   ...
#   [206]
#   [208]
#   [209]]]
# Image: [[[194]
#   [193]
#   [196]
#   ...
#   [189]
#   [189]
#   [187]]
#
#  [[197]
#   [196]
#   [197]
#   ...
#   [187]
#   [188]
#   [188]]
#
#  [[199]
#   [198]
#   [198]
#   ...
#   [187]
#   [187]
#   [187]]
#
#  ...
#
#  [[214]
#   [212]
#   [212]
#   ...
#   [202]
#   [203]
#   [203]]
#
#  [[216]
#   [215]
#   [212]
#   ...
#   [200]
#   [202]
#   [201]]
#
#  [[216]
#   [217]
#   [214]
#   ...
#   [200]
#   [201]
#   [201]]]
# Image: [[[206]
#   [204]
#   [203]
#   ...
#   [197]
#   [196]
#   [196]]
#
#  [[206]
#   [204]
#   [203]
#   ...
#   [196]
#   [197]
#   [197]]
#
#  [[206]
#   [204]
#   [203]
#   ...
#   [196]
#   [195]
#   [197]]
#
#  ...
#
#  [[220]
#   [220]
#   [220]
#   ...
#   [209]
#   [212]
#   [212]]
#
#  [[218]
#   [219]
#   [220]
#   ...
#   [208]
#   [210]
#   [211]]
#
#  [[217]
#   [218]
#   [219]
#   ...
#   [207]
#   [209]
#   [211]]]
# Image: [[[201]
#   [201]
#   [202]
#   ...
#   [192]
#   [190]
#   [191]]
#
#  [[199]
#   [199]
#   [202]
#   ...
#   [192]
#   [192]
#   [192]]
#
#  [[200]
#   [200]
#   [202]
#   ...
#   [192]
#   [192]
#   [192]]
#
#  ...
#
#  [[217]
#   [216]
#   [216]
#   ...
#   [204]
#   [206]
#   [206]]
#
#  [[217]
#   [216]
#   [218]
#   ...
#   [205]
#   [207]
#   [206]]
#
#  [[216]
#   [216]
#   [218]
#   ...
#   [206]
#   [206]
#   [205]]]
# Image: [[[202]
#   [202]
#   [202]
#   ...
#   [187]
#   [188]
#   [187]]
#
#  [[203]
#   [204]
#   [202]
#   ...
#   [187]
#   [188]
#   [187]]
#
#  [[201]
#   [203]
#   [201]
#   ...
#   [186]
#   [189]
#   [188]]
#
#  ...
#
#  [[212]
#   [212]
#   [211]
#   ...
#   [206]
#   [206]
#   [204]]
#
#  [[212]
#   [212]
#   [213]
#   ...
#   [206]
#   [205]
#   [203]]
#
#  [[213]
#   [213]
#   [214]
#   ...
#   [205]
#   [206]
#   [205]]]
# Step: sampling
# Image: [[[92]
#   [91]
#   [90]
#   ...
#   [93]
#   [93]
#   [92]]
#
#  [[92]
#   [91]
#   [90]
#   ...
#   [93]
#   [93]
#   [93]]
#
#  [[91]
#   [91]
#   [90]
#   ...
#   [96]
#   [96]
#   [95]]
#
#  ...
#
#  [[91]
#   [91]
#   [91]
#   ...
#   [83]
#   [81]
#   [82]]
#
#  [[92]
#   [91]
#   [91]
#   ...
#   [83]
#   [83]
#   [84]]
#
#  [[90]
#   [91]
#   [91]
#   ...
#   [84]
#   [85]
#   [85]]]
# Image: [[[156]
#   [154]
#   [153]
#   ...
#   [133]
#   [133]
#   [133]]
#
#  [[154]
#   [153]
#   [153]
#   ...
#   [132]
#   [132]
#   [132]]
#
#  [[154]
#   [154]
#   [154]
#   ...
#   [129]
#   [131]
#   [132]]
#
#  ...
#
#  [[152]
#   [151]
#   [152]
#   ...
#   [111]
#   [112]
#   [111]]
#
#  [[152]
#   [152]
#   [151]
#   ...
#   [111]
#   [113]
#   [112]]
#
#  [[151]
#   [151]
#   [152]
#   ...
#   [110]
#   [112]
#   [112]]]
# Image: [[[196]
#   [194]
#   [196]
#   ...
#   [180]
#   [181]
#   [182]]
#
#  [[198]
#   [196]
#   [195]
#   ...
#   [181]
#   [181]
#   [182]]
#
#  [[198]
#   [197]
#   [194]
#   ...
#   [181]
#   [182]
#   [180]]
#
#  ...
#
#  [[210]
#   [209]
#   [210]
#   ...
#   [195]
#   [195]
#   [197]]
#
#  [[211]
#   [210]
#   [209]
#   ...
#   [196]
#   [194]
#   [196]]
#
#  [[211]
#   [212]
#   [209]
#   ...
#   [198]
#   [195]
#   [197]]]
