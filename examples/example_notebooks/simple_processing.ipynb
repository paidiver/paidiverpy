# %% [markdown]
# ## Simple Processing

# %% [markdown]
# An example to proessing images without a proper pipeline

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.open_layer import OpenLayer
from paidiverpy.resample_layer import ResampleLayer

# %% [markdown]
# ### Open the images

# %% [markdown]
# The first step will be always the load images step

# %%
# Instantiate the class
open_layer = OpenLayer(config_file_path="../config_files/config_1.yaml")

# %%
# See the configuration file
open_layer.config
# Out:
# {
#     "general": {
#         "name": "raw",
#         "step_name": "open",
#         "input_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen",
#         "output_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data",
#         "n_jobs": 1,
#         "metadata_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/metadata/metadata_benthic.csv",
#         "metadata_type": "CSV_FILE",
#         "append_data_to_metadata": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen/waypoints/scidata_20180610.csv",
#         "image_type": "JPG",
#         "rename": "datetime",
#         "sampling": [
#             {
#                 "name": "sampling",
#                 "step_name": "sampling",
#                 "mode": "percent",
#                 "test": false,
#                 "params": {
#                     "value": 0.1
#                 }
#             }
#         ],
#         "convert": [
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "mode": "bits",
#                 "test": false,
#                 "params": {
#                     "output_bits": 8
#                 }
#             },
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "mode": "to",
#                 "test": false,
#                 "params": {
#                     "to": "gray",
#                     "channel_selector": 0
#                 }
#             }
#         ]
#     },
#     "steps": []
# }

# %%
# Run the open layer process. It will open the images from the input path, and save then as a ImagesLayer
open_layer.run()
# Out:
# Open Images: 100%|█████████████████████████████████████| 10/10 [00:01<00:00,  5.19it/s]

# %%
# See the images output
open_layer.images
# Out:
# Step: raw
# Image: [[82 81 81 ... 82 82 81]
#  [81 81 81 ... 81 81 82]
#  [81 81 81 ... 81 82 82]
#  ...
#  [79 80 81 ... 81 81 81]
#  [80 80 80 ... 81 81 80]
#  [80 80 80 ... 81 81 80]]
# Image: [[156 154 153 ... 133 133 133]
#  [154 153 153 ... 132 132 132]
#  [154 154 154 ... 129 131 132]
#  ...
#  [152 151 152 ... 111 112 111]
#  [152 152 151 ... 111 113 112]
#  [151 151 152 ... 110 112 112]]
# Image: [[198 198 198 ... 187 189 186]
#  [198 198 198 ... 186 188 186]
#  [198 194 195 ... 185 187 186]
#  ...
#  [212 212 212 ... 200 201 202]
#  [212 212 211 ... 203 203 203]
#  [210 212 211 ... 204 203 203]]
# Image: [[202 203 200 ... 189 189 187]
#  [201 203 202 ... 190 192 192]
#  [202 204 204 ... 190 192 195]
#  ...
#  [216 216 216 ... 203 205 206]
#  [216 216 217 ... 202 203 203]
#  [215 216 216 ... 202 204 205]]
# Image: [[199 199 199 ... 184 181 183]
#  [200 199 199 ... 181 180 183]
#  [201 202 201 ... 179 181 184]
#  ...
#  [215 215 215 ... 203 203 202]
#  [215 215 215 ... 204 204 202]
#  [214 215 214 ... 205 205 203]]
# Image: [[202 201 200 ... 195 192 190]
#  [200 202 201 ... 194 190 188]
#  [200 200 203 ... 194 192 191]
#  ...
#  [214 212 213 ... 208 207 207]
#  [215 213 214 ... 209 207 206]
#  [215 215 214 ... 208 207 205]]
# Image: [[197 196 196 ... 190 191 190]
#  [198 197 197 ... 191 191 190]
#  [197 197 195 ... 188 190 189]
#  ...
#  [215 213 214 ... 207 208 207]
#  [213 212 214 ... 207 208 207]
#  [212 212 214 ... 207 209 208]]
# Image: [[198 198 196 ... 193 191 192]
#  [199 199 199 ... 192 189 189]
#  [200 200 200 ... 192 190 190]
#  ...
#  [215 216 216 ... 213 216 215]
#  [214 214 216 ... 213 215 214]
#  [214 215 215 ... 214 213 212]]
# Image: [[195 195 196 ... 187 187 186]
#  [194 196 196 ... 187 188 187]
#  [194 195 196 ... 186 187 186]
#  ...
#  [216 214 215 ... 207 206 206]
#  [214 213 214 ... 204 205 204]
#  [214 212 213 ... 207 206 206]]
# Image: [[198 199 200 ... 187 189 188]
#  [197 198 199 ... 188 190 191]
#  [196 198 198 ... 188 191 192]
#  ...
#  [215 214 214 ... 202 204 204]
#  [214 212 213 ... 203 204 203]
#  [213 212 213 ... 203 204 205]]

# %%
open_layer.get_metadata()
# Out:
#     ID  Unnamed: 0_x                  filename  XResolution_x  YResolution_x  \
# 9    9           439  20180611T041551.000Z.JPG            300            300
# 26  26           456  20180611T041841.000Z.JPG            300            300
# 47  47           477  20180611T042211.000Z.JPG            300            300
# 50  50           480  20180611T042241.000Z.JPG            300            300
# 51  51           481  20180611T042251.000Z.JPG            300            300
# 64  64           494  20180611T042501.000Z.JPG            300            300
# 67  67           497  20180611T042531.000Z.JPG            300            300
# 70  70           500  20180611T042601.000Z.JPG            300            300
# 80  80           510  20180611T042741.000Z.JPG            300            300
# 91  91           521  20180611T042931.000Z.JPG            300            300
#
#     ExposureTime  FNumber  ISO            datetime  MaxApertureValue  ...  \
# 9       0.016667        8  200 2018-06-11 04:15:51          2.828427  ...
# 26      0.016667        8  200 2018-06-11 04:18:41          2.828427  ...
# 47      0.016667        8  200 2018-06-11 04:22:11          2.828427  ...
# 50      0.016667        8  200 2018-06-11 04:22:41          2.828427  ...
# 51      0.016667        8  200 2018-06-11 04:22:51          2.828427  ...
# 64      0.016667        8  200 2018-06-11 04:25:01          2.828427  ...
# 67      0.016667        8  200 2018-06-11 04:25:31          2.828427  ...
# 70      0.016667        8  200 2018-06-11 04:26:01          2.828427  ...
# 80      0.016667        8  200 2018-06-11 04:27:41          2.828427  ...
# 91      0.016667        8  200 2018-06-11 04:29:31          2.828427  ...
#
#                  Make        Model   Software  Orientation  \
# 9   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 26  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 47  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 50  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 51  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 64  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 67  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 70  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 80  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 91  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
#
#                DateTime  YCbCrPositioning  YResolution_y  \
# 9   2018:06:11 04:15:51                 2          300.0
# 26  2018:06:11 04:18:41                 2          300.0
# 47  2018:06:11 04:22:11                 2          300.0
# 50  2018:06:11 04:22:41                 2          300.0
# 51  2018:06:11 04:22:51                 2          300.0
# 64  2018:06:11 04:25:01                 2          300.0
# 67  2018:06:11 04:25:31                 2          300.0
# 70  2018:06:11 04:26:01                 2          300.0
# 80  2018:06:11 04:27:41                 2          300.0
# 91  2018:06:11 04:29:31                 2          300.0
#
#                                             Copyright  XResolution_y  \
# 9                                                 ...          300.0
# 26                                                ...          300.0
# 47                                                ...          300.0
# 50                                                ...          300.0
# 51                                                ...          300.0
# 64                                                ...          300.0
# 67                                                ...          300.0
# 70                                                ...          300.0
# 80                                                ...          300.0
# 91                                                ...          300.0
#
#                                   Artist
# 9
# 26
# 47
# 50
# 51
# 64
# 67
# 70
# 80
# 91
#
# [10 rows x 51 columns]

# %%
# See a particular image
open_layer.images.show(index=5)

# %%
# See the first 5 lines of the metadata
open_layer.get_metadata().head(5)
# Out:
#     ID  Unnamed: 0_x                  filename  XResolution_x  YResolution_x  \
# 9    9           439  20180611T041551.000Z.JPG            300            300
# 26  26           456  20180611T041841.000Z.JPG            300            300
# 47  47           477  20180611T042211.000Z.JPG            300            300
# 50  50           480  20180611T042241.000Z.JPG            300            300
# 51  51           481  20180611T042251.000Z.JPG            300            300
#
#     ExposureTime  FNumber  ISO            datetime  MaxApertureValue  ...  \
# 9       0.016667        8  200 2018-06-11 04:15:51          2.828427  ...
# 26      0.016667        8  200 2018-06-11 04:18:41          2.828427  ...
# 47      0.016667        8  200 2018-06-11 04:22:11          2.828427  ...
# 50      0.016667        8  200 2018-06-11 04:22:41          2.828427  ...
# 51      0.016667        8  200 2018-06-11 04:22:51          2.828427  ...
#
#                  Make        Model   Software  Orientation  \
# 9   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 26  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 47  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 50  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 51  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
#
#                DateTime  YCbCrPositioning  YResolution_y  \
# 9   2018:06:11 04:15:51                 2          300.0
# 26  2018:06:11 04:18:41                 2          300.0
# 47  2018:06:11 04:22:11                 2          300.0
# 50  2018:06:11 04:22:41                 2          300.0
# 51  2018:06:11 04:22:51                 2          300.0
#
#                                             Copyright  XResolution_y  \
# 9                                                 ...          300.0
# 26                                                ...          300.0
# 47                                                ...          300.0
# 50                                                ...          300.0
# 51                                                ...          300.0
#
#                                   Artist
# 9
# 26
# 47
# 50
# 51
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Resample the images

# %% [markdown]
# The add a next step to your processing pipeline, you need to instantiate the ResampleLayer class and pass the OpenLayer class as an argument

# %%
# Set the parameters
parameters = {
    "name": "datetime",
    "mode": "datetime",
    "params": {"min": "2018-06-11 04:14:00", "max": "2018-06-11 04:20:00"},
}

# %%
# Instantiate the new class
resample = ResampleLayer(paidiverpy=open_layer, parameters=parameters)

# %%
# Run the process using the parameters provided
resample.run()

# %%
# See the output images
resample.images
# Out:
# Step: raw
# Image: [[82 81 81 ... 82 82 81]
#  [81 81 81 ... 81 81 82]
#  [81 81 81 ... 81 82 82]
#  ...
#  [79 80 81 ... 81 81 81]
#  [80 80 80 ... 81 81 80]
#  [80 80 80 ... 81 81 80]]
# Image: [[156 154 153 ... 133 133 133]
#  [154 153 153 ... 132 132 132]
#  [154 154 154 ... 129 131 132]
#  ...
#  [152 151 152 ... 111 112 111]
#  [152 152 151 ... 111 113 112]
#  [151 151 152 ... 110 112 112]]
# Image: [[198 198 198 ... 187 189 186]
#  [198 198 198 ... 186 188 186]
#  [198 194 195 ... 185 187 186]
#  ...
#  [212 212 212 ... 200 201 202]
#  [212 212 211 ... 203 203 203]
#  [210 212 211 ... 204 203 203]]
# Image: [[202 203 200 ... 189 189 187]
#  [201 203 202 ... 190 192 192]
#  [202 204 204 ... 190 192 195]
#  ...
#  [216 216 216 ... 203 205 206]
#  [216 216 217 ... 202 203 203]
#  [215 216 216 ... 202 204 205]]
# Image: [[199 199 199 ... 184 181 183]
#  [200 199 199 ... 181 180 183]
#  [201 202 201 ... 179 181 184]
#  ...
#  [215 215 215 ... 203 203 202]
#  [215 215 215 ... 204 204 202]
#  [214 215 214 ... 205 205 203]]
# Image: [[202 201 200 ... 195 192 190]
#  [200 202 201 ... 194 190 188]
#  [200 200 203 ... 194 192 191]
#  ...
#  [214 212 213 ... 208 207 207]
#  [215 213 214 ... 209 207 206]
#  [215 215 214 ... 208 207 205]]
# Image: [[197 196 196 ... 190 191 190]
#  [198 197 197 ... 191 191 190]
#  [197 197 195 ... 188 190 189]
#  ...
#  [215 213 214 ... 207 208 207]
#  [213 212 214 ... 207 208 207]
#  [212 212 214 ... 207 209 208]]
# Image: [[198 198 196 ... 193 191 192]
#  [199 199 199 ... 192 189 189]
#  [200 200 200 ... 192 190 190]
#  ...
#  [215 216 216 ... 213 216 215]
#  [214 214 216 ... 213 215 214]
#  [214 215 215 ... 214 213 212]]
# Image: [[195 195 196 ... 187 187 186]
#  [194 196 196 ... 187 188 187]
#  [194 195 196 ... 186 187 186]
#  ...
#  [216 214 215 ... 207 206 206]
#  [214 213 214 ... 204 205 204]
#  [214 212 213 ... 207 206 206]]
# Image: [[198 199 200 ... 187 189 188]
#  [197 198 199 ... 188 190 191]
#  [196 198 198 ... 188 191 192]
#  ...
#  [215 214 214 ... 202 204 204]
#  [214 212 213 ... 203 204 203]
#  [213 212 213 ... 203 204 205]]
# Step: sampling
# Image: [[82 81 81 ... 82 82 81]
#  [81 81 81 ... 81 81 82]
#  [81 81 81 ... 81 82 82]
#  ...
#  [79 80 81 ... 81 81 81]
#  [80 80 80 ... 81 81 80]
#  [80 80 80 ... 81 81 80]]
# Image: [[156 154 153 ... 133 133 133]
#  [154 153 153 ... 132 132 132]
#  [154 154 154 ... 129 131 132]
#  ...
#  [152 151 152 ... 111 112 111]
#  [152 152 151 ... 111 113 112]
#  [151 151 152 ... 110 112 112]]
