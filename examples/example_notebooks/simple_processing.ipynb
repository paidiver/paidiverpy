# %% [markdown]
# ## Simple Processing

# %% [markdown]
# An example to proessing images without a proper pipeline

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.open_layer import OpenLayer
from paidiverpy.resample_layer import ResampleLayer
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Open the images

# %% [markdown]
# The first step will be always the load images step

# %%
# Instantiate the class
open_layer = OpenLayer(config_file_path="../config_files/config_simple.yaml")

# %%
# See the configuration file
open_layer.config
# Out:
# {
#     "general": {
#         "name": "raw",
#         "step_name": "open",
#         "input_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/images",
#         "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/metadata_benthic_csv.csv",
#         "metadata_type": "CSV_FILE",
#         "image_type": "PNG",
#         "append_data_to_metadata": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/appended_metadata_benthic_csv.csv",
#         "output_path": "output",
#         "n_jobs": 1,
#         "rename": "datetime",
#         "sampling": [
#             {
#                 "name": "sampling",
#                 "step_name": "sampling",
#                 "mode": "percent",
#                 "test": false,
#                 "params": {
#                     "value": 0.1
#                 }
#             }
#         ],
#         "convert": [
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "mode": "bits",
#                 "test": false,
#                 "params": {
#                     "output_bits": 8
#                 }
#             },
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "mode": "to",
#                 "test": false,
#                 "params": {
#                     "to": "gray",
#                     "channel_selector": 0
#                 }
#             }
#         ]
#     },
#     "steps": []
# }

# %%
# Run the open layer process. It will open the images from the input path, and save then as a ImagesLayer
open_layer.run()
# Out:
# Open Images: 100%|█████████████████████████████████████| 10/10 [00:00<00:00, 20.16it/s]

# %%
# See the images output
open_layer.images
# Out:
# Step: raw
# Image: [[144 144 142 ...  98  97  95]
#  [145 141 142 ...  94  95  98]
#  [142 132 144 ...  97  96  95]
#  ...
#  [ 99  97  95 ...  76  73  73]
#  [ 97  97  92 ...  74  73  73]
#  [ 98  95  92 ...  76  73  74]]
# Image: [[167 172 168 ... 115 111 115]
#  [164 171 169 ... 112 112 111]
#  [170 167 167 ... 112 107 110]
#  ...
#  [103 103 101 ... 147 140 151]
#  [107 104  95 ... 149 141 150]
#  [106 100  92 ... 151 147 144]]
# Image: [[202 201 204 ... 154 164 172]
#  [203 202 196 ... 170 175 166]
#  [199 201 199 ... 177 166 165]
#  ...
#  [200 198 187 ... 161 162 168]
#  [199 195 134 ... 165 161 164]
#  [203 178 110 ... 161 161 163]]
# Image: [[234 238 232 ... 217 232 227]
#  [232 235 232 ... 217 215 224]
#  [236 228 234 ... 219 217 213]
#  ...
#  [241 245 233 ... 237 235 229]
#  [243 246 150 ... 232 235 230]
#  [249 212 117 ... 238 235 233]]
# Image: [[235 229 236 ... 225 221 222]
#  [235 237 234 ... 223 220 221]
#  [237 229 237 ... 223 223 220]
#  ...
#  [241 245 236 ... 237 227 235]
#  [243 242 155 ... 240 239 232]
#  [246 218 116 ... 239 238 239]]
# Image: [[240 241 239 ... 220 216 221]
#  [236 239 239 ... 218 213 219]
#  [241 237 236 ... 217 216 215]
#  ...
#  [249 248 233 ... 240 238 236]
#  [244 245 156 ... 236 235 237]
#  [242 213 118 ... 235 238 236]]
# Image: [[239 238 239 ... 225 224 222]
#  [242 236 239 ... 224 221 221]
#  [238 241 237 ... 226 225 228]
#  ...
#  [248 247 238 ... 242 240 238]
#  [248 247 164 ... 236 238 238]
#  [249 216 121 ... 239 242 244]]
# Image: [[239 241 229 ... 221 228 219]
#  [236 235 239 ... 223 226 219]
#  [237 237 236 ... 221 230 219]
#  ...
#  [249 245 239 ... 238 237 231]
#  [246 246 161 ... 237 241 233]
#  [245 211 120 ... 235 238 236]]
# Image: [[237 234 235 ... 218 223 222]
#  [231 235 229 ... 224 224 219]
#  [239 236 237 ... 217 229 224]
#  ...
#  [246 243 238 ... 237 236 239]
#  [244 242 159 ... 243 238 242]
#  [246 214 121 ... 234 236 240]]
# Image: [[240 239 239 ... 227 231 223]
#  [240 234 237 ... 224 230 231]
#  [237 238 239 ... 225 229 226]
#  ...
#  [241 248 224 ... 242 239 245]
#  [247 244 143 ... 237 240 243]
#  [246 206 119 ... 245 249 242]]

# %%
open_layer.get_metadata()
# Out:
#      ID            image-filename  XResolution  YResolution  ExposureTime  \
# 15  445  20180611T041651.000Z.PNG          300          300      0.016667
# 22  452  20180611T041801.000Z.PNG          300          300      0.016667
# 27  457  20180611T041851.000Z.PNG          300          300      0.016667
# 35  465  20180611T042011.000Z.PNG          300          300      0.016667
# 37  467  20180611T042031.000Z.PNG          300          300      0.016667
# 47  477  20180611T042211.000Z.PNG          300          300      0.016667
# 66  496  20180611T042521.000Z.PNG          300          300      0.016667
# 68  498  20180611T042541.000Z.PNG          300          300      0.016667
# 83  513  20180611T042811.000Z.PNG          300          300      0.016667
# 94  524  20180611T043001.000Z.PNG          300          300      0.016667
#
#     FNumber  ISO      image-datetime  MaxApertureValue  WhiteBalance  ...  \
# 15        8  200 2018-06-11 04:16:51          2.828427  FLASH         ...
# 22        8  200 2018-06-11 04:18:01          2.828427  FLASH         ...
# 27        8  200 2018-06-11 04:18:51          2.828427  FLASH         ...
# 35        8  200 2018-06-11 04:20:11          2.828427  FLASH         ...
# 37        8  200 2018-06-11 04:20:31          2.828427  FLASH         ...
# 47        8  200 2018-06-11 04:22:11          2.828427  FLASH         ...
# 66        8  200 2018-06-11 04:25:21          2.828427  FLASH         ...
# 68        8  200 2018-06-11 04:25:41          2.828427  FLASH         ...
# 83        8  200 2018-06-11 04:28:11          2.828427  FLASH         ...
# 94        8  200 2018-06-11 04:30:01          2.828427  FLASH         ...
#
#     speed_of_sound_m_s  temperature_c  positioning_ok  attitude_ok  depth_ok  \
# 15            1545.232         1.4506               1            1         1
# 22            1545.190         1.4460               1            1         1
# 27            1545.169         1.4447               1            1         1
# 35            1545.125         1.4327               1            1         1
# 37            1545.121         1.4321               1            1         1
# 47            1545.097         1.4326               1            1         1
# 66            1545.080         1.4324               1            1         1
# 68            1545.081         1.4333               1            1         1
# 83            1545.072         1.4323               1            1         1
# 94            1545.067         1.4315               1            1         1
#
#     altitude_ok   X            phototime  flag  \
# 15            1 NaN  2018-06-11 04:16:51     0
# 22            1 NaN  2018-06-11 04:18:01     0
# 27            0 NaN  2018-06-11 04:18:51     0
# 35            1 NaN  2018-06-11 04:20:11     0
# 37            1 NaN  2018-06-11 04:20:31     0
# 47            1 NaN  2018-06-11 04:22:11     0
# 66            1 NaN  2018-06-11 04:25:21     0
# 68            1 NaN  2018-06-11 04:25:41     0
# 83            1 NaN  2018-06-11 04:28:11     0
# 94            1 NaN  2018-06-11 04:30:01     0
#
#                                 point
# 15  POINT (-153.60531968 11.25163773)
# 22  POINT (-153.60530782 11.25162813)
# 27  POINT (-153.60527218 11.25163858)
# 35   POINT (-153.6052031 11.25162276)
# 37  POINT (-153.60518772 11.25162512)
# 47  POINT (-153.60511554 11.25165272)
# 66  POINT (-153.60491562 11.25157483)
# 68  POINT (-153.60489065 11.25155959)
# 83  POINT (-153.60468519 11.25150961)
# 94  POINT (-153.60450119 11.25151294)
#
# [10 rows x 37 columns]

# %%
# See a particular image
open_layer.images.show(index=5)

# %%
# See the first 5 lines of the metadata
open_layer.get_metadata().head(5)
# Out:
#     ID  Unnamed: 0_x                  filename  XResolution_x  YResolution_x  \
# 9    9           439  20180611T041551.000Z.JPG            300            300
# 26  26           456  20180611T041841.000Z.JPG            300            300
# 47  47           477  20180611T042211.000Z.JPG            300            300
# 50  50           480  20180611T042241.000Z.JPG            300            300
# 51  51           481  20180611T042251.000Z.JPG            300            300
#
#     ExposureTime  FNumber  ISO            datetime  MaxApertureValue  ...  \
# 9       0.016667        8  200 2018-06-11 04:15:51          2.828427  ...
# 26      0.016667        8  200 2018-06-11 04:18:41          2.828427  ...
# 47      0.016667        8  200 2018-06-11 04:22:11          2.828427  ...
# 50      0.016667        8  200 2018-06-11 04:22:41          2.828427  ...
# 51      0.016667        8  200 2018-06-11 04:22:51          2.828427  ...
#
#                  Make        Model   Software  Orientation  \
# 9   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 26  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 47  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 50  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 51  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
#
#                DateTime  YCbCrPositioning  YResolution_y  \
# 9   2018:06:11 04:15:51                 2          300.0
# 26  2018:06:11 04:18:41                 2          300.0
# 47  2018:06:11 04:22:11                 2          300.0
# 50  2018:06:11 04:22:41                 2          300.0
# 51  2018:06:11 04:22:51                 2          300.0
#
#                                             Copyright  XResolution_y  \
# 9                                                 ...          300.0
# 26                                                ...          300.0
# 47                                                ...          300.0
# 50                                                ...          300.0
# 51                                                ...          300.0
#
#                                   Artist
# 9
# 26
# 47
# 50
# 51
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Resample the images

# %% [markdown]
# The add a next step to your processing pipeline, you need to instantiate the ResampleLayer class and pass the OpenLayer class as an argument

# %%
# Set the parameters
parameters = {
    "name": "datetime",
    "mode": "datetime",
    "params": {"min": "2018-06-11 04:14:00", "max": "2018-06-11 04:20:00"},
}

# %%
# Instantiate the new class
resample = ResampleLayer(paidiverpy=open_layer, parameters=parameters)

# %%
# Run the process using the parameters provided
resample.run()

# %%
# See the output images
resample.images
# Out:
# Step: raw
# Image: [[82 81 81 ... 82 82 81]
#  [81 81 81 ... 81 81 82]
#  [81 81 81 ... 81 82 82]
#  ...
#  [79 80 81 ... 81 81 81]
#  [80 80 80 ... 81 81 80]
#  [80 80 80 ... 81 81 80]]
# Image: [[156 154 153 ... 133 133 133]
#  [154 153 153 ... 132 132 132]
#  [154 154 154 ... 129 131 132]
#  ...
#  [152 151 152 ... 111 112 111]
#  [152 152 151 ... 111 113 112]
#  [151 151 152 ... 110 112 112]]
# Image: [[198 198 198 ... 187 189 186]
#  [198 198 198 ... 186 188 186]
#  [198 194 195 ... 185 187 186]
#  ...
#  [212 212 212 ... 200 201 202]
#  [212 212 211 ... 203 203 203]
#  [210 212 211 ... 204 203 203]]
# Image: [[202 203 200 ... 189 189 187]
#  [201 203 202 ... 190 192 192]
#  [202 204 204 ... 190 192 195]
#  ...
#  [216 216 216 ... 203 205 206]
#  [216 216 217 ... 202 203 203]
#  [215 216 216 ... 202 204 205]]
# Image: [[199 199 199 ... 184 181 183]
#  [200 199 199 ... 181 180 183]
#  [201 202 201 ... 179 181 184]
#  ...
#  [215 215 215 ... 203 203 202]
#  [215 215 215 ... 204 204 202]
#  [214 215 214 ... 205 205 203]]
# Image: [[202 201 200 ... 195 192 190]
#  [200 202 201 ... 194 190 188]
#  [200 200 203 ... 194 192 191]
#  ...
#  [214 212 213 ... 208 207 207]
#  [215 213 214 ... 209 207 206]
#  [215 215 214 ... 208 207 205]]
# Image: [[197 196 196 ... 190 191 190]
#  [198 197 197 ... 191 191 190]
#  [197 197 195 ... 188 190 189]
#  ...
#  [215 213 214 ... 207 208 207]
#  [213 212 214 ... 207 208 207]
#  [212 212 214 ... 207 209 208]]
# Image: [[198 198 196 ... 193 191 192]
#  [199 199 199 ... 192 189 189]
#  [200 200 200 ... 192 190 190]
#  ...
#  [215 216 216 ... 213 216 215]
#  [214 214 216 ... 213 215 214]
#  [214 215 215 ... 214 213 212]]
# Image: [[195 195 196 ... 187 187 186]
#  [194 196 196 ... 187 188 187]
#  [194 195 196 ... 186 187 186]
#  ...
#  [216 214 215 ... 207 206 206]
#  [214 213 214 ... 204 205 204]
#  [214 212 213 ... 207 206 206]]
# Image: [[198 199 200 ... 187 189 188]
#  [197 198 199 ... 188 190 191]
#  [196 198 198 ... 188 191 192]
#  ...
#  [215 214 214 ... 202 204 204]
#  [214 212 213 ... 203 204 203]
#  [213 212 213 ... 203 204 205]]
# Step: sampling
# Image: [[82 81 81 ... 82 82 81]
#  [81 81 81 ... 81 81 82]
#  [81 81 81 ... 81 82 82]
#  ...
#  [79 80 81 ... 81 81 81]
#  [80 80 80 ... 81 81 80]
#  [80 80 80 ... 81 81 80]]
# Image: [[156 154 153 ... 133 133 133]
#  [154 153 153 ... 132 132 132]
#  [154 154 154 ... 129 131 132]
#  ...
#  [152 151 152 ... 111 112 111]
#  [152 152 151 ... 111 113 112]
#  [151 151 152 ... 110 112 112]]
