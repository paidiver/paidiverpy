# %% [markdown]
# ## Simple Processing

# %% [markdown]
# An example to proessing images without a proper pipeline

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.open_layer import OpenLayer
from paidiverpy.resample_layer import ResampleLayer

# %% [markdown]
# ### Open the images

# %% [markdown]
# The first step will be always the load images step

# %%
# Instantiate the class
open_layer = OpenLayer(config_file_path='../config_files/config_1.yaml')

# %%
# See the configuration file
open_layer.config
# Out:
# {
#     "general": {
#         "input_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen",
#         "output_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data",
#         "catalog_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/catalog/catalog_jen.csv",
#         "catalog_type": "CSV",
#         "append_data_to_catalog": "/mnt/code/code/noc/paidiver/paidiverpy/examples/catalog/scidata_20180610.csv",
#         "image_type": "JPG",
#         "sampling_mode": "fixed",
#         "sampling_limits": 30,
#         "convert_autoscale": true,
#         "convert_bits": 8,
#         "convert_to": "RGB",
#         "convert_channel_selector": -1,
#         "name": "raw",
#         "step_name": "Open"
#     },
#     "steps": []
# }

# %%
# Run the open layer process. It will open the images from the input path, and save then as a ImagesLayer
open_layer.run()
# Out:
# Processing Images: 100%|███████████████████████████████| 30/30 [00:14<00:00,  2.08it/s]

# %%
# See the images output
open_layer.images
# Out:
# Step: raw
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a111b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68d30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b3121a7a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68c40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68e50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69120>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68dc0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69030>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69180>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a692a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68fd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68580>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68f70>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68ee0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69060>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69600>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a690f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a684f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68c70>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69000>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a693f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68b20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69210>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a686d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68cd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69150>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a696f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a695a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a692d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69a20>

# %%
# See a particular image
open_layer.images.images[0][5].show()

# %%
# See the first 5 lines of the catalog
open_layer.get_catalog().head(5)
# Out:
#     ID  Unnamed: 0_x            filename  XResolution_x  YResolution_x  \
# 1    1           431  20180611041431.JPG            300            300
# 2    2           432  20180611041441.JPG            300            300
# 6    6           436  20180611041521.JPG            300            300
# 11  11           441  20180611041611.JPG            300            300
# 15  15           445  20180611041651.JPG            300            300
#
#     ExposureTime  FNumber  ISO            datetime  MaxApertureValue  ...  \
# 1       0.016667        8  200 2018-06-11 04:14:31          2.828427  ...
# 2       0.016667        8  200 2018-06-11 04:14:41          2.828427  ...
# 6       0.016667        8  200 2018-06-11 04:15:21          2.828427  ...
# 11      0.016667        8  200 2018-06-11 04:16:11          2.828427  ...
# 15      0.016667        8  200 2018-06-11 04:16:51          2.828427  ...
#
#                  Make        Model   Software  Orientation  \
# 1   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 2   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 6   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 11  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 15  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
#
#                DateTime  YCbCrPositioning  YResolution_y  \
# 1   2018:06:11 04:14:31                 2          300.0
# 2   2018:06:11 04:14:41                 2          300.0
# 6   2018:06:11 04:15:21                 2          300.0
# 11  2018:06:11 04:16:11                 2          300.0
# 15  2018:06:11 04:16:51                 2          300.0
#
#                                             Copyright  XResolution_y  \
# 1                                                 ...          300.0
# 2                                                 ...          300.0
# 6                                                 ...          300.0
# 11                                                ...          300.0
# 15                                                ...          300.0
#
#                                   Artist
# 1
# 2
# 6
# 11
# 15
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Resample the images

# %% [markdown]
# The add a next step to your processing pipeline, you need to instantiate the ResampleLayer class and pass the OpenLayer class as an argument

# %%
# Set the parameters
parameters = {
    'name': 'datetime',
    'mode': 'datetime',
    'limits': ['2018-06-11 04:14:00', '2018-06-11 04:20:00']
}

# %%
# Instantiate the new class
resample = ResampleLayer(paidiverpy=open_layer, parameters=parameters)

# %%
# Run the process using the parameters provided
resample.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-08-06 17:39:17 | Number of photos to be removed: 18

# %%
# See the output images
resample.images
# Out:
# Step: raw
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a111b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68d30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b3121a7a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68c40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68e50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69120>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68dc0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69030>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69180>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a692a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68fd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68580>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68f70>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68ee0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69060>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69600>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a690f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a684f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68c70>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69000>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a693f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68b20>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69210>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a686d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68cd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69150>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a696f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a695a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a692d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69a20>
# Step: trim_datetime
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a111b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68d30>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b3121a7a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68c40>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68e50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69120>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68dc0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69030>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a69180>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a692a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68fd0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x772b30a68580>
