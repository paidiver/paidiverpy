# %% [markdown]
# ## Simple Processing

# %% [markdown]
# An example to proessing images without a proper pipeline

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.open_layer import OpenLayer
from paidiverpy.sampling_layer import SamplingLayer
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Open the images

# %% [markdown]
# The first step will be always the load images step

# %%
# Instantiate the class
open_layer = OpenLayer(config_file_path="../config_files/config_simple.yml")

# %%
# See the configuration file
open_layer.config
# Out:
# {
#     "general": {
#         "name": "raw",
#         "step_name": "open",
#         "sample_data": "benthic_csv",
#         "input_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/images",
#         "output_path": "output",
#         "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/metadata_benthic_csv.csv",
#         "metadata_type": "CSV_FILE",
#         "image_open_args": "PNG",
#         "append_data_to_metadata": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/appended_metadata_benthic_csv.csv",
#         "n_jobs": 1,
#         "track_changes": true,
#         "rename": "datetime",
#         "sampling": [
#             {
#                 "name": "sampling",
#                 "step_name": "sampling",
#                 "test": false,
#                 "params": {
#                     "value": 0.1,
#                     "raise_error": false
#                 },
#                 "mode": "percent"
#             }
#         ],
#         "convert": [
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "test": false,
#                 "params": {
#                     "output_bits": 8,
#                     "raise_error": false
#                 },
#                 "mode": "bits"
#             },
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "test": false,
#                 "params": {
#                     "to": "gray",
#                     "channel_selector": 0,
#                     "raise_error": false
#                 },
#                 "mode": "to"
#             }
#         ]
#     },
#     "steps": []
# }

# %%
# Run the open layer process. It will open the images from the input path, and save then as a ImagesLayer
open_layer.run()
# Out:
# [########################################] | 100% Completed | 105.82 ms
# [{'ID': 433.0, 'filename': '2018-06-11T04:14:51', 'XResolution': 300.0, 'YResolution': 300.0, 'ExposureTime': 0.01666666667, 'FNumber': 8.0, 'ISO': 200.0, 'image-datetime': Timestamp('2018-06-11 04:14:51'), 'MaxApertureValue': 2.82842712474619, 'WhiteBalance': 'FLASH       ', 'FocusPosition': 17.0, 'FocusDistance': 0.298538261891796, 'Unnamed: 0': 427274, 'image-longitude': -153.60531313, 'image-latitude': 11.25170837, 'image-altitude-meters': 1.5, 'image-camera-roll-degrees': 0.841, 'image-camera-pitch-degrees': 2.262, 'heading_deg': 90.468, 'cog_deg': 232.125016348902, 'image-depth': 5203.724, 'sog_m_s': 0.0114017542509914, 'time_unix_seconds': 1528690491.06994, 'conductivity': 3.21395, 'depth_m.1': 5203.724, 'pressure_psi': 7688.26484345799, 'salinity': 34.7067, 'speed_of_sound_m_s': 1545.363, 'temperature_c': 1.4911, 'positioning_ok': 1, 'attitude_ok': 1, 'depth_ok': 1, 'altitude_ok': 1, 'X': nan, 'phototime': '2018-06-11 04:14:51', 'flag': 0, 'point': <POINT (-153.605 11.252)>}, {'ID': 442.0, 'filename': '2018-06-11T04:16:21', 'XResolution': 300.0, 'YResolution': 300.0, 'ExposureTime': 0.01666666667, 'FNumber': 8.0, 'ISO': 200.0, 'image-datetime': Timestamp('2018-06-11 04:16:21'), 'MaxApertureValue': 2.82842712474619, 'WhiteBalance': 'FLASH       ', 'FocusPosition': 17.0, 'FocusDistance': 0.298538261891796, 'Unnamed: 0': 428879, 'image-longitude': -153.60532147, 'image-latitude': 11.25164913, 'image-altitude-meters': 1.6, 'image-camera-roll-degrees': 0.432, 'image-camera-pitch-degrees': 1.34, 'heading_deg': 90.433, 'cog_deg': 335.556045219583, 'image-depth': 5203.703, 'sog_m_s': 0.0120830459735946, 'time_unix_seconds': 1528690581.04368, 'conductivity': 3.21398, 'depth_m.1': 5203.703, 'pressure_psi': 7688.234385533, 'salinity': 34.755, 'speed_of_sound_m_s': 1545.232, 'temperature_c': 1.4455, 'positioning_ok': 1, 'attitude_ok': 1, 'depth_ok': 1, 'altitude_ok': 1, 'X': nan, 'phototime': '2018-06-11 04:16:21', 'flag': 0, 'point': <POINT (-153.605 11.252)>}, {'ID': 449.0, 'filename': '2018-06-11T04:17:31', 'XResolution': 300.0, 'YResolution': 300.0, 'ExposureTime': 0.01666666667, 'FNumber': 8.0, 'ISO': 200.0, 'image-datetime': Timestamp('2018-06-11 04:17:31'), 'MaxApertureValue': 2.82842712474619, 'WhiteBalance': 'FLASH       ', 'FocusPosition': 17.0, 'FocusDistance': 0.298538261891796, 'Unnamed: 0': 430128, 'image-longitude': -153.60531831, 'image-latitude': 11.25162916, 'image-altitude-meters': 1.6, 'image-camera-roll-degrees': 0.533, 'image-camera-pitch-degrees': 0.609, 'heading_deg': 91.017, 'cog_deg': 41.9872124958167, 'image-depth': 5203.724, 'sog_m_s': 0.0403608721412211, 'time_unix_seconds': 1528690651.05024, 'conductivity': 3.21197, 'depth_m.1': 5203.724, 'pressure_psi': 7688.26484345799, 'salinity': 34.7283, 'speed_of_sound_m_s': 1545.206, 'temperature_c': 1.4478, 'positioning_ok': 1, 'attitude_ok': 1, 'depth_ok': 1, 'altitude_ok': 1, 'X': nan, 'phototime': '2018-06-11 04:17:31', 'flag': 0, 'point': <POINT (-153.605 11.252)>}, {'ID': 460.0, 'filename': '2018-06-11T04:19:21', 'XResolution': 300.0, 'YResolution': 300.0, 'ExposureTime': 0.01666666667, 'FNumber': 8.0, 'ISO': 200.0, 'image-datetime': Timestamp('2018-06-11 04:19:21'), 'MaxApertureValue': 2.82842712474619, 'WhiteBalance': 'FLASH       ', 'FocusPosition': 17.0, 'FocusDistance': 0.298538261891796, 'Unnamed: 0': 432093, 'image-longitude': -153.60524786, 'image-latitude': 11.25163778, 'image-altitude-meters': 1.5, 'image-camera-roll-degrees': 0.555, 'image-camera-pitch-degrees': 1.093, 'heading_deg': 90.342, 'cog_deg': 81.3628685849293, 'image-depth': 5203.735, 'sog_m_s': 0.0799061950038919, 'time_unix_seconds': 1528690761.05847, 'conductivity': 3.20991, 'depth_m.1': 5203.735, 'pressure_psi': 7688.28224798655, 'salinity': 34.6958, 'speed_of_sound_m_s': 1545.194, 'temperature_c': 1.4549, 'positioning_ok': 1, 'attitude_ok': 1, 'depth_ok': 1, 'altitude_ok': 1, 'X': nan, 'phototime': '2018-06-11 04:19:21', 'flag': 0, 'point': <POINT (-153.605 11.252)>}, {'ID': 472. ...
# WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8
# WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8
# WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8
# WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8
# WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8
# WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8

# %%
# See the images output
open_layer.images
# Out:
# Step: raw
# Image: i
# Image: m
# Image: a
# Image: g
# Image: e
# Image: s
# Image: _
# Image: 0

# %%
open_layer.get_metadata()
# Out:
# <xarray.DataArray 'metadata' (filename: 5)> Size: 40B
# array([{'ID': 433.0, 'filename': '2018-06-11T04:14:51', 'XResolution': 300.0, 'YResolution': 300.0, 'ExposureTime': 0.01666666667, 'FNumber': 8.0, 'ISO': 200.0, 'image-datetime': Timestamp('2018-06-11 04:14:51'), 'MaxApertureValue': 2.82842712474619, 'WhiteBalance': 'FLASH       ', 'FocusPosition': 17.0, 'FocusDistance': 0.298538261891796, 'Unnamed: 0': 427274, 'image-longitude': -153.60531313, 'image-latitude': 11.25170837, 'image-altitude-meters': 1.5, 'image-camera-roll-degrees': 0.841, 'image-camera-pitch-degrees': 2.262, 'heading_deg': 90.468, 'cog_deg': 232.125016348902, 'image-depth': 5203.724, 'sog_m_s': 0.0114017542509914, 'time_unix_seconds': 1528690491.06994, 'conductivity': 3.21395, 'depth_m.1': 5203.724, 'pressure_psi': 7688.26484345799, 'salinity': 34.7067, 'speed_of_sound_m_s': 1545.363, 'temperature_c': 1.4911, 'positioning_ok': 1, 'attitude_ok': 1, 'depth_ok': 1, 'altitude_ok': 1, 'X': nan, 'phototime': '2018-06-11 04:14:51', 'flag': 0, 'point': <POINT (-153.605 11.252)>},
#        {'ID': 442.0, 'filename': '2018-06-11T04:16:21', 'XResolution': 300.0, 'YResolution': 300.0, 'ExposureTime': 0.01666666667, 'FNumber': 8.0, 'ISO': 200.0, 'image-datetime': Timestamp('2018-06-11 04:16:21'), 'MaxApertureValue': 2.82842712474619, 'WhiteBalance': 'FLASH       ', 'FocusPosition': 17.0, 'FocusDistance': 0.298538261891796, 'Unnamed: 0': 428879, 'image-longitude': -153.60532147, 'image-latitude': 11.25164913, 'image-altitude-meters': 1.6, 'image-camera-roll-degrees': 0.432, 'image-camera-pitch-degrees': 1.34, 'heading_deg': 90.433, 'cog_deg': 335.556045219583, 'image-depth': 5203.703, 'sog_m_s': 0.0120830459735946, 'time_unix_seconds': 1528690581.04368, 'conductivity': 3.21398, 'depth_m.1': 5203.703, 'pressure_psi': 7688.234385533, 'salinity': 34.755, 'speed_of_sound_m_s': 1545.232, 'temperature_c': 1.4455, 'positioning_ok': 1, 'attitude_ok': 1, 'depth_ok': 1, 'altitude_ok': 1, 'X': nan, 'phototime': '2018-06-11 04:16:21', 'flag': 0, 'point': <POINT (-153.605 11.252)>},
#        {'ID': 449.0, 'filename': '2018-06-11T04:17:31', 'XResolution': 300.0, 'YResolution': 300.0, 'ExposureTime': 0.01666666667, 'FNumber': 8.0, 'ISO': 200.0, 'image-datetime': Timestamp('2018-06-11 04:17:31'), 'MaxApertureValue': 2.82842712474619, 'WhiteBalance': 'FLASH       ', 'FocusPosition': 17.0, 'FocusDistance': 0.298538261891796, 'Unnamed: 0': 430128, 'image-longitude': -153.60531831, 'image-latitude': 11.25162916, 'image-altitude-meters': 1.6, 'image-camera-roll-degrees': 0.533, 'image-camera-pitch-degrees': 0.609, 'heading_deg': 91.017, 'cog_deg': 41.9872124958167, 'image-depth': 5203.724, 'sog_m_s': 0.0403608721412211, 'time_unix_seconds': 1528690651.05024, 'conductivity': 3.21197, 'depth_m.1': 5203.724, 'pressure_psi': 7688.26484345799, 'salinity': 34.7283, 'speed_of_sound_m_s': 1545.206, 'temperature_c': 1.4478, 'positioning_ok': 1, 'attitude_ok': 1, 'depth_ok': 1, 'altitude_ok': 1, 'X': nan, 'phototime': '2018-06-11 04:17:31', 'flag': 0, 'point': <POINT (-153.605 11.252)>},
#        {'ID': 460.0, 'filename': '2018-06-11T04:19:21', 'XResolution': 300.0, 'YResolution': 300.0, 'ExposureTime': 0.01666666667, 'FNumber': 8.0, 'ISO': 200.0, 'image-datetime': Timestamp('2018-06-11 04:19:21'), 'MaxApertureValue': 2.82842712474619, 'WhiteBalance': 'FLASH       ', 'FocusPosition': 17.0, 'FocusDistance': 0.298538261891796, 'Unnamed: 0': 432093, 'image-longitude': -153.60524786, 'image-latitude': 11.25163778, 'image-altitude-meters': 1.5, 'image-camera-roll-degrees': 0.555, 'image-camera-pitch-degrees': 1.093, 'heading_deg': 90.342, 'cog_deg': 81.3628685849293, 'image-depth': 5203.735, 'sog_m_s': 0.0799061950038919, 'time_unix_seconds': 1528690761.05847, 'conductivity': 3.20991, 'depth_m.1': 5203.735, 'pressure_psi': 7688.28224798655, 'salinity': 34.6958, 'speed_of_sound_m_s': 1545.194, 'temperature_c': 1.4549, 'positioning_ok': 1, 'attitude_ok': 1, 'depth_ok': 1, 'altitude_ok': 1, 'X': nan, 'phototime': '2018-06-11 04:19:21', 'flag': 0, 'point': <POINT (-153.605 11.252)>},
#        {'ID': 472.0, 'filename': '2018-06-11T04:21:21', 'XResolution': 300.0, 'YResolution': 300.0, 'ExposureTime': 0.01666666667, 'FNumber': 8.0, 'ISO': 200.0, 'image-datetime': Timestamp('2018-06-11 04:21:21'), 'MaxApertureValue': 2.82842712474619, 'WhiteBalance': 'FLASH       ', 'FocusPosition': 17.0, 'FocusDistance': 0.298538261891796, 'Unnamed: 0': 434235, 'image-longitude': -153.6051516, 'image-latitude': 11.25164437, 'image-altitude-meters': 1.9, 'image-camera-roll-degrees': -1.375, 'image-camera-pitch-degrees': -4.386, 'heading_deg': 98.787, 'cog_deg': 64.1601731219813, 'image-depth': 5203.182, 'sog_m_s': 0.176663521984591, 'time_unix_seconds': 1528690881.02357, 'conductivity': 3.20891, 'depth_m.1': 5203.182, 'pressure_psi': 7687.45408250252, 'salinity': 34.7047, 'speed_of_sound_m_s': 1545.111, 'temperature_c': 1.435, 'positioning_ok': 1, 'attitude_ok': 1, 'depth_ok': 1, 'altitude_ok': 1, 'X': nan, 'phototime': '2018-06-11 04:21:21', 'flag': 0, 'point': <POINT (-153.605 11.252)>}],
#       dtype=object)
# Coordinates:
#   * filename         (filename) <U19 380B '2018-06-11T04:14:51' ... '2018-06-...
#     metadata         (filename) object 40B {'ID': 433.0, 'filename': '2018-06...
#     original_height  (filename) int64 40B 128 128 128 128 128
#     original_width   (filename) int64 40B 128 128 128 128 128
#     flag             (filename) int64 40B 0 0 0 0 0

# %%
# See a particular image
open_layer.images.show(image_number=2)
# Out:
# <div><svg style="position: absolute; width: 0; height: 0; overflow: hidden">
# <defs>
# <symbol id="arrow-right" viewBox="0 0 330 330">
#   <path id="XMLID_222_" d="M250.606,154.389l-150-149.996c-5.857-5.858-15.355-5.858-21.213,0.001
# 	c-5.857,5.858-5.857,15.355,0.001,21.213l139.393,139.39L79.393,304.394c-5.857,5.858-5.857,15.355,0.001,21.213
# 	C82.322,328.536,86.161,330,90,330s7.678-1.464,10.607-4.394l149.999-150.004c2.814-2.813,4.394-6.628,4.394-10.606
# 	C255,161.018,253.42,157.202,250.606,154.389z"/>
# </defs>
# </svg>
# <style>/* CSS stylesheet for displaying Paidiverpy objects in jupyterlab.
#  *
#  */
#
# :root {
#   --ppy-font-color: var(--jp-content-font-color, rgba(0, 0, 0, 1));
#   --ppy-font-color-brown: var(--jp-content-font-color-brown, brown);
#   --ppy-font-color-olive: var(--jp-content-font-color-olive, olive);
#   --ppy-font-color-teal: var(--jp-content-font-color-teal, teal);
#   --ppy-font-color-blue: var(--jp-content-font-color-blue, blue);
#   --ppy-font-color-gray: var(--jp-content-font-color-gray, gray);
#   --ppy-border-color: var(--jp-border-color2, #e0e0e0);
#   --ppy-disabled-color: var(--jp-layout-color3, #bdbdbd);
#   --ppy-background-color: var(--jp-layout-color, white);
#   --ppy-background-color2: var(--jp-layout-color3, rgba(212, 212, 212, 0.15));
# }
#
#
# html[theme="dark"],
# html[data-theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --ppy-font-color: rgba(255, 255, 255, 1);
#   --ppy-font-color-brown: brown;
#   --ppy-font-color-olive: olive;
#   --ppy-font-color-teal: teal;
#   --ppy-font-color-blue: blue;
#   --ppy-font-color-gray: gray;
#   --ppy-border-color: #1f1f1f;
#   --ppy-disabled-color: #515151;
#   --ppy-background-color: #111111;
# }
#
# .ppy-background-color {
#   background-color: var(--ppy-background-color) !important;
# }
#
# .ppy-font-color-brown {
#   color: var(--ppy-font-color-brown) !important;
# }
#
# .ppy-font-color {
#   color: var(--ppy-font-color) !important;
# }
# .ppy-h2 {
#   font-size: 20px !important;
# }
# .ppy-h3 {
#   font-size: 13px !important;
# }
# .ppy-p {
#   font-size: 10px;
# }
# .ppy-p-error {
#   color: var(--ppy-font-color-brown);
#   font-weight: bold;
#   display: block;
# }
#
# .ppy-text-repr-fallback {
#   /* fallback to plain text repr when CSS is not injected (untrusted notebook) */
#   display: none;
# }
#
# .ppy-pipeline-wrap{
#   display: flex;
#   flex-wrap: wrap;
#   align-items: center;
# }
#
# .ppy-pipeline {
#   float:left;
#   cursor: pointer;
#   padding: 10px;
#   width: max-content;
#   height: 150px;
#   margin: 10px;
#   border: 1px solid #000;
#   text-align: center;
#   /* line-height: 80px; */
# }
#
# .ppy-pipeline-clear-fix {
#   clear: both;
# }
#
# .ppy-pipeline-parameters-all {
#   padding: 10px;
#   margin: 10px;
# }
#
# .ppy-images-step-header {
#   cursor: pointer;
#   font-weight: bold;
#   margin-top: 10px;
#   margin-bottom: 5px;
# }
# .ppy-images-metadata {
#   margin-left: 20px;
#   margin-bottom: 10px;
# }
# .ppy-images {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 10px;
#   margin-left: 20px;
# }
#
# .ppy-show-more-button, .ppy-hide-button {
#   margin-left: 20px;
#   background-color: #007bff;
#   color: white;
#   border: none;
#   padding: 5px 10px;
#   cursor: pointer;
# }
#
#
# .ppy-pipeline-arrow {
#   float:left;
#   width: 50px;
#   height: 80px;
#   margin: 10px;
#   text-align: center;
#   line-height: 80px;
# }
#
# .ppy-images-img{
#   display: block;
#   max-width: 200px;
#   margin: 10px;
# }
#
# .ppy-images-toggle-arrow {
#   cursor: pointer;
#   margin-left: 5px;
# }
#
# .ppy-images-image-p {
#   cursor: pointer;
# }
#
# .ppy-arrow-right {
#   display: inline-block;
#   vertical-align: middle;
#   width: 1em;
#   height: 1.5em !important;
#   stroke-width: 0;
#   stroke: currentColor;
#   fill: currentColor;
# }
#
#
# .ppy-json-block {
#   font-family: monospace;
#   background: var(--ppy-background-color);
#   padding: 1em;
#   border-radius: 6px;
# }
# .ppy-json-key {
#   color: var(--ppy-font-color-brown);
# }
# .ppy-json-string {
#   color: var(--ppy-font-color-olive);
# }
# .ppy-json-number {
#   color: var(--ppy-font-color-teal);
# }
# .ppy-json-bool {
#   color: var(--ppy-font-color-blue);
# }
# .ppy-json-null {
#   color: var(--ppy-font-color-gray);
# }
#
#
# .ppy-pn-title-0 {
#   font-size: 30px;
# }
#
# .ppy-pn-title-1 {
#   font-size: 20px;
# }
# .ppy-pn-title-2 {
#   font-size: 17px;
# }
# .ppy-pn-title-3 {
#   font-size: 14px;
# }
# .ppy-pn-title-4 {
#   font-size: 12px;
# }
#
# .ppy-pn-bold {
#   font-weight: bold;
# }
# .ppy-pn-italic {
#   font-style: italic;
# }
# .ppy-pn-description {
#   font-size: 14px;
#   margin-bottom: 1px;
# }
#
# .bk-root {
#   width: 100% !important;
#   max-width: 100% !important;
#   box-sizing: border-box;
# }
#
# input, .bk-input, .bk-input-group {
#   margin-top: 0px;
#   margin-bottom: 3px;
#   padding-top: 0px;
#   padding-bottom: 0px;
# }
#
# .ppy-pn-header-button .bk-btn {
#   background: none !important;
#   border: none !important;
#   font-weight: bold;
#   font-size: 16px;
#   text-align: left;
#   padding-left: 0;
#   cursor: pointer;
#   box-shadow: none !important;
#   color: black;
# }
#
# .ppy-pn-danger-modal{
#   border: 2px solid red;
#   border-radius: 10px;
#   box-shadow: 0px 0px 10px rgba(255, 0, 0, 0.5);
# }
#
# .ppy-pn-config-form{
#   padding: 10px;
#   margin-top: 10px;
#   margin-bottom: 10px;
#   background-color: var(--ppy-background-color2);
#   border-radius: 5px;
#   box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);
# }
#
#
# .ppy-pn-align-right {
#   display: flex;
#   justify-content: flex-end;
# }
# </style><script>function toggleMetadata(stepIndex, randomId) {
#   var metadata = document.getElementById("ppy-images-metadata-" + randomId + "-" + stepIndex);
#   var arrow = document.getElementById("ppy-images-arrow-" + randomId + "-" + stepIndex);
#   if (metadata.style.display === "none") {
#       metadata.style.display = "block";
#       arrow.innerHTML = "▼";
#       arrow.classList.remove("ppy-font-color");
#       arrow.classList.add("ppy-font-color-brown");
#   } else {
#       metadata.style.display = "none";
#       arrow.innerHTML = "►";
#       arrow.classList.remove("ppy-font-color-brown");
#       arrow.classList.add("ppy-font-color");
#   }
# }
# function toggleImage(imageId, randomId) {
#   var img = document.getElementById(imageId);
#   var arrow = document.getElementById("ppy-images-arrow-" + randomId + "-" + imageId);
#   if (img.style.display === "none") {
#       img.style.display = "block";
#       arrow.innerHTML = "▼";
#       arrow.classList.remove("ppy-font-color");
#       arrow.classList.add("ppy-font-color-brown");
#   } else {
#       img.style.display = "none";
#       arrow.innerHTML = "►";
#       arrow.classList.remove("ppy-font-color-brown");
#       arrow.classList.add("ppy-font-color");
#   }
# }
# function showMore(stepIndex) {
#   var moreImages = document.getElementById("ppy-more-images-" + stepIndex);
#   var showMoreButton = document.getElementById("ppy-show-more-button-" + stepIndex);
#   var hideButton = document.getElementById("ppy-hide-button-" + stepIndex);
#   moreImages.style.display = "flex";
#   showMoreButton.style.display = "none";
#   hideButton.style.display = "inline-block";
# }
# function hide(stepIndex) {
#   var moreImages = document.getElementById("ppy-more-images-" + stepIndex);
#   var showMoreButton = document.getElementById("ppy-show-more-button-" + stepIndex);
#   var hideButton = document.getElementById("ppy-hide-button-" + stepIndex);
#   moreImages.style.display = "none";
#   showMoreButton.style.display = "inline-block";
#   hideButton.style.display = "none";
# }
#
#
# function showParameters(id, randomId) {
#   var currentTarget = document.getElementById('ppy-pipeline-' + randomId + '-' + id);
#   var square = document.getElementsByClassName('ppy-pipeline-' + randomId);
#   var allParams = document.getElementsByClassName('ppy-pipeline-parameters-' + randomId);
#   var selectedParams = document.getElementById('ppy-pipeline-parameters-' + randomId + '-' + id);
#   var idWasVisible = false;
#   if (selectedParams) {
#       var idWasVisible = selectedParams.style.display === 'block';
#   }
#   for (var i = 0; i < square.length; i++) {
#       square[i].classList.remove('ppy-font-color-brown');
#       square[i].classList.add('ppy-font-color');
#   }
#   for (var i = 0; i < allParams.length; i++) {
#       allParams[i].style.display = 'none';
#   }
#   // Show the selected parameter section
#   if (selectedParams) {
#       if (idWasVisible) {
#           sele

# %%
# See the first 5 lines of the metadata
open_layer.get_metadata(output_format="pandas").head(5)
# Out:
#       ID             filename  XResolution  YResolution  ExposureTime  \
# 0  433.0  2018-06-11T04:14:51        300.0        300.0      0.016667
# 1  442.0  2018-06-11T04:16:21        300.0        300.0      0.016667
# 2  449.0  2018-06-11T04:17:31        300.0        300.0      0.016667
# 3  460.0  2018-06-11T04:19:21        300.0        300.0      0.016667
# 4  472.0  2018-06-11T04:21:21        300.0        300.0      0.016667
#
#    FNumber    ISO      image-datetime  MaxApertureValue  WhiteBalance  ...  \
# 0      8.0  200.0 2018-06-11 04:14:51          2.828427  FLASH         ...
# 1      8.0  200.0 2018-06-11 04:16:21          2.828427  FLASH         ...
# 2      8.0  200.0 2018-06-11 04:17:31          2.828427  FLASH         ...
# 3      8.0  200.0 2018-06-11 04:19:21          2.828427  FLASH         ...
# 4      8.0  200.0 2018-06-11 04:21:21          2.828427  FLASH         ...
#
#    speed_of_sound_m_s  temperature_c  positioning_ok  attitude_ok  depth_ok  \
# 0            1545.363         1.4911               1            1         1
# 1            1545.232         1.4455               1            1         1
# 2            1545.206         1.4478               1            1         1
# 3            1545.194         1.4549               1            1         1
# 4            1545.111         1.4350               1            1         1
#
#    altitude_ok   X            phototime  flag  \
# 0            1 NaN  2018-06-11 04:14:51     0
# 1            1 NaN  2018-06-11 04:16:21     0
# 2            1 NaN  2018-06-11 04:17:31     0
# 3            1 NaN  2018-06-11 04:19:21     0
# 4            1 NaN  2018-06-11 04:21:21     0
#
#                                point
# 0  POINT (-153.60531313 11.25170837)
# 1  POINT (-153.60532147 11.25164913)
# 2  POINT (-153.60531831 11.25162916)
# 3  POINT (-153.60524786 11.25163778)
# 4   POINT (-153.6051516 11.25164437)
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Resample the images

# %% [markdown]
# The add a next step to your processing pipeline, you need to instantiate the SamplingLayer class and pass the OpenLayer class as an argument

# %%
# Set the parameters
parameters = {
    "name": "datetime",
    "mode": "datetime",
    "params": {"min": "2018-06-11 04:14:00", "max": "2018-06-11 04:20:00"},
}

# %%
# Instantiate the new class
resample = SamplingLayer(paidiverpy=open_layer, parameters=parameters)

# %%
# Run the process using the parameters provided
resample.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-08-26 19:04:37 | Number of images to be removed: 1. Total number of images: 5
# INFO:paidiverpy:Number of images to be removed: 1. Total number of images: 5

# %%
# See the output images
resample.images
# Out:
# Step: raw
# Image: i
# Image: m
# Image: a
# Image: g
# Image: e
# Image: s
# Image: _
# Image: 0
# Step: sampling
# Image: i
# Image: m
# Image: a
# Image: g
# Image: e
# Image: s
# Image: _
# Image: 1
