# %% [markdown]
# ## Simple Processing

# %% [markdown]
# An example to proessing images without a proper pipeline

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.open_layer import OpenLayer
from paidiverpy.resample_layer import ResampleLayer

# %% [markdown]
# ### Open the images

# %% [markdown]
# The first step will be always the load images step

# %%
# Instantiate the class
open_layer = OpenLayer(config_file_path='../config_files/config_1.yaml')

# %%
# See the configuration file
open_layer.config
# Out:
# {
#     "general": {
#         "input_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen",
#         "output_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data",
#         "catalog_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/catalog/catalog_jen.csv",
#         "catalog_type": "CSV",
#         "append_data_to_catalog": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen/waypoints/scidata_20180610.csv",
#         "image_type": "JPG",
#         "sampling": [
#             {
#                 "mode": "percent",
#                 "params": {
#                     "value": 0.1
#                 }
#             }
#         ],
#         "convert": [
#             {
#                 "mode": "bits",
#                 "params": {
#                     "autoscale": true
#                 }
#             },
#             {
#                 "mode": "to",
#                 "params": {
#                     "to": "RGB",
#                     "channel_selector": -1
#                 }
#             }
#         ],
#         "name": "raw",
#         "step_name": "Open"
#     },
#     "steps": []
# }

# %%
# Run the open layer process. It will open the images from the input path, and save then as a ImagesLayer
open_layer.run()
# Out:
# Processing Images: 100%|█████████████████████████| 10/10 [00:02<00:00,  4.84it/s]
# Processing Images: 100%|█████████████████████████| 10/10 [00:02<00:00,  3.62it/s]
# Processing Images: 100%|███████████████████████| 10/10 [00:00<00:00, 1365.73it/s]

# %%
# See the images output
open_layer.images
# Out:
# Step: raw
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda6110>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda60e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda5c90>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda53f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda4a00>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda4940>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda5330>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda50c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda5030>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda4a60>

# %%
# See a particular image
open_layer.images.images[0][5].show()

# %%
# See the first 5 lines of the catalog
open_layer.get_catalog().head(5)
# Out:
#     ID  Unnamed: 0_x            filename  XResolution_x  YResolution_x  \
# 9    9           439  20180611041551.JPG            300            300
# 10  10           440  20180611041601.JPG            300            300
# 13  13           443  20180611041631.JPG            300            300
# 17  17           447  20180611041711.JPG            300            300
# 54  54           484  20180611042321.JPG            300            300
#
#     ExposureTime  FNumber  ISO            datetime  MaxApertureValue  ...  \
# 9       0.016667        8  200 2018-06-11 04:15:51          2.828427  ...
# 10      0.016667        8  200 2018-06-11 04:16:01          2.828427  ...
# 13      0.016667        8  200 2018-06-11 04:16:31          2.828427  ...
# 17      0.016667        8  200 2018-06-11 04:17:11          2.828427  ...
# 54      0.016667        8  200 2018-06-11 04:23:21          2.828427  ...
#
#                  Make        Model   Software  Orientation  \
# 9   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 10  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 13  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 17  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 54  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
#
#                DateTime  YCbCrPositioning  YResolution_y  \
# 9   2018:06:11 04:15:51                 2          300.0
# 10  2018:06:11 04:16:01                 2          300.0
# 13  2018:06:11 04:16:31                 2          300.0
# 17  2018:06:11 04:17:11                 2          300.0
# 54  2018:06:11 04:23:21                 2          300.0
#
#                                             Copyright  XResolution_y  \
# 9                                                 ...          300.0
# 10                                                ...          300.0
# 13                                                ...          300.0
# 17                                                ...          300.0
# 54                                                ...          300.0
#
#                                   Artist
# 9
# 10
# 13
# 17
# 54
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Resample the images

# %% [markdown]
# The add a next step to your processing pipeline, you need to instantiate the ResampleLayer class and pass the OpenLayer class as an argument

# %%
# Set the parameters
parameters = {
    'name': 'datetime',
    'mode': 'datetime',
    'params': {
        'min': '2018-06-11 04:14:00',
        'max': '2018-06-11 04:20:00'
    }
}

# %%
# Instantiate the new class
resample = ResampleLayer(paidiverpy=open_layer, parameters=parameters)

# %%
# Run the process using the parameters provided
resample.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 18:06:11 | Number of photos to be removed: 6

# %%
# See the output images
resample.images
# Out:
# Step: raw
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda6110>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda60e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda5c90>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda53f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda4a00>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda4940>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda5330>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda50c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda5030>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda4a60>
# Step: trim_datetime
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda6110>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda60e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda5c90>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7522fdda53f0>
