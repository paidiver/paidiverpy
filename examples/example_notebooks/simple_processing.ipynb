# %% [markdown]
# ## Simple Processing

# %% [markdown]
# An example to proessing images without a proper pipeline

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.open_layer import OpenLayer
from paidiverpy.resample_layer import ResampleLayer

# %% [markdown]
# ### Open the images

# %% [markdown]
# The first step will be always the load images step

# %%
# Instantiate the class
open_layer = OpenLayer(config_file_path='../config_files/config_1.yaml')

# %%
# See the configuration file
open_layer.config
# Out:
# {
#     "general": {
#         "name": "raw",
#         "step_name": "open",
#         "input_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen",
#         "output_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data",
#         "n_jobs": 1,
#         "metadata_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/metadata/metadata_benthic.csv",
#         "metadata_type": "CSV_FILE",
#         "append_data_to_metadata": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen/waypoints/scidata_20180610.csv",
#         "image_type": "JPG",
#         "rename": "datetime",
#         "sampling": [
#             {
#                 "name": "sampling",
#                 "step_name": "sampling",
#                 "mode": "percent",
#                 "test": false,
#                 "params": {
#                     "value": 0.1
#                 }
#             }
#         ],
#         "convert": [
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "mode": "bits",
#                 "test": false,
#                 "params": {
#                     "output_bits": 8
#                 }
#             },
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "mode": "to",
#                 "test": false,
#                 "params": {
#                     "to": "gray",
#                     "channel_selector": 0
#                 }
#             }
#         ]
#     },
#     "steps": []
# }

# %%
# Run the open layer process. It will open the images from the input path, and save then as a ImagesLayer
open_layer.run()
# Out:
# Open Images: 100%|█████████████████████████████████████| 10/10 [00:01<00:00,  5.24it/s]

# %%
# See the images output
open_layer.images
# Out:
# Step: raw
# Image: [[92 92 93 ... 91 92 91]
#  [94 93 93 ... 91 92 92]
#  [94 93 93 ... 91 89 90]
#  ...
#  [84 84 83 ... 85 85 82]
#  [84 84 85 ... 85 85 84]
#  [84 83 84 ... 87 85 84]]
# Image: [[156 154 153 ... 133 133 133]
#  [154 153 153 ... 132 132 132]
#  [154 154 154 ... 129 131 132]
#  ...
#  [152 151 152 ... 111 112 111]
#  [152 152 151 ... 111 113 112]
#  [151 151 152 ... 110 112 112]]
# Image: [[204 203 203 ... 197 197 197]
#  [203 204 204 ... 198 200 199]
#  [202 205 206 ... 199 201 200]
#  ...
#  [217 219 217 ... 209 211 211]
#  [218 219 217 ... 207 210 211]
#  [217 217 217 ... 206 208 209]]
# Image: [[199 199 199 ... 184 181 183]
#  [200 199 199 ... 181 180 183]
#  [201 202 201 ... 179 181 184]
#  ...
#  [215 215 215 ... 203 203 202]
#  [215 215 215 ... 204 204 202]
#  [214 215 214 ... 205 205 203]]
# Image: [[196 195 198 ... 190 192 193]
#  [195 196 198 ... 190 191 193]
#  [197 198 198 ... 191 192 193]
#  ...
#  [215 213 213 ... 203 204 205]
#  [214 213 212 ... 205 205 205]
#  [211 212 213 ... 206 205 204]]
# Image: [[194 193 196 ... 189 189 187]
#  [197 196 197 ... 187 188 188]
#  [199 198 198 ... 187 187 187]
#  ...
#  [214 212 212 ... 202 203 203]
#  [216 215 212 ... 200 202 201]
#  [216 217 214 ... 200 201 201]]
# Image: [[198 196 197 ... 193 193 192]
#  [196 198 199 ... 193 192 194]
#  [197 200 200 ... 192 191 193]
#  ...
#  [216 216 217 ... 205 205 204]
#  [218 219 220 ... 205 205 206]
#  [217 219 219 ... 205 207 209]]
# Image: [[198 197 195 ... 188 188 186]
#  [196 194 194 ... 187 188 188]
#  [196 193 195 ... 188 188 187]
#  ...
#  [216 216 215 ... 203 204 204]
#  [216 216 215 ... 205 203 203]
#  [216 215 215 ... 206 204 203]]
# Image: [[200 200 198 ... 194 196 195]
#  [198 199 200 ... 195 198 197]
#  [199 201 201 ... 196 196 195]
#  ...
#  [215 216 217 ... 202 201 201]
#  [218 219 217 ... 202 201 201]
#  [218 219 216 ... 204 202 202]]
# Image: [[203 202 202 ... 195 193 190]
#  [201 203 202 ... 191 189 187]
#  [203 204 201 ... 188 186 186]
#  ...
#  [216 216 216 ... 201 202 203]
#  [215 215 217 ... 203 203 204]
#  [215 216 215 ... 202 206 206]]

# %%
open_layer.get_metadata()
# Out:
#     ID  Unnamed: 0_x            filename  XResolution_x  YResolution_x  \
# 4    4           434  20180611041501.JPG            300            300
# 8    8           438  20180611041541.JPG            300            300
# 11  11           441  20180611041611.JPG            300            300
# 26  26           456  20180611041841.JPG            300            300
# 32  32           462  20180611041941.JPG            300            300
# 64  64           494  20180611042501.JPG            300            300
# 72  72           502  20180611042621.JPG            300            300
# 73  73           503  20180611042631.JPG            300            300
# 90  90           520  20180611042921.JPG            300            300
# 93  93           523  20180611042951.JPG            300            300
#
#     ExposureTime  FNumber  ISO            datetime  MaxApertureValue  ...  \
# 4       0.016667        8  200 2018-06-11 04:15:01          2.828427  ...
# 8       0.016667        8  200 2018-06-11 04:15:41          2.828427  ...
# 11      0.016667        8  200 2018-06-11 04:16:11          2.828427  ...
# 26      0.016667        8  200 2018-06-11 04:18:41          2.828427  ...
# 32      0.016667        8  200 2018-06-11 04:19:41          2.828427  ...
# 64      0.016667        8  200 2018-06-11 04:25:01          2.828427  ...
# 72      0.016667        8  200 2018-06-11 04:26:21          2.828427  ...
# 73      0.016667        8  200 2018-06-11 04:26:31          2.828427  ...
# 90      0.016667        8  200 2018-06-11 04:29:21          2.828427  ...
# 93      0.016667        8  200 2018-06-11 04:29:51          2.828427  ...
#
#                  Make        Model   Software  Orientation  \
# 4   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 8   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 11  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 26  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 32  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 64  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 72  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 73  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 90  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 93  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
#
#                DateTime  YCbCrPositioning  YResolution_y  \
# 4   2018:06:11 04:15:01                 2          300.0
# 8   2018:06:11 04:15:41                 2          300.0
# 11  2018:06:11 04:16:11                 2          300.0
# 26  2018:06:11 04:18:41                 2          300.0
# 32  2018:06:11 04:19:41                 2          300.0
# 64  2018:06:11 04:25:01                 2          300.0
# 72  2018:06:11 04:26:21                 2          300.0
# 73  2018:06:11 04:26:31                 2          300.0
# 90  2018:06:11 04:29:21                 2          300.0
# 93  2018:06:11 04:29:51                 2          300.0
#
#                                             Copyright  XResolution_y  \
# 4                                                 ...          300.0
# 8                                                 ...          300.0
# 11                                                ...          300.0
# 26                                                ...          300.0
# 32                                                ...          300.0
# 64                                                ...          300.0
# 72                                                ...          300.0
# 73                                                ...          300.0
# 90                                                ...          300.0
# 93                                                ...          300.0
#
#                                   Artist
# 4
# 8
# 11
# 26
# 32
# 64
# 72
# 73
# 90
# 93
#
# [10 rows x 51 columns]

# %%
# See a particular image
open_layer.images.show(index=5)

# %%
# See the first 5 lines of the metadata
open_layer.get_metadata().head(5)
# Out:
#     ID  Unnamed: 0_x            filename  XResolution_x  YResolution_x  \
# 2    2           432  20180611041441.JPG            300            300
# 17  17           447  20180611041711.JPG            300            300
# 21  21           451  20180611041751.JPG            300            300
# 29  29           459  20180611041911.JPG            300            300
# 39  39           469  20180611042051.JPG            300            300
#
#     ExposureTime  FNumber  ISO            datetime  MaxApertureValue  ...  \
# 2       0.016667        8  200 2018-06-11 04:14:41          2.828427  ...
# 17      0.016667        8  200 2018-06-11 04:17:11          2.828427  ...
# 21      0.016667        8  200 2018-06-11 04:17:51          2.828427  ...
# 29      0.016667        8  200 2018-06-11 04:19:11          2.828427  ...
# 39      0.016667        8  200 2018-06-11 04:20:51          2.828427  ...
#
#                  Make        Model   Software  Orientation  \
# 2   NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 17  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 21  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 29  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
# 39  NIKON CORPORATION  NIKON D7100  Ver.1.03             1
#
#                DateTime  YCbCrPositioning  YResolution_y  \
# 2   2018:06:11 04:14:41                 2          300.0
# 17  2018:06:11 04:17:11                 2          300.0
# 21  2018:06:11 04:17:51                 2          300.0
# 29  2018:06:11 04:19:11                 2          300.0
# 39  2018:06:11 04:20:51                 2          300.0
#
#                                             Copyright  XResolution_y  \
# 2                                                 ...          300.0
# 17                                                ...          300.0
# 21                                                ...          300.0
# 29                                                ...          300.0
# 39                                                ...          300.0
#
#                                   Artist
# 2
# 17
# 21
# 29
# 39
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Resample the images

# %% [markdown]
# The add a next step to your processing pipeline, you need to instantiate the ResampleLayer class and pass the OpenLayer class as an argument

# %%
# Set the parameters
parameters = {
    'name': 'datetime',
    'mode': 'datetime',
    'params': {
        'min': '2018-06-11 04:14:00',
        'max': '2018-06-11 04:20:00'
    }
}

# %%
# Instantiate the new class
resample = ResampleLayer(paidiverpy=open_layer, parameters=parameters)

# %%
# Run the process using the parameters provided
resample.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-09-23 15:45:11 | Number of photos to be removed: 6

# %%
# See the output images
resample.images
# Out:
# Step: raw
# Image: [[92 92 93 ... 91 92 91]
#  [94 93 93 ... 91 92 92]
#  [94 93 93 ... 91 89 90]
#  ...
#  [84 84 83 ... 85 85 82]
#  [84 84 85 ... 85 85 84]
#  [84 83 84 ... 87 85 84]]
# Image: [[120 120 120 ...  99  98  98]
#  [120 120 121 ...  99  99  99]
#  [120 120 121 ...  99  99  99]
#  ...
#  [123 124 123 ... 106 105 104]
#  [121 123 123 ... 106 106 104]
#  [122 123 124 ... 103 104 104]]
# Image: [[129 130 129 ... 137 136 135]
#  [132 130 129 ... 138 136 136]
#  [130 130 128 ... 135 134 136]
#  ...
#  [135 136 137 ... 140 140 138]
#  [137 136 135 ... 140 139 138]
#  [138 136 133 ... 142 140 141]]
# Image: [[193 193 197 ... 186 187 188]
#  [196 197 197 ... 186 188 190]
#  [196 197 197 ... 185 185 185]
#  ...
#  [214 214 213 ... 207 204 204]
#  [213 214 215 ... 206 204 203]
#  [214 215 217 ... 204 203 200]]
# Image: [[202 201 202 ... 198 199 199]
#  [203 203 203 ... 200 201 200]
#  [203 203 203 ... 199 200 199]
#  ...
#  [216 218 218 ... 160 162 162]
#  [217 218 217 ... 161 162 160]
#  [216 217 215 ... 162 162 162]]
# Image: [[204 203 203 ... 197 197 197]
#  [203 204 204 ... 198 200 199]
#  [202 205 206 ... 199 201 200]
#  ...
#  [217 219 217 ... 209 211 211]
#  [218 219 217 ... 207 210 211]
#  [217 217 217 ... 206 208 209]]
# Image: [[194 193 196 ... 189 189 187]
#  [197 196 197 ... 187 188 188]
#  [199 198 198 ... 187 187 187]
#  ...
#  [214 212 212 ... 202 203 203]
#  [216 215 212 ... 200 202 201]
#  [216 217 214 ... 200 201 201]]
# Image: [[199 200 200 ... 187 191 188]
#  [199 200 201 ... 189 193 190]
#  [199 201 201 ... 189 190 190]
#  ...
#  [212 213 213 ... 204 205 204]
#  [212 212 212 ... 204 205 205]
#  [211 212 211 ... 204 205 204]]
# Image: [[202 201 200 ... 195 192 190]
#  [200 202 201 ... 194 190 188]
#  [200 200 203 ... 194 192 191]
#  ...
#  [214 212 213 ... 208 207 207]
#  [215 213 214 ... 209 207 206]
#  [215 215 214 ... 208 207 205]]
# Image: [[197 196 196 ... 192 192 190]
#  [196 195 198 ... 191 193 192]
#  [196 197 199 ... 191 193 193]
#  ...
#  [211 211 214 ... 207 207 206]
#  [211 211 213 ... 207 207 206]
#  [209 212 214 ... 207 209 208]]
# Step: sampling
# Image: [[92 92 93 ... 91 92 91]
#  [94 93 93 ... 91 92 92]
#  [94 93 93 ... 91 89 90]
#  ...
#  [84 84 83 ... 85 85 82]
#  [84 84 85 ... 85 85 84]
#  [84 83 84 ... 87 85 84]]
# Image: [[120 120 120 ...  99  98  98]
#  [120 120 121 ...  99  99  99]
#  [120 120 121 ...  99  99  99]
#  ...
#  [123 124 123 ... 106 105 104]
#  [121 123 123 ... 106 106 104]
#  [122 123 124 ... 103 104 104]]
# Image: [[129 130 129 ... 137 136 135]
#  [132 130 129 ... 138 136 136]
#  [130 130 128 ... 135 134 136]
#  ...
#  [135 136 137 ... 140 140 138]
#  [137 136 135 ... 140 139 138]
#  [138 136 133 ... 142 140 141]]
# Image: [[193 193 197 ... 186 187 188]
#  [196 197 197 ... 186 188 190]
#  [196 197 197 ... 185 185 185]
#  ...
#  [214 214 213 ... 207 204 204]
#  [213 214 215 ... 206 204 203]
#  [214 215 217 ... 204 203 200]]
