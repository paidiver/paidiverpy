# %% [markdown]
# ## Simple Processing

# %% [markdown]
# An example to proessing images without a proper pipeline

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.open_layer import OpenLayer
from paidiverpy.resample_layer import ResampleLayer
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Open the images

# %% [markdown]
# The first step will be always the load images step

# %%
# Instantiate the class
open_layer = OpenLayer(config_file_path="../config_files/config_simple.yaml")
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 23:07:08 | Downloading sample dataset: 'benthic_csv'
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 23:07:08 | Downloading benthic_csv files...
# Downloading benthic_csv files: 100%|███████| 1.64M/1.64M [00:21<00:00, 76.1kB/s]
# ☁ paidiverpy ☁  |       INFO | 2025-02-06 23:07:35 | Downloaded and cached at /home/tobfer/.paidiverpy_cache/494c971598bf0e549764e33af40d37942745e1229f79e7ae0dd1d13db5403057.zip
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Instantiate the class
# ----> 2 open_layer = OpenLayer(config_file_path="../config_files/config_simple.yaml")
#
# File /mnt/noc/code/paidiver/paidiverpy/src/paidiverpy/open_layer/open_layer.py:71, in OpenLayer.__init__(self, config_params, config_file_path, config, metadata, images, paidiverpy, step_name, parameters, logger, raise_error, verbose)
#      57 def __init__(
#      58     self,
#      59     config_params: dict | ConfigParams = None,
#    (...)
#      69     verbose: int = 2,
#      70 ):
# ---> 71     super().__init__(
#      72         config_params=config_params,
#      73         config_file_path=config_file_path,
#      74         metadata=metadata,
#      75         config=config,
#      76         images=images,
#      77         paidiverpy=paidiverpy,
#      78         logger=logger,
#      79         raise_error=raise_error,
#      80         verbose=verbose,
#      81     )
#      83     self.step_name = step_name
#      84     if parameters:
#
# File /mnt/noc/code/paidiver/paidiverpy/src/paidiverpy/paidiverpy.py:67, in Paidiverpy.__init__(self, config_params, config_file_path, config, metadata, images, client, paidiverpy, track_changes, logger, raise_error, verbose)
#      65 self.verbose = verbose
#      66 self.logger = logger or initialise_logging(verbose=self.verbose)
# ---> 67 self.config = config or self._initialise_config(config_file_path, config_params)
#      68 self.metadata = metadata or self._initialize_metadata()
#      69 self.images = images or ImagesLayer(
#      70     output_path=self.config.general.output_path,
#      71 )
#
# File /mnt/noc/code/paidiver/paidiverpy/src/paidiverpy/paidiverpy.py:198, in Paidiverpy._initialise_config(self, config_file_path, config_params)
#     188 """Initialize the configuration object.
#     189
#     190 Args:
#    (...)
#     195     Configuration: The configuration object.
#     196 """
#     197 if config_file_path:
# --> 198     return Configuration(config_file_path)
#     199 general_config = {}
#     200 config_params = ConfigParams(config_params) if isinstance(config_params, dict) else config_params
#
# File /mnt/noc/code/paidiver/paidiverpy/src/paidiverpy/config/config.py:193, in Configuration.__init__(self, config_file_path, input_path, output_path)
#     190 self.steps = []
#     192 if config_file_path:
# --> 193     self._load_config_from_file(config_file_path)
#     194 else:
#     195     self._validate_paths(input_path, output_path)
#
# File /mnt/noc/code/paidiver/paidiverpy/src/paidiverpy/config/config.py:226, in Configuration._load_config_from_file(self, config_file_path)
#     223     msg = f"Failed to parse the configuration file: {e!s}"
#     224     raise yaml.parser.ParserError(msg) from e
# --> 226 self.general = self._validate_general_config(config_data)
#     227 self._load_steps(config_data)
#
# File /mnt/noc/code/paidiver/paidiverpy/src/paidiverpy/config/config.py:269, in Configuration._validate_general_config(self, config_data)
#     267 if not name:
#     268     config_data["general"]["name"] = "raw"
# --> 269 return GeneralConfig(**config_data["general"])
#
# File /mnt/noc/code/paidiver/paidiverpy/src/paidiverpy/config/config.py:32, in GeneralConfig.__init__(self, **kwargs)
#      30 self.sample_data = kwargs.get("sample_data")
#      31 if self.sample_data:
# ---> 32     self._define_sample_data(self.sample_data)
#      33     self.is_remote = False
#      34 else:
#
# File /mnt/noc/code/paidiver/paidiverpy/src/paidiverpy/config/config.py:73, in GeneralConfig._define_sample_data(self, sample_data)
#      67 def _define_sample_data(self, sample_data: str) -> None:
#      68     """Define the sample data.
#      69
#      70     Args:
#      71         sample_data (str): The sample data type
#      72     """
# ---> 73     information = data.load(sample_data)
#      74     self.input_path = Path(information["input_path"])
#      75     self.metadata_path = Path(information["metadata_path"])
#
# File /mnt/noc/code/paidiver/paidiverpy/src/paidiverpy/utils/data.py:181, in load(dataset_name)
#     179 url = dataset_information["url"]
#     180 zip_path = download_file(url, dataset_name)
# --> 181 unzip_file(zip_path, dataset_name, extract_dir)
#     183 if zip_path.exists():
#     184     zip_path.unlink()
#
# File /mnt/noc/code/paidiver/paidiverpy/src/paidiverpy/utils/data.py:123, in unzip_file(zip_path, dataset_name, extract_dir)
#     115 """Unzip the file to the specified directory.
#     116
#     117 Args:
#    (...)
#     120     dataset_name (str): The name of the dataset.
#     121 """
#     122 if not extract_dir.exists():
# --> 123     with zipfile.ZipFile(zip_path, "r") as zip_ref:
#     124         total_files = len(zip_ref.infolist())
#     125         # Progress bar for extraction
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/zipfile.py:1269, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1267 try:
#    1268     if mode == 'r':
# -> 1269         self._RealGetContents()
#    1270     elif mode in ('w', 'x'):
#    1271         # set the modified flag so central directory gets written
#    1272         # even if no files are added to the archive
#    1273         self._didModify = True
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/zipfile.py:1336, in ZipFile._RealGetContents(self)
#    1334     raise BadZipFile("File is not a zip file")
#    1335 if not endrec:
# -> 1336     raise BadZipFile("File is not a zip file")
#    1337 if self.debug > 1:
#    1338     print(endrec)
#
# BadZipFile: File is not a zip file

# %%
# See the configuration file
open_layer.config

# %%
# Run the open layer process. It will open the images from the input path, and save then as a ImagesLayer
open_layer.run()
# Out:
# Open Images: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  9.96it/s]

# %%
# See the images output
open_layer.images
# Out:
# Step: raw
# Image: [[125 126 123 ... 136 135 134]
#  [122 120 124 ... 134 132 133]
#  [121 119 121 ... 131 136 134]
#  ...
#  [134 134 118 ... 141 145 140]
#  [136 135 111 ... 140 144 144]
#  [135 118 119 ... 137 139 142]]
# Image: [[164 163 164 ... 145 140 142]
#  [165 164 164 ... 138 146 140]
#  [162 161 167 ... 141 145 142]
#  ...
#  [172 168 134 ... 126 129 131]
#  [171 164 123 ... 128 128 128]
#  [171 128 121 ... 126 130 127]]
# Image: [[195 197 198 ... 182 187 183]
#  [195 195 195 ... 187 180 182]
#  [193 193 198 ... 182 181 181]
#  ...
#  [212 212 150 ... 202 200 198]
#  [212 205 131 ... 201 203 202]
#  [218 139 129 ... 204 203 203]]
# Image: [[191 188 190 ... 181 183 185]
#  [189 190 187 ... 182 186 180]
#  [190 188 193 ... 179 182 178]
#  ...
#  [211 213 155 ... 194 200 199]
#  [212 206 130 ... 202 200 199]
#  [218 139 129 ... 199 203 201]]
# Image: [[201 200 204 ... 198 196 199]
#  [201 201 201 ... 198 198 196]
#  [202 202 202 ... 197 197 195]
#  ...
#  [216 217 139 ... 144 144 186]
#  [212 208 129 ... 137 152 169]
#  [219 133 131 ... 133 142 156]]

# %%
open_layer.get_metadata()
# Out:
#       ID            image-filename  XResolution  YResolution  ExposureTime  \
# 0  451.0  20180611T041751.000Z.PNG        300.0        300.0      0.016667
# 1  457.0  20180611T041851.000Z.PNG        300.0        300.0      0.016667
# 2  460.0  20180611T041921.000Z.PNG        300.0        300.0      0.016667
# 3  466.0  20180611T042021.000Z.PNG        300.0        300.0      0.016667
# 4  469.0  20180611T042051.000Z.PNG        300.0        300.0      0.016667
#
#    FNumber    ISO      image-datetime  MaxApertureValue  WhiteBalance  ...  \
# 0      8.0  200.0 2018-06-11 04:17:51          2.828427  FLASH         ...
# 1      8.0  200.0 2018-06-11 04:18:51          2.828427  FLASH         ...
# 2      8.0  200.0 2018-06-11 04:19:21          2.828427  FLASH         ...
# 3      8.0  200.0 2018-06-11 04:20:21          2.828427  FLASH         ...
# 4      8.0  200.0 2018-06-11 04:20:51          2.828427  FLASH         ...
#
#    speed_of_sound_m_s  temperature_c  positioning_ok  attitude_ok  depth_ok  \
# 0            1545.198         1.4473               1            1         1
# 1            1545.169         1.4447               1            1         1
# 2            1545.194         1.4549               1            1         1
# 3            1545.124         1.4325               1            1         1
# 4            1545.114         1.4314               1            1         1
#
#    altitude_ok   X            phototime  flag  \
# 0            1 NaN  2018-06-11 04:17:51     0
# 1            0 NaN  2018-06-11 04:18:51     0
# 2            1 NaN  2018-06-11 04:19:21     0
# 3            1 NaN  2018-06-11 04:20:21     0
# 4            1 NaN  2018-06-11 04:20:51     0
#
#                                point
# 0  POINT (-153.60531062 11.25162821)
# 1  POINT (-153.60527218 11.25163858)
# 2  POINT (-153.60524786 11.25163778)
# 3  POINT (-153.60519493 11.25162345)
# 4   POINT (-153.60517508 11.2516303)
#
# [5 rows x 37 columns]

# %%
# See a particular image
open_layer.images.show(image_number=5)
# Out:
#         <style>
#         .step-header {
#             font-size: 1.2em;
#             font-weight: bold;
#             margin-top: 10px;
#             margin-bottom: 5px;
#         }
#         .metadata {
#             margin-left: 20px;
#             margin-bottom: 10px;
#         }
#         .image-container {
#             display: flex;
#             flex-wrap: wrap;
#             gap: 10px;
#             margin-left: 20px;
#         }
#         .image-container img {
#             max-width: 200px;
#             margin: 10px;
#         }
#         .toggle-arrow {
#             cursor: pointer;
#             margin-left: 5px;
#         }
#         .show-more-button, .hide-button {
#             margin-left: 20px;
#             background-color: #007bff;
#             color: white;
#             border: none;
#             padding: 5px 10px;
#             cursor: pointer;
#         }
#         </style>
#         <script>
#         function toggleMetadata(stepIndex) {
#             var x = document.getElementById("metadata-" + stepIndex);
#             var arrow = document.getElementById("arrow-" + stepIndex);
#             if (x.style.display === "none") {
#                 x.style.display = "block";
#                 arrow.innerHTML = "▼";
#             } else {
#                 x.style.display = "none";
#                 arrow.innerHTML = "►";
#             }
#         }
#         function toggleImage(imageId) {
#             var img = document.getElementById(imageId);
#             var arrow = document.getElementById("arrow-" + imageId);
#             if (img.style.display === "none") {
#                 img.style.display = "block";
#                 arrow.innerHTML = "▼";
#             } else {
#                 img.style.display = "none";
#                 arrow.innerHTML = "►";
#             }
#         }
#         function showMore(stepIndex) {
#             var moreImages = document.getElementById("more-images-" + stepIndex);
#             var showMoreButton = document.getElementById("show-more-button-" + stepIndex);
#             var hideButton = document.getElementById("hide-button-" + stepIndex);
#             moreImages.style.display = "flex";
#             showMoreButton.style.display = "none";
#             hideButton.style.display = "inline-block";
#         }
#         function hide(stepIndex) {
#             var moreImages = document.getElementById("more-images-" + stepIndex);
#             var showMoreButton = document.getElementById("show-more-button-" + stepIndex);
#             var hideButton = document.getElementById("hide-button-" + stepIndex);
#             moreImages.style.display = "none";
#             showMoreButton.style.display = "inline-block";
#             hideButton.style.display = "none";
#         }
#         </script>
#
#                 <div class='step-header'>Step: raw <span id='arrow-0'
#                     class='toggle-arrow'
#                     onclick='toggleMetadata(0)'>►</span>
#                 </div>
#                 <div id='metadata-0' class='metadata' style='display:block;'><div class='image-container'><p>No images to show</p></div></div>

# %%
# See the first 5 lines of the metadata
open_layer.get_metadata().head(5)
# Out:
#       ID            image-filename  XResolution  YResolution  ExposureTime  \
# 0  451.0  20180611T041751.000Z.PNG        300.0        300.0      0.016667
# 1  457.0  20180611T041851.000Z.PNG        300.0        300.0      0.016667
# 2  460.0  20180611T041921.000Z.PNG        300.0        300.0      0.016667
# 3  466.0  20180611T042021.000Z.PNG        300.0        300.0      0.016667
# 4  469.0  20180611T042051.000Z.PNG        300.0        300.0      0.016667
#
#    FNumber    ISO      image-datetime  MaxApertureValue  WhiteBalance  ...  \
# 0      8.0  200.0 2018-06-11 04:17:51          2.828427  FLASH         ...
# 1      8.0  200.0 2018-06-11 04:18:51          2.828427  FLASH         ...
# 2      8.0  200.0 2018-06-11 04:19:21          2.828427  FLASH         ...
# 3      8.0  200.0 2018-06-11 04:20:21          2.828427  FLASH         ...
# 4      8.0  200.0 2018-06-11 04:20:51          2.828427  FLASH         ...
#
#    speed_of_sound_m_s  temperature_c  positioning_ok  attitude_ok  depth_ok  \
# 0            1545.198         1.4473               1            1         1
# 1            1545.169         1.4447               1            1         1
# 2            1545.194         1.4549               1            1         1
# 3            1545.124         1.4325               1            1         1
# 4            1545.114         1.4314               1            1         1
#
#    altitude_ok   X            phototime  flag  \
# 0            1 NaN  2018-06-11 04:17:51     0
# 1            0 NaN  2018-06-11 04:18:51     0
# 2            1 NaN  2018-06-11 04:19:21     0
# 3            1 NaN  2018-06-11 04:20:21     0
# 4            1 NaN  2018-06-11 04:20:51     0
#
#                                point
# 0  POINT (-153.60531062 11.25162821)
# 1  POINT (-153.60527218 11.25163858)
# 2  POINT (-153.60524786 11.25163778)
# 3  POINT (-153.60519493 11.25162345)
# 4   POINT (-153.60517508 11.2516303)
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Resample the images

# %% [markdown]
# The add a next step to your processing pipeline, you need to instantiate the ResampleLayer class and pass the OpenLayer class as an argument

# %%
# Set the parameters
parameters = {
    "name": "datetime",
    "mode": "datetime",
    "params": {"min": "2018-06-11 04:14:00", "max": "2018-06-11 04:20:00"},
}

# %%
# Instantiate the new class
resample = ResampleLayer(paidiverpy=open_layer, parameters=parameters)

# %%
# Run the process using the parameters provided
resample.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 00:16:35 | Number of photos to be removed: 2

# %%
# See the output images
resample.images
# Out:
# Step: raw
# Image: [[125 126 123 ... 136 135 134]
#  [122 120 124 ... 134 132 133]
#  [121 119 121 ... 131 136 134]
#  ...
#  [134 134 118 ... 141 145 140]
#  [136 135 111 ... 140 144 144]
#  [135 118 119 ... 137 139 142]]
# Image: [[164 163 164 ... 145 140 142]
#  [165 164 164 ... 138 146 140]
#  [162 161 167 ... 141 145 142]
#  ...
#  [172 168 134 ... 126 129 131]
#  [171 164 123 ... 128 128 128]
#  [171 128 121 ... 126 130 127]]
# Image: [[195 197 198 ... 182 187 183]
#  [195 195 195 ... 187 180 182]
#  [193 193 198 ... 182 181 181]
#  ...
#  [212 212 150 ... 202 200 198]
#  [212 205 131 ... 201 203 202]
#  [218 139 129 ... 204 203 203]]
# Image: [[191 188 190 ... 181 183 185]
#  [189 190 187 ... 182 186 180]
#  [190 188 193 ... 179 182 178]
#  ...
#  [211 213 155 ... 194 200 199]
#  [212 206 130 ... 202 200 199]
#  [218 139 129 ... 199 203 201]]
# Image: [[201 200 204 ... 198 196 199]
#  [201 201 201 ... 198 198 196]
#  [202 202 202 ... 197 197 195]
#  ...
#  [216 217 139 ... 144 144 186]
#  [212 208 129 ... 137 152 169]
#  [219 133 131 ... 133 142 156]]
# Step: sampling
# Image: [[125 126 123 ... 136 135 134]
#  [122 120 124 ... 134 132 133]
#  [121 119 121 ... 131 136 134]
#  ...
#  [134 134 118 ... 141 145 140]
#  [136 135 111 ... 140 144 144]
#  [135 118 119 ... 137 139 142]]
# Image: [[164 163 164 ... 145 140 142]
#  [165 164 164 ... 138 146 140]
#  [162 161 167 ... 141 145 142]
#  ...
#  [172 168 134 ... 126 129 131]
#  [171 164 123 ... 128 128 128]
#  [171 128 121 ... 126 130 127]]
# Image: [[195 197 198 ... 182 187 183]
#  [195 195 195 ... 187 180 182]
#  [193 193 198 ... 182 181 181]
#  ...
#  [212 212 150 ... 202 200 198]
#  [212 205 131 ... 201 203 202]
#  [218 139 129 ... 204 203 203]]
