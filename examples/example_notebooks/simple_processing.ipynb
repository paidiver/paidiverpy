# %% [markdown]
# ## Simple Processing

# %% [markdown]
# An example to proessing images without a proper pipeline

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.open_layer import OpenLayer
from paidiverpy.sampling_layer import SamplingLayer

# %% [markdown]
# ### Open the images

# %% [markdown]
# The first step will be always the load images step

# %%
# Instantiate the class
open_layer = OpenLayer(config_file_path="../config_files/config_simple.yml")

# %%
# See the configuration file
open_layer.config
# Out:
# {
#     "general": {
#         "name": "raw",
#         "step_name": "open",
#         "sample_data": "benthic_csv",
#         "input_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/images",
#         "output_path": "output",
#         "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/metadata_benthic_csv.csv",
#         "metadata_type": "CSV_FILE",
#         "image_open_args": "PNG",
#         "append_data_to_metadata": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/appended_metadata_benthic_csv.csv",
#         "n_jobs": 1,
#         "track_changes": true,
#         "rename": "datetime",
#         "sampling": [
#             {
#                 "name": "sampling",
#                 "step_name": "sampling",
#                 "test": false,
#                 "params": {
#                     "value": 0.1,
#                     "raise_error": false
#                 },
#                 "mode": "percent"
#             }
#         ],
#         "convert": [
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "test": false,
#                 "params": {
#                     "output_bits": 8,
#                     "raise_error": false
#                 },
#                 "mode": "bits"
#             },
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "test": false,
#                 "params": {
#                     "to": "gray",
#                     "channel_selector": 0,
#                     "raise_error": false
#                 },
#                 "mode": "to"
#             }
#         ]
#     },
#     "steps": []
# }

# %%
# Run the open layer process. It will open the images from the input path, and save then as a ImagesLayer
open_layer.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-06-02 19:33:39 | Number of images to be removed: 44. Total number of images: 49
# Open Images: 100%|███████████████████████████████████| 5/5 [00:00<00:00, 209.82it/s]
# Processing images:   0%|                                      | 0/5 [00:00<?, ?it/s]WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8
# WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8
# WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8
# WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8
# WARNING:root:Failed to convert the image to 8 bits: Unsupported output bits or image already within provided format: 8
# Processing images: 100%|█████████████████████████████| 5/5 [00:00<00:00, 573.18it/s]
# Processing images: 100%|████████████████████████████| 5/5 [00:00<00:00, 3250.39it/s]
# WARNING:root:Unsupported output bits or image already within provided format: 8
# WARNING:root:Unsupported output bits or image already within provided format: 8
# WARNING:root:Unsupported output bits or image already within provided format: 8
# WARNING:root:Unsupported output bits or image already within provided format: 8
# WARNING:root:Unsupported output bits or image already within provided format: 8
# Processing images: 100%|████████████████████████| 5/5 [00:00<00:00, 1409.85it/s]
# Processing images:   0%|                                  | 0/5 [00:00<?, ?it/s]
# Processing images: 100%|███████████████████████| 5/5 [00:00<00:00, 57299.23it/s]

# %%
# See the images output
open_layer.images
# Out:
# Step: raw
# Image: [[[183]
#   [183]
#   [185]
#   ...
#   [202]
#   [201]
#   [202]]
#
#  [[185]
#   [184]
#   [184]
#   ...
#   [201]
#   [202]
#   [203]]
#
#  [[185]
#   [184]
#   [185]
#   ...
#   [202]
#   [201]
#   [203]]
#
#  ...
#
#  [[187]
#   [186]
#   [189]
#   ...
#   [206]
#   [207]
#   [206]]
#
#  [[185]
#   [186]
#   [188]
#   ...
#   [206]
#   [206]
#   [206]]
#
#  [[186]
#   [187]
#   [187]
#   ...
#   [205]
#   [206]
#   [206]]]
# Image: [[[198]
#   [198]
#   [199]
#   ...
#   [203]
#   [204]
#   [204]]
#
#  [[199]
#   [198]
#   [198]
#   ...
#   [204]
#   [204]
#   [205]]
#
#  [[201]
#   [200]
#   [198]
#   ...
#   [205]
#   [204]
#   [205]]
#
#  ...
#
#  [[195]
#   [196]
#   [198]
#   ...
#   [205]
#   [207]
#   [206]]
#
#  [[194]
#   [195]
#   [194]
#   ...
#   [206]
#   [207]
#   [207]]
#
#  [[194]
#   [194]
#   [195]
#   ...
#   [204]
#   [207]
#   [207]]]
# Image: [[[198]
#   [199]
#   [198]
#   ...
#   [205]
#   [205]
#   [204]]
#
#  [[199]
#   [198]
#   [197]
#   ...
#   [205]
#   [204]
#   [206]]
#
#  [[199]
#   [198]
#   [199]
#   ...
#   [205]
#   [205]
#   [205]]
#
#  ...
#
#  [[191]
#   [194]
#   [195]
#   ...
#   [200]
#   [199]
#   [200]]
#
#  [[192]
#   [192]
#   [194]
#   ...
#   [198]
#   [199]
#   [201]]
#
#  [[193]
#   [193]
#   [193]
#   ...
#   [199]
#   [199]
#   [199]]]
# Image: [[[132]
#   [135]
#   [131]
#   ...
#   [172]
#   [173]
#   [174]]
#
#  [[139]
#   [133]
#   [133]
#   ...
#   [173]
#   [173]
#   [173]]
#
#  [[138]
#   [139]
#   [137]
#   ...
#   [177]
#   [173]
#   [172]]
#
#  ...
#
#  [[165]
#   [165]
#   [170]
#   ...
#   [189]
#   [188]
#   [191]]
#
#  [[166]
#   [167]
#   [172]
#   ...
#   [187]
#   [189]
#   [191]]
#
#  [[167]
#   [169]
#   [169]
#   ...
#   [189]
#   [188]
#   [190]]]
# Image: [[[ 51]
#   [ 54]
#   [ 55]
#   ...
#   [ 74]
#   [ 76]
#   [ 80]]
#
#  [[ 54]
#   [ 57]
#   [ 58]
#   ...
#   [ 68]
#   [ 67]
#   [ 58]]
#
#  [[ 54]
#   [ 54]
#   [ 59]
#   ...
#   [ 71]
#   [ 68]
#   [ 66]]
#
#  ...
#
#  [[ 36]
#   [ 34]
#   [117]
#   ...
#   [ 48]
#   [ 50]
#   [ 50]]
#
#  [[ 39]
#   [ 49]
#   [139]
#   ...
#   [ 49]
#   [ 48]
#   [ 47]]
#
#  [[ 32]
#   [134]
#   [143]
#   ...
#   [ 47]
#   [ 46]
#   [ 47]]]

# %%
open_layer.get_metadata()
# Out:
#              image-filename     ID  XResolution  YResolution  ExposureTime  \
# 0  20180611T041421.000Z.PNG  430.0        300.0        300.0      0.016667
# 1  20180611T041451.000Z.PNG  433.0        300.0        300.0      0.016667
# 2  20180611T041521.000Z.PNG  436.0        300.0        300.0      0.016667
# 3  20180611T041651.000Z.PNG  445.0        300.0        300.0      0.016667
# 4  20180611T041951.000Z.PNG  463.0        300.0        300.0      0.016667
#
#    FNumber    ISO      image-datetime  MaxApertureValue  WhiteBalance  ...  \
# 0      8.0  200.0 2018-06-11 04:14:21          2.828427  FLASH         ...
# 1      8.0  200.0 2018-06-11 04:14:51          2.828427  FLASH         ...
# 2      8.0  200.0 2018-06-11 04:15:21          2.828427  FLASH         ...
# 3      8.0  200.0 2018-06-11 04:16:51          2.828427  FLASH         ...
# 4      8.0  200.0 2018-06-11 04:19:51          2.828427  FLASH         ...
#
#    temperature_c  positioning_ok  attitude_ok  depth_ok  altitude_ok   X  \
# 0         1.5059               1            1         1            1 NaN
# 1         1.4911               1            1         1            1 NaN
# 2         1.4697               1            1         1            1 NaN
# 3         1.4506               1            1         1            1 NaN
# 4         1.4427               1            1         1            1 NaN
#
#              phototime  flag                              point  num_channels
# 0  2018-06-11 04:14:21     0  POINT (-153.60531587 11.25172554)             1
# 1  2018-06-11 04:14:51     0  POINT (-153.60531313 11.25170837)             1
# 2  2018-06-11 04:15:21     0   POINT (-153.6053176 11.25169125)             1
# 3  2018-06-11 04:16:51     0  POINT (-153.60531968 11.25163773)             1
# 4  2018-06-11 04:19:51     0  POINT (-153.60522104 11.25162529)             1
#
# [5 rows x 38 columns]

# %%
# See a particular image
open_layer.images.show(image_number=5)
# Out:
# <div><svg style="position: absolute; width: 0; height: 0; overflow: hidden">
# <defs>
# <symbol id="arrow-right" viewBox="0 0 330 330">
#   <path id="XMLID_222_" d="M250.606,154.389l-150-149.996c-5.857-5.858-15.355-5.858-21.213,0.001
# 	c-5.857,5.858-5.857,15.355,0.001,21.213l139.393,139.39L79.393,304.394c-5.857,5.858-5.857,15.355,0.001,21.213
# 	C82.322,328.536,86.161,330,90,330s7.678-1.464,10.607-4.394l149.999-150.004c2.814-2.813,4.394-6.628,4.394-10.606
# 	C255,161.018,253.42,157.202,250.606,154.389z"/>
# </defs>
# </svg>
# <style>/* CSS stylesheet for displaying Paidiverpy objects in jupyterlab.
#  *
#  */
#
# :root {
#   --ppy-font-color: var(--jp-content-font-color, rgba(0, 0, 0, 1));
#   --ppy-font-color-brown: var(--jp-content-font-color-brown, brown);
#   --ppy-font-color-olive: var(--jp-content-font-color-olive, olive);
#   --ppy-font-color-teal: var(--jp-content-font-color-teal, teal);
#   --ppy-font-color-blue: var(--jp-content-font-color-blue, blue);
#   --ppy-font-color-gray: var(--jp-content-font-color-gray, gray);
#   --ppy-border-color: var(--jp-border-color2, #e0e0e0);
#   --ppy-disabled-color: var(--jp-layout-color3, #bdbdbd);
#   --ppy-background-color: var(--jp-layout-color, white);
#   --ppy-background-color2: var(--jp-layout-color3, rgba(212, 212, 212, 0.15));
# }
#
#
# html[theme="dark"],
# html[data-theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --ppy-font-color: rgba(255, 255, 255, 1);
#   --ppy-font-color-brown: brown;
#   --ppy-font-color-olive: olive;
#   --ppy-font-color-teal: teal;
#   --ppy-font-color-blue: blue;
#   --ppy-font-color-gray: gray;
#   --ppy-border-color: #1f1f1f;
#   --ppy-disabled-color: #515151;
#   --ppy-background-color: #111111;
# }
#
# .ppy-background-color {
#   background-color: var(--ppy-background-color) !important;
# }
#
# .ppy-font-color-brown {
#   color: var(--ppy-font-color-brown) !important;
# }
#
# .ppy-font-color {
#   color: var(--ppy-font-color) !important;
# }
# .ppy-h2 {
#   font-size: 20px !important;
# }
# .ppy-h3 {
#   font-size: 13px !important;
# }
# .ppy-p {
#   font-size: 10px;
# }
# .ppy-p-error {
#   color: var(--ppy-font-color-brown);
#   font-weight: bold;
#   display: block;
# }
#
# .ppy-text-repr-fallback {
#   /* fallback to plain text repr when CSS is not injected (untrusted notebook) */
#   display: none;
# }
#
# .ppy-pipeline-wrap{
#   display: flex;
#   flex-wrap: wrap;
#   align-items: center;
# }
#
# .ppy-pipeline {
#   float:left;
#   cursor: pointer;
#   padding: 10px;
#   width: max-content;
#   height: 150px;
#   margin: 10px;
#   border: 1px solid #000;
#   text-align: center;
#   /* line-height: 80px; */
# }
#
# .ppy-pipeline-clear-fix {
#   clear: both;
# }
#
# .ppy-pipeline-parameters-all {
#   padding: 10px;
#   margin: 10px;
# }
#
# .ppy-images-step-header {
#   cursor: pointer;
#   font-weight: bold;
#   margin-top: 10px;
#   margin-bottom: 5px;
# }
# .ppy-images-metadata {
#   margin-left: 20px;
#   margin-bottom: 10px;
# }
# .ppy-images {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 10px;
#   margin-left: 20px;
# }
#
# .ppy-show-more-button, .ppy-hide-button {
#   margin-left: 20px;
#   background-color: #007bff;
#   color: white;
#   border: none;
#   padding: 5px 10px;
#   cursor: pointer;
# }
#
#
# .ppy-pipeline-arrow {
#   float:left;
#   width: 50px;
#   height: 80px;
#   margin: 10px;
#   text-align: center;
#   line-height: 80px;
# }
#
# .ppy-images-img{
#   display: block;
#   max-width: 200px;
#   margin: 10px;
# }
#
# .ppy-images-toggle-arrow {
#   cursor: pointer;
#   margin-left: 5px;
# }
#
# .ppy-images-image-p {
#   cursor: pointer;
# }
#
# .ppy-arrow-right {
#   display: inline-block;
#   vertical-align: middle;
#   width: 1em;
#   height: 1.5em !important;
#   stroke-width: 0;
#   stroke: currentColor;
#   fill: currentColor;
# }
#
#
# .ppy-json-block {
#   font-family: monospace;
#   background: var(--ppy-background-color);
#   padding: 1em;
#   border-radius: 6px;
# }
# .ppy-json-key {
#   color: var(--ppy-font-color-brown);
# }
# .ppy-json-string {
#   color: var(--ppy-font-color-olive);
# }
# .ppy-json-number {
#   color: var(--ppy-font-color-teal);
# }
# .ppy-json-bool {
#   color: var(--ppy-font-color-blue);
# }
# .ppy-json-null {
#   color: var(--ppy-font-color-gray);
# }
#
#
# .ppy-pn-title-0 {
#   font-size: 30px;
# }
#
# .ppy-pn-title-1 {
#   font-size: 20px;
# }
# .ppy-pn-title-2 {
#   font-size: 17px;
# }
# .ppy-pn-title-3 {
#   font-size: 14px;
# }
# .ppy-pn-title-4 {
#   font-size: 12px;
# }
#
# .ppy-pn-bold {
#   font-weight: bold;
# }
# .ppy-pn-italic {
#   font-style: italic;
# }
# .ppy-pn-description {
#   font-size: 14px;
#   margin-bottom: 1px;
# }
#
# .bk-root {
#   width: 100% !important;
#   max-width: 100% !important;
#   box-sizing: border-box;
# }
#
# input, .bk-input, .bk-input-group {
#   margin-top: 0px;
#   margin-bottom: 3px;
#   padding-top: 0px;
#   padding-bottom: 0px;
# }
#
# .ppy-pn-header-button .bk-btn {
#   background: none !important;
#   border: none !important;
#   font-weight: bold;
#   font-size: 16px;
#   text-align: left;
#   padding-left: 0;
#   cursor: pointer;
#   box-shadow: none !important;
#   color: black;
# }
#
# .ppy-pn-danger-modal{
#   border: 2px solid red;
#   border-radius: 10px;
#   box-shadow: 0px 0px 10px rgba(255, 0, 0, 0.5);
# }
#
# .ppy-pn-config-form{
#   padding: 10px;
#   margin-top: 10px;
#   margin-bottom: 10px;
#   background-color: var(--ppy-background-color2);
#   border-radius: 5px;
#   box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);
# }
#
#
# .ppy-pn-align-right {
#   display: flex;
#   justify-content: flex-end;
# }
# </style><script>function toggleMetadata(stepIndex, randomId) {
#   var metadata = document.getElementById("ppy-images-metadata-" + randomId + "-" + stepIndex);
#   var arrow = document.getElementById("ppy-images-arrow-" + randomId + "-" + stepIndex);
#   if (metadata.style.display === "none") {
#       metadata.style.display = "block";
#       arrow.innerHTML = "▼";
#       arrow.classList.remove("ppy-font-color");
#       arrow.classList.add("ppy-font-color-brown");
#   } else {
#       metadata.style.display = "none";
#       arrow.innerHTML = "►";
#       arrow.classList.remove("ppy-font-color-brown");
#       arrow.classList.add("ppy-font-color");
#   }
# }
# function toggleImage(imageId, randomId) {
#   var img = document.getElementById(imageId);
#   var arrow = document.getElementById("ppy-images-arrow-" + randomId + "-" + imageId);
#   if (img.style.display === "none") {
#       img.style.display = "block";
#       arrow.innerHTML = "▼";
#       arrow.classList.remove("ppy-font-color");
#       arrow.classList.add("ppy-font-color-brown");
#   } else {
#       img.style.display = "none";
#       arrow.innerHTML = "►";
#       arrow.classList.remove("ppy-font-color-brown");
#       arrow.classList.add("ppy-font-color");
#   }
# }
# function showMore(stepIndex) {
#   var moreImages = document.getElementById("ppy-more-images-" + stepIndex);
#   var showMoreButton = document.getElementById("ppy-show-more-button-" + stepIndex);
#   var hideButton = document.getElementById("ppy-hide-button-" + stepIndex);
#   moreImages.style.display = "flex";
#   showMoreButton.style.display = "none";
#   hideButton.style.display = "inline-block";
# }
# function hide(stepIndex) {
#   var moreImages = document.getElementById("ppy-more-images-" + stepIndex);
#   var showMoreButton = document.getElementById("ppy-show-more-button-" + stepIndex);
#   var hideButton = document.getElementById("ppy-hide-button-" + stepIndex);
#   moreImages.style.display = "none";
#   showMoreButton.style.display = "inline-block";
#   hideButton.style.display = "none";
# }
#
#
# function showParameters(id, randomId) {
#   var currentTarget = document.getElementById('ppy-pipeline-' + randomId + '-' + id);
#   var square = document.getElementsByClassName('ppy-pipeline-' + randomId);
#   var allParams = document.getElementsByClassName('ppy-pipeline-parameters-' + randomId);
#   var selectedParams = document.getElementById('ppy-pipeline-parameters-' + randomId + '-' + id);
#   var idWasVisible = false;
#   if (selectedParams) {
#       var idWasVisible = selectedParams.style.display === 'block';
#   }
#   for (var i = 0; i < square.length; i++) {
#       square[i].classList.remove('ppy-font-color-brown');
#       square[i].classList.add('ppy-font-color');
#   }
#   for (var i = 0; i < allParams.length; i++) {
#       allParams[i].style.display = 'none';
#   }
#   // Show the selected parameter section
#   if (selectedParams) {
#       if (idWasVisible) {
#           sele

# %%
# See the first 5 lines of the metadata
open_layer.get_metadata().head(5)
# Out:
#              image-filename     ID  XResolution  YResolution  ExposureTime  \
# 0  20180611T041421.000Z.PNG  430.0        300.0        300.0      0.016667
# 1  20180611T041451.000Z.PNG  433.0        300.0        300.0      0.016667
# 2  20180611T041521.000Z.PNG  436.0        300.0        300.0      0.016667
# 3  20180611T041651.000Z.PNG  445.0        300.0        300.0      0.016667
# 4  20180611T041951.000Z.PNG  463.0        300.0        300.0      0.016667
#
#    FNumber    ISO      image-datetime  MaxApertureValue  WhiteBalance  ...  \
# 0      8.0  200.0 2018-06-11 04:14:21          2.828427  FLASH         ...
# 1      8.0  200.0 2018-06-11 04:14:51          2.828427  FLASH         ...
# 2      8.0  200.0 2018-06-11 04:15:21          2.828427  FLASH         ...
# 3      8.0  200.0 2018-06-11 04:16:51          2.828427  FLASH         ...
# 4      8.0  200.0 2018-06-11 04:19:51          2.828427  FLASH         ...
#
#    temperature_c  positioning_ok  attitude_ok  depth_ok  altitude_ok   X  \
# 0         1.5059               1            1         1            1 NaN
# 1         1.4911               1            1         1            1 NaN
# 2         1.4697               1            1         1            1 NaN
# 3         1.4506               1            1         1            1 NaN
# 4         1.4427               1            1         1            1 NaN
#
#              phototime  flag                              point  num_channels
# 0  2018-06-11 04:14:21     0  POINT (-153.60531587 11.25172554)             1
# 1  2018-06-11 04:14:51     0  POINT (-153.60531313 11.25170837)             1
# 2  2018-06-11 04:15:21     0   POINT (-153.6053176 11.25169125)             1
# 3  2018-06-11 04:16:51     0  POINT (-153.60531968 11.25163773)             1
# 4  2018-06-11 04:19:51     0  POINT (-153.60522104 11.25162529)             1
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Resample the images

# %% [markdown]
# The add a next step to your processing pipeline, you need to instantiate the SamplingLayer class and pass the OpenLayer class as an argument

# %%
# Set the parameters
parameters = {
    "name": "datetime",
    "mode": "datetime",
    "params": {"min": "2018-06-11 04:14:00", "max": "2018-06-11 04:20:00"},
}

# %%
# Instantiate the new class
resample = SamplingLayer(paidiverpy=open_layer, parameters=parameters)

# %%
# Run the process using the parameters provided
resample.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-06-02 19:33:40 | Number of images to be removed: 0. Total number of images: 5
# INFO:paidiverpy:Number of images to be removed: 0. Total number of images: 5

# %%
# See the output images
resample.images
# Out:
# Step: raw
# Image: [[[183]
#   [183]
#   [185]
#   ...
#   [202]
#   [201]
#   [202]]
#
#  [[185]
#   [184]
#   [184]
#   ...
#   [201]
#   [202]
#   [203]]
#
#  [[185]
#   [184]
#   [185]
#   ...
#   [202]
#   [201]
#   [203]]
#
#  ...
#
#  [[187]
#   [186]
#   [189]
#   ...
#   [206]
#   [207]
#   [206]]
#
#  [[185]
#   [186]
#   [188]
#   ...
#   [206]
#   [206]
#   [206]]
#
#  [[186]
#   [187]
#   [187]
#   ...
#   [205]
#   [206]
#   [206]]]
# Image: [[[198]
#   [198]
#   [199]
#   ...
#   [203]
#   [204]
#   [204]]
#
#  [[199]
#   [198]
#   [198]
#   ...
#   [204]
#   [204]
#   [205]]
#
#  [[201]
#   [200]
#   [198]
#   ...
#   [205]
#   [204]
#   [205]]
#
#  ...
#
#  [[195]
#   [196]
#   [198]
#   ...
#   [205]
#   [207]
#   [206]]
#
#  [[194]
#   [195]
#   [194]
#   ...
#   [206]
#   [207]
#   [207]]
#
#  [[194]
#   [194]
#   [195]
#   ...
#   [204]
#   [207]
#   [207]]]
# Image: [[[198]
#   [199]
#   [198]
#   ...
#   [205]
#   [205]
#   [204]]
#
#  [[199]
#   [198]
#   [197]
#   ...
#   [205]
#   [204]
#   [206]]
#
#  [[199]
#   [198]
#   [199]
#   ...
#   [205]
#   [205]
#   [205]]
#
#  ...
#
#  [[191]
#   [194]
#   [195]
#   ...
#   [200]
#   [199]
#   [200]]
#
#  [[192]
#   [192]
#   [194]
#   ...
#   [198]
#   [199]
#   [201]]
#
#  [[193]
#   [193]
#   [193]
#   ...
#   [199]
#   [199]
#   [199]]]
# Image: [[[132]
#   [135]
#   [131]
#   ...
#   [172]
#   [173]
#   [174]]
#
#  [[139]
#   [133]
#   [133]
#   ...
#   [173]
#   [173]
#   [173]]
#
#  [[138]
#   [139]
#   [137]
#   ...
#   [177]
#   [173]
#   [172]]
#
#  ...
#
#  [[165]
#   [165]
#   [170]
#   ...
#   [189]
#   [188]
#   [191]]
#
#  [[166]
#   [167]
#   [172]
#   ...
#   [187]
#   [189]
#   [191]]
#
#  [[167]
#   [169]
#   [169]
#   ...
#   [189]
#   [188]
#   [190]]]
# Image: [[[ 51]
#   [ 54]
#   [ 55]
#   ...
#   [ 74]
#   [ 76]
#   [ 80]]
#
#  [[ 54]
#   [ 57]
#   [ 58]
#   ...
#   [ 68]
#   [ 67]
#   [ 58]]
#
#  [[ 54]
#   [ 54]
#   [ 59]
#   ...
#   [ 71]
#   [ 68]
#   [ 66]]
#
#  ...
#
#  [[ 36]
#   [ 34]
#   [117]
#   ...
#   [ 48]
#   [ 50]
#   [ 50]]
#
#  [[ 39]
#   [ 49]
#   [139]
#   ...
#   [ 49]
#   [ 48]
#   [ 47]]
#
#  [[ 32]
#   [134]
#   [143]
#   ...
#   [ 47]
#   [ 46]
#   [ 47]]]
# Step: sampling
# Image: [[[183]
#   [183]
#   [185]
#   ...
#   [202]
#   [201]
#   [202]]
#
#  [[185]
#   [184]
#   [184]
#   ...
#   [201]
#   [202]
#   [203]]
#
#  [[185]
#   [184]
#   [185]
#   ...
#   [202]
#   [201]
#   [203]]
#
#  ...
#
#  [[187]
#   [186]
#   [189]
#   ...
#   [206]
#   [207]
#   [206]]
#
#  [[185]
#   [186]
#   [188]
#   ...
#   [206]
#   [206]
#   [206]]
#
#  [[186]
#   [187]
#   [187]
#   ...
#   [205]
#   [206]
#   [206]]]
# Image: [[[198]
#   [198]
#   [199]
#   ...
#   [203]
#   [204]
#   [204]]
#
#  [[199]
#   [198]
#   [198]
#   ...
#   [204]
#   [204]
#   [205]]
#
#  [[201]
#   [200]
#   [198]
#   ...
#   [205]
#   [204]
#   [205]]
#
#  ...
#
#  [[195]
#   [196]
#   [198]
#   ...
#   [205]
#   [207]
#   [206]]
#
#  [[194]
#   [195]
#   [194]
#   ...
#   [206]
#   [207]
#   [207]]
#
#  [[194]
#   [194]
#   [195]
#   ...
#   [204]
#   [207]
#   [207]]]
# Image: [[[198]
#   [199]
#   [198]
#   ...
#   [205]
#   [205]
#   [204]]
#
#  [[199]
#   [198]
#   [197]
#   ...
#   [205]
#   [204]
#   [206]]
#
#  [[199]
#   [198]
#   [199]
#   ...
#   [205]
#   [205]
#   [205]]
#
#  ...
#
#  [[191]
#   [194]
#   [195]
#   ...
#   [200]
#   [199]
#   [200]]
#
#  [[192]
#   [192]
#   [194]
#   ...
#   [198]
#   [199]
#   [201]]
#
#  [[193]
#   [193]
#   [193]
#   ...
#   [199]
#   [199]
#   [199]]]
# Image: [[[132]
#   [135]
#   [131]
#   ...
#   [172]
#   [173]
#   [174]]
#
#  [[139]
#   [133]
#   [133]
#   ...
#   [173]
#   [173]
#   [173]]
#
#  [[138]
#   [139]
#   [137]
#   ...
#   [177]
#   [173]
#   [172]]
#
#  ...
#
#  [[165]
#   [165]
#   [170]
#   ...
#   [189]
#   [188]
#   [191]]
#
#  [[166]
#   [167]
#   [172]
#   ...
#   [187]
#   [189]
#   [191]]
#
#  [[167]
#   [169]
#   [169]
#   ...
#   [189]
#   [188]
#   [190]]]
# Image: [[[ 51]
#   [ 54]
#   [ 55]
#   ...
#   [ 74]
#   [ 76]
#   [ 80]]
#
#  [[ 54]
#   [ 57]
#   [ 58]
#   ...
#   [ 68]
#   [ 67]
#   [ 58]]
#
#  [[ 54]
#   [ 54]
#   [ 59]
#   ...
#   [ 71]
#   [ 68]
#   [ 66]]
#
#  ...
#
#  [[ 36]
#   [ 34]
#   [117]
#   ...
#   [ 48]
#   [ 50]
#   [ 50]]
#
#  [[ 39]
#   [ 49]
#   [139]
#   ...
#   [ 49]
#   [ 48]
#   [ 47]]
#
#  [[ 32]
#   [134]
#   [143]
#   ...
#   [ 47]
#   [ 46]
#   [ 47]]]
