# %% [markdown]
# ## Run a pipeline with data on a remote s3 bucket

# %% [markdown]
# This process will run the entire pipeline described in a configuration file. The input data is available in a remote s3 bucket.

# %% [markdown]
# ## Import dependencies

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline

# %% [markdown]
# ## Working with a public object store (https data)

# %% [markdown]
# When working with public object store, you just need to give as input path the paths of the files in the configuration file, as you can see in the example below:
#
# ```yaml
# general:
#   input_path: "https://paidiver-o.s3-ext.jc.rl.ac.uk/paidiverpy/data/lazy_load_benthic/"
#   output_path: "output"
#   metadata_path: "https://paidiver-o.s3-ext.jc.rl.ac.uk/paidiverpy/data/lazy_load_benthic/metadata_ifdo_hf.json"
# ```
#
# In this case, I am giving the path on the object store where all my images are storage. For the metadata path, you have to give the exact link of the metadata

# %%
pipeline = Pipeline(config_file_path="../config_files/config_object_store.yml")
# Out:
# Checking files have unique names 100/100

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square"
#             style="float:left; cursor: pointer; padding: 10px;
#             width: max-content; height: 80px; margin: 10px;
#             border: 1px solid #000; text-align: center; line-height: 80px;"
#             onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#         <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Colour_correction</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_1" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_1')">
#                     <h2 style="font-size:20px;">Datetime</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_2" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_2')">
#                     <h2 style="font-size:20px;">Colour_correction</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_3" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_3')">
#                     <h2 style="font-size:20px;">Sharpen</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#                 <div id="parameters_step_0" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "colour_correction",
#     "step_name": "colour",
#     "mode": "grayscale",
#     "test": false
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_1" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "datetime",
#     "step_name": "sampling",
#     "mode": "datetime",
#     "test": false,
#     "params": {
#         "min": "2016-05-11 04:14:00",
#         "max": "2016-05-11 09:27:00",
#         "raise_error": false
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_2" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "colour_correction",
#     "step_name": "colour",
#     "mode": "gaussian_blur",
#     "test": false,
#     "params": {
#         "sigma": 1.0,
#         "raise_error": false
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_3" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "sharpen",
#     "step_name": "colour",
#     "mode": "sharpen",
#     "test": false,
#     "params": {
#         "alpha": 1.5,
#         "beta": -0.5,
#         "raise_error": false
#     }
# }</pre>
#                 </div>
#
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "name": "raw",
#     "step_name": "open",
#     "sample_data": null,
#     "is_remote": true,
#     "input_path": "https://paidiver-o.s3-ext.jc.rl.ac.uk/paidiverpy/data/lazy_load_benthic/",
#     "metadata_path": "https://paidiver-o.s3-ext.jc.rl.ac.uk/paidiverpy/data/lazy_load_benthic/metadata_ifdo_hf.json",
#     "metadata_type": "IFDO",
#     "image_type": "JPG",
#     "append_data_to_metadata": false,
#     "output_is_remote": false,
#     "output_path": "output",
#     "n_jobs": 8,
#     "client": null,
#     "track_changes": true,
#     "rename": null,
#     "sampling": [
#         {
#             "name": "sampling",
#             "step_name": "sampling",
#             "mode": "percent",
#             "test": false,
#             "params": {
#                 "value": 0.1,
#                 "raise_error": false
#             }
#         }
#     ],
#     "convert": [
#         {
#             "name": "convert",
#             "step_name": "convert",
#             "mode": "bits",
#             "test": false,
#             "params": {
#                 "output_bits": 8,
#                 "raise_error": false
#             }
#         }
#     ]
# }</pre>
#             </div>
#         </div>
#         <script>
#             function showParameters(id) {
#                 // Hide all parameter sections
#                 var currentTarget = document.getElementById(id);
#                 var square = document.getElementsByClassName('square');
#                 var allParams = document.getElementsByClassName('parameters');
#                 var selectedParams = document.getElementById('parameters_' + id);
#                 var idWasVisible = false;
#                 if (selectedParams) {
#                     var idWasVisible = selectedParams.style.display === 'block';
#                 }
#                 for (var i = 0; i < square.length; i++) {
#                     square[i].style.color = 'black';
#                 }
#                 for (var i = 0; i < allParams.length; i++) {
#                     allParams[i].style.display = 'none';
#                 }
#                 // Show the selected parameter section
#                 if (selectedParams) {
#                     if (idWasVisible) {
#                         selectedParams.style.display = 'none';
#                         currentTarget.style.color = 'black';
#                     } else {
#                         selectedParams.style.display = 'block';
#                         currentTarget.style.color = 'red';
#                     }
#                 }
#             }
#         </script>

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:04 | Processing images using 8 cores
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:04 | Running step 0: raw - OpenLayer
# [########################################] | 100% Completed | 7.67 ss
# [########################################] | 100% Completed | 625.34 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:13 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:13 | Running step 1: colour_correction - ColourLayer
# [########################################] | 100% Completed | 206.56 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:14 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:14 | Running step 2: datetime - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:14 | Number of photos to be removed: 0
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:14 | Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:14 | Running step 3: colour_correction - ColourLayer
# [########################################] | 100% Completed | 206.34 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:15 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:15 | Running step 4: sharpen - ColourLayer
# [########################################] | 100% Completed | 4.27 sms
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:55:20 | Step 4 completed

# %%
# See the images output
# pipeline.images

# %% [markdown]
# ## Get files with a private object store with credentials
#
# Get files from a private object store. In this case, you need to pass the credentials of the object store as env variables:
#
# ```
# OS_SECRET=
# OS_TOKEN=
# OS_ENDPOINT=
# ```
#
# Normally, in this case, the path starts with "s3://", like  in the example below:
#
# ```yaml
# general:
#   input_path: "s3://paidiverpy/data/lazy_load_benthic/"
#   output_path: "s3://paidiverpy/data/lazy_load_benthic/output2/"
#   metadata_path: "s3://paidiverpy/data/lazy_load_benthic/metadata_ifdo_hf.json"
# ```

# %%
pipeline = Pipeline(config_file_path="../config_files/config_object_store2.yml")
# Out:
# Checking files have unique names 100/100

# %%
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:39 | Processing images using 8 cores
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:39 | Running step 0: raw - OpenLayer
# [########################################] | 100% Completed | 5.09 ss
# [                                        ] | 0% Completed | 105.83 ms☁ paidiverpy ☁  |    WARNING | 2025-02-24 13:30:44 | Unsupported output bits or image already within provided format: 8
# ☁ paidiverpy ☁  |    WARNING | 2025-02-24 13:30:44 | Unsupported output bits or image already within provided format: 8
# ☁ paidiverpy ☁  |    WARNING | 2025-02-24 13:30:44 | Unsupported output bits or image already within provided format: 8
# [##############                          ] | 35% Completed | 207.51 ms☁ paidiverpy ☁  |    WARNING | 2025-02-24 13:30:44 | Unsupported output bits or image already within provided format: 8
# ☁ paidiverpy ☁  |    WARNING | 2025-02-24 13:30:44 | Unsupported output bits or image already within provided format: 8
# [####################                    ] | 50% Completed | 308.88 ms☁ paidiverpy ☁  |    WARNING | 2025-02-24 13:30:44 | Unsupported output bits or image already within provided format: 8
# ☁ paidiverpy ☁  |    WARNING | 2025-02-24 13:30:44 | Unsupported output bits or image already within provided format: 8
# [############################            ] | 70% Completed | 413.37 ms☁ paidiverpy ☁  |    WARNING | 2025-02-24 13:30:45 | Unsupported output bits or image already within provided format: 8
# ☁ paidiverpy ☁  |    WARNING | 2025-02-24 13:30:45 | Unsupported output bits or image already within provided format: 8
# ☁ paidiverpy ☁  |    WARNING | 2025-02-24 13:30:45 | Unsupported output bits or image already within provided format: 8
# [########################################] | 100% Completed | 515.98 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:45 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:45 | Running step 1: colour_correction - ColourLayer
# [########################################] | 100% Completed | 106.13 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:46 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:46 | Running step 2: datetime - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:46 | Number of photos to be removed: 0
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:46 | Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:46 | Running step 3: colour_correction - ColourLayer
# [########################################] | 100% Completed | 207.39 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:47 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:47 | Running step 4: sharpen - ColourLayer
# [########################################] | 100% Completed | 3.18 sms
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:30:50 | Step 4 completed

# %%
pipeline.images
# Out:
# Step: raw
# Image: dask.array<array, shape=(10173, 1784, 3), dtype=uint8, chunksize=(10173, 1784, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10912, 2643, 3), dtype=uint8, chunksize=(10912, 2643, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10390, 2631, 3), dtype=uint8, chunksize=(10390, 2631, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10419, 2654, 3), dtype=uint8, chunksize=(10419, 2654, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429, 3), dtype=uint8, chunksize=(10507, 2429, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10351, 2390, 3), dtype=uint8, chunksize=(10351, 2390, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10550, 2278, 3), dtype=uint8, chunksize=(10550, 2278, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12461, 2481, 3), dtype=uint8, chunksize=(12461, 2481, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10255, 2641, 3), dtype=uint8, chunksize=(10255, 2641, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10397, 2760, 3), dtype=uint8, chunksize=(10397, 2760, 3), chunktype=numpy.ndarray>
# Step: colour_correction
# Image: dask.array<array, shape=(10173, 1784), dtype=uint8, chunksize=(10173, 1784), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10912, 2643), dtype=uint8, chunksize=(10912, 2643), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10390, 2631), dtype=uint8, chunksize=(10390, 2631), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10419, 2654), dtype=uint8, chunksize=(10419, 2654), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10351, 2390), dtype=uint8, chunksize=(10351, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10550, 2278), dtype=uint8, chunksize=(10550, 2278), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12461, 2481), dtype=uint8, chunksize=(12461, 2481), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10255, 2641), dtype=uint8, chunksize=(10255, 2641), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10397, 2760), dtype=uint8, chunksize=(10397, 2760), chunktype=numpy.ndarray>
# Step: datetime
# Image: dask.array<array, shape=(10173, 1784), dtype=uint8, chunksize=(10173, 1784), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10912, 2643), dtype=uint8, chunksize=(10912, 2643), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10390, 2631), dtype=uint8, chunksize=(10390, 2631), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10419, 2654), dtype=uint8, chunksize=(10419, 2654), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10351, 2390), dtype=uint8, chunksize=(10351, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10550, 2278), dtype=uint8, chunksize=(10550, 2278), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12461, 2481), dtype=uint8, chunksize=(12461, 2481), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10255, 2641), dtype=uint8, chunksize=(10255, 2641), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10397, 2760), dtype=uint8, chunksize=(10397, 2760), chunktype=numpy.ndarray>
# Step: colour_correction
# Image: dask.array<array, shape=(10173, 1784), dtype=uint8, chunksize=(10173, 1784), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10912, 2643), dtype=uint8, chunksize=(10912, 2643), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10390, 2631), dtype=uint8, chunksize=(10390, 2631), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10419, 2654), dtype=uint8, chunksize=(10419, 2654), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10351, 2390), dtype=uint8, chunksize=(10351, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10550, 2278), dtype=uint8, chunksize=(10550, 2278), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12461, 2481), dtype=uint8, chunksize=(12461, 2481), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10255, 2641), dtype=uint8, chunksize=(10255, 2641), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10397, 2760), dtype=uint8, chunksize=(10397, 2760), chunktype=numpy.ndarray>
# Step: sharpen
# Image: dask.array<array, shape=(10173, 1784), dtype=uint8, chunksize=(10173, 1784), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10912, 2643), dtype=uint8, chunksize=(10912, 2643), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10390, 2631), dtype=uint8, chunksize=(10390, 2631), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10419, 2654), dtype=uint8, chunksize=(10419, 2654), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10507, 2429), dtype=uint8, chunksize=(10507, 2429), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10351, 2390), dtype=uint8, chunksize=(10351, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10550, 2278), dtype=uint8, chunksize=(10550, 2278), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12461, 2481), dtype=uint8, chunksize=(12461, 2481), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10255, 2641), dtype=uint8, chunksize=(10255, 2641), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10397, 2760), dtype=uint8, chunksize=(10397, 2760), chunktype=numpy.ndarray>

# %% [markdown]
# # Export Images to file

# %% [markdown]
# In this case, the images will be saved in the object store, in the path provided

# %%
pipeline.save_images(image_format="png")
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:33:38 | Saving images from step: last
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:33:38 | Uploading images to S3 using Dask
# [########################################] | 100% Completed | 63.51 ss
# ☁ paidiverpy ☁  |       INFO | 2025-02-24 13:34:42 | Images are saved to: s3://paidiverpy/data/lazy_load_benthic/output2/
