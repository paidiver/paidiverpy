# %% [markdown]
# ## Run a pipeline

# %% [markdown]
# This process will run the entire pipeline described in a configuration file

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline

# %%
pipeline = Pipeline(config_file_path="../config_files/config_object_store.yaml")
# Out:
# Checking files have unique names 100/100

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square"
#             style="float:left; cursor: pointer; padding: 10px;
#             width: max-content; height: 80px; margin: 10px;
#             border: 1px solid #000; text-align: center; line-height: 80px;"
#             onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#         <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Colour_correction</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_1" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_1')">
#                     <h2 style="font-size:20px;">Datetime</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_2" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_2')">
#                     <h2 style="font-size:20px;">Colour_correction</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_3" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_3')">
#                     <h2 style="font-size:20px;">Sharpen</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#                 <div id="parameters_step_0" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "colour_correction",
#     "step_name": "colour",
#     "mode": "grayscale",
#     "test": false
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_1" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "datetime",
#     "step_name": "sampling",
#     "mode": "datetime",
#     "test": false,
#     "params": {
#         "min": "2016-05-11 04:14:00",
#         "max": "2016-05-11 09:27:00"
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_2" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "colour_correction",
#     "step_name": "colour",
#     "mode": "gaussian_blur",
#     "test": false,
#     "params": {
#         "sigma": 1.0
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_3" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "sharpen",
#     "step_name": "colour",
#     "mode": "sharpen",
#     "test": false,
#     "params": {
#         "alpha": 1.5,
#         "beta": -0.5
#     }
# }</pre>
#                 </div>
#
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "name": "raw",
#     "step_name": "open",
#     "sample_data": null,
#     "is_remote": true,
#     "input_path": "https://paidiver-o.s3-ext.jc.rl.ac.uk/paidiverpy/data/lazy_load_benthic/",
#     "metadata_path": "https://paidiver-o.s3-ext.jc.rl.ac.uk/paidiverpy/data/lazy_load_benthic/metadata_ifdo_hf.json",
#     "metadata_type": "IFDO",
#     "image_type": "JPG",
#     "append_data_to_metadata": false,
#     "output_is_remote": false,
#     "output_path": "output",
#     "n_jobs": 8,
#     "client": null,
#     "track_changes": true,
#     "rename": null,
#     "sampling": [
#         {
#             "name": "sampling",
#             "step_name": "sampling",
#             "mode": "percent",
#             "test": false,
#             "params": {
#                 "value": 0.1
#             }
#         }
#     ],
#     "convert": [
#         {
#             "name": "convert",
#             "step_name": "convert",
#             "mode": "bits",
#             "test": false,
#             "params": {
#                 "output_bits": 8
#             }
#         }
#     ]
# }</pre>
#             </div>
#         </div>
#         <script>
#             function showParameters(id) {
#                 // Hide all parameter sections
#                 var currentTarget = document.getElementById(id);
#                 var square = document.getElementsByClassName('square');
#                 var allParams = document.getElementsByClassName('parameters');
#                 var selectedParams = document.getElementById('parameters_' + id);
#                 var idWasVisible = false;
#                 if (selectedParams) {
#                     var idWasVisible = selectedParams.style.display === 'block';
#                 }
#                 for (var i = 0; i < square.length; i++) {
#                     square[i].style.color = 'black';
#                 }
#                 for (var i = 0; i < allParams.length; i++) {
#                     allParams[i].style.display = 'none';
#                 }
#                 // Show the selected parameter section
#                 if (selectedParams) {
#                     if (idWasVisible) {
#                         selectedParams.style.display = 'none';
#                         currentTarget.style.color = 'black';
#                     } else {
#                         selectedParams.style.display = 'block';
#                         currentTarget.style.color = 'red';
#                     }
#                 }
#             }
#         </script>

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:32:27 | Processing images using 8 cores
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:32:27 | Running step 0: raw - OpenLayer
# [########################################] | 100% Completed | 48.60 s
# [########################################] | 100% Completed | 624.98 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:33:18 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:33:18 | Running step 1: colour_correction - ColourLayer
# [########################################] | 100% Completed | 205.15 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:33:19 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:33:19 | Running step 2: datetime - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:33:19 | Number of photos to be removed: 0
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:33:19 | Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:33:19 | Running step 3: colour_correction - ColourLayer
# [########################################] | 100% Completed | 213.09 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:33:20 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:33:20 | Running step 4: sharpen - ColourLayer
# [########################################] | 100% Completed | 3.88 sms
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 17:33:25 | Step 4 completed

# %%
# See the images output
# pipeline.images

# %% [markdown]
# ## Get files with a private object store with credentials
#
# Get files from a private object store. In this case, you need to pass the credentials of the object store

# %%
pipeline = Pipeline(config_file_path="../config_files/config_object_store2.yaml")
# Out:
# Checking files have unique names 100/100

# %%
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:16 | Processing images using 8 cores
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:16 | Running step 0: raw - OpenLayer
# [########################################] | 100% Completed | 7.69 ss
# [########################################] | 100% Completed | 616.02 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:26 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:26 | Running step 1: colour_correction - ColourLayer
# [########################################] | 100% Completed | 103.96 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:26 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:26 | Running step 2: datetime - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:26 | Number of photos to be removed: 0
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:27 | Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:27 | Running step 3: colour_correction - ColourLayer
# [########################################] | 100% Completed | 205.28 ms
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:27 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:27 | Running step 4: sharpen - ColourLayer
# [########################################] | 100% Completed | 2.90 sms
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:31 | Step 4 completed

# %%
pipeline.images
# Out:
# Step: raw
# Image: dask.array<array, shape=(10543, 2213, 3), dtype=uint8, chunksize=(10543, 2213, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10125, 2475, 3), dtype=uint8, chunksize=(10125, 2475, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9257, 2307, 3), dtype=uint8, chunksize=(9257, 2307, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636, 3), dtype=uint8, chunksize=(10439, 2636, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10400, 2394, 3), dtype=uint8, chunksize=(10400, 2394, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10072, 2572, 3), dtype=uint8, chunksize=(10072, 2572, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660, 3), dtype=uint8, chunksize=(10485, 2660, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324, 3), dtype=uint8, chunksize=(10298, 2324, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12461, 2481, 3), dtype=uint8, chunksize=(12461, 2481, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411, 3), dtype=uint8, chunksize=(12256, 2411, 3), chunktype=numpy.ndarray>
# Step: colour_correction
# Image: dask.array<array, shape=(10543, 2213), dtype=uint8, chunksize=(10543, 2213), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10125, 2475), dtype=uint8, chunksize=(10125, 2475), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9257, 2307), dtype=uint8, chunksize=(9257, 2307), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636), dtype=uint8, chunksize=(10439, 2636), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10400, 2394), dtype=uint8, chunksize=(10400, 2394), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10072, 2572), dtype=uint8, chunksize=(10072, 2572), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660), dtype=uint8, chunksize=(10485, 2660), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324), dtype=uint8, chunksize=(10298, 2324), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12461, 2481), dtype=uint8, chunksize=(12461, 2481), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411), dtype=uint8, chunksize=(12256, 2411), chunktype=numpy.ndarray>
# Step: datetime
# Image: dask.array<array, shape=(10543, 2213), dtype=uint8, chunksize=(10543, 2213), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10125, 2475), dtype=uint8, chunksize=(10125, 2475), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9257, 2307), dtype=uint8, chunksize=(9257, 2307), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636), dtype=uint8, chunksize=(10439, 2636), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10400, 2394), dtype=uint8, chunksize=(10400, 2394), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10072, 2572), dtype=uint8, chunksize=(10072, 2572), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660), dtype=uint8, chunksize=(10485, 2660), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324), dtype=uint8, chunksize=(10298, 2324), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12461, 2481), dtype=uint8, chunksize=(12461, 2481), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411), dtype=uint8, chunksize=(12256, 2411), chunktype=numpy.ndarray>
# Step: colour_correction
# Image: dask.array<array, shape=(10543, 2213), dtype=uint8, chunksize=(10543, 2213), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10125, 2475), dtype=uint8, chunksize=(10125, 2475), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9257, 2307), dtype=uint8, chunksize=(9257, 2307), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636), dtype=uint8, chunksize=(10439, 2636), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10400, 2394), dtype=uint8, chunksize=(10400, 2394), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10072, 2572), dtype=uint8, chunksize=(10072, 2572), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660), dtype=uint8, chunksize=(10485, 2660), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324), dtype=uint8, chunksize=(10298, 2324), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12461, 2481), dtype=uint8, chunksize=(12461, 2481), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411), dtype=uint8, chunksize=(12256, 2411), chunktype=numpy.ndarray>
# Step: sharpen
# Image: dask.array<array, shape=(10543, 2213), dtype=uint8, chunksize=(10543, 2213), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10125, 2475), dtype=uint8, chunksize=(10125, 2475), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(9257, 2307), dtype=uint8, chunksize=(9257, 2307), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10439, 2636), dtype=uint8, chunksize=(10439, 2636), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10400, 2394), dtype=uint8, chunksize=(10400, 2394), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10072, 2572), dtype=uint8, chunksize=(10072, 2572), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10485, 2660), dtype=uint8, chunksize=(10485, 2660), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10298, 2324), dtype=uint8, chunksize=(10298, 2324), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12461, 2481), dtype=uint8, chunksize=(12461, 2481), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(12256, 2411), dtype=uint8, chunksize=(12256, 2411), chunktype=numpy.ndarray>

# %% [markdown]
# # Export Images to file

# %%
pipeline.save_images(image_format="png")
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:32 | Saving images from step: last
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:11:34 | Uploading images to S3 using Dask
# [########################################] | 100% Completed | 173.32 s
# ☁ paidiverpy ☁  |       INFO | 2025-02-04 19:14:27 | Images are saved to: s3://paidiverpy-test/data/lazy_load_benthic/output/
