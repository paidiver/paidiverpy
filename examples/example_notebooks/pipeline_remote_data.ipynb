# %% [markdown]
# ## Run a pipeline with data on a remote s3 bucket

# %% [markdown]
# This process will run the entire pipeline described in a configuration file. The input data is available in a remote s3 bucket.

# %% [markdown]
# ## Import dependencies

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline

# %% [markdown]
# ## Working with a public object store (https data)

# %% [markdown]
# When working with public object store, you just need to give as input path the paths of the files in the configuration file, as you can see in the example below:
#
# ```yaml
# general:
#   input_path: "https://paidiver-o.s3-ext.jc.rl.ac.uk/paidiverpy/data/lazy_load_benthic/"
#   output_path: "output"
#   metadata_path: "https://paidiver-o.s3-ext.jc.rl.ac.uk/paidiverpy/data/lazy_load_benthic/metadata_ifdo_hf.json"
# ```
#
# In this case, I am giving the path on the object store where all my images are storage. For the metadata path, you have to give the exact link of the metadata

# %%
pipeline = Pipeline(config_file_path="../config_files/config_object_store.yml")
# Out:
# ☁ paidiverpy ☁  |    WARNING | 2025-03-06 10:30:24 | Failed to validate the IFDO metadata.
# You can continue, but some functions may not work properly.
# Please set verbose to 3 (DEBUG) to see the validation errors.
# ☁ paidiverpy ☁  |    WARNING | 2025-03-06 10:30:24 | Metadata does not have a image-altitude-meters type column. It should have one of the following columns: ['image-altitude-meters', 'depth', 'depth_m', 'depth_metres', 'depth_metre', 'depth_meters', 'depth_meter']
# ☁ paidiverpy ☁  |    WARNING | 2025-03-06 10:30:24 | Some functions may not work properly.

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square"
#             style="float:left; cursor: pointer; padding: 10px;
#             width: max-content; height: 80px; margin: 10px;
#             border: 1px solid #000; text-align: center; line-height: 80px;"
#             onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#         <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Colour_correction</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_1" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_1')">
#                     <h2 style="font-size:20px;">Datetime</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_2" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_2')">
#                     <h2 style="font-size:20px;">Colour_correction</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_3" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_3')">
#                     <h2 style="font-size:20px;">Sharpen</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#                 <div id="parameters_step_0" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "colour_correction",
#     "step_name": "colour",
#     "mode": "grayscale",
#     "test": false
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_1" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "datetime",
#     "step_name": "sampling",
#     "mode": "datetime",
#     "test": false,
#     "params": {
#         "min": "2016-05-11 04:14:00",
#         "max": "2016-05-11 09:27:00",
#         "raise_error": false
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_2" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "colour_correction",
#     "step_name": "colour",
#     "mode": "gaussian_blur",
#     "test": false,
#     "params": {
#         "sigma": 1.0,
#         "raise_error": false
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_3" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "sharpen",
#     "step_name": "colour",
#     "mode": "sharpen",
#     "test": false,
#     "params": {
#         "alpha": 1.5,
#         "beta": -0.5,
#         "raise_error": false
#     }
# }</pre>
#                 </div>
#
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "name": "raw",
#     "step_name": "open",
#     "sample_data": null,
#     "is_remote": true,
#     "input_path": "https://paidiver-o.s3-ext.jc.rl.ac.uk/paidiverpy/data/lazy_load_benthic/",
#     "metadata_path": "https://paidiver-o.s3-ext.jc.rl.ac.uk/paidiverpy/data/lazy_load_benthic/metadata_ifdo_hf.json",
#     "metadata_type": "IFDO",
#     "image_type": "JPG",
#     "append_data_to_metadata": false,
#     "output_is_remote": false,
#     "output_path": "output",
#     "n_jobs": 8,
#     "client": null,
#     "track_changes": true,
#     "rename": null,
#     "sampling": [
#         {
#             "name": "sampling",
#             "step_name": "sampling",
#             "mode": "percent",
#             "test": false,
#             "params": {
#                 "value": 0.1,
#                 "raise_error": false
#             }
#         }
#     ],
#     "convert": [
#         {
#             "name": "convert",
#             "step_name": "convert",
#             "mode": "bits",
#             "test": false,
#             "params": {
#                 "output_bits": 8,
#                 "raise_error": false
#             }
#         }
#     ]
# }</pre>
#             </div>
#         </div>
#         <script>
#             function showParameters(id) {
#                 // Hide all parameter sections
#                 var currentTarget = document.getElementById(id);
#                 var square = document.getElementsByClassName('square');
#                 var allParams = document.getElementsByClassName('parameters');
#                 var selectedParams = document.getElementById('parameters_' + id);
#                 var idWasVisible = false;
#                 if (selectedParams) {
#                     var idWasVisible = selectedParams.style.display === 'block';
#                 }
#                 for (var i = 0; i < square.length; i++) {
#                     square[i].style.color = 'black';
#                 }
#                 for (var i = 0; i < allParams.length; i++) {
#                     allParams[i].style.display = 'none';
#                 }
#                 // Show the selected parameter section
#                 if (selectedParams) {
#                     if (idWasVisible) {
#                         selectedParams.style.display = 'none';
#                         currentTarget.style.color = 'black';
#                     } else {
#                         selectedParams.style.display = 'block';
#                         currentTarget.style.color = 'red';
#                     }
#                 }
#             }
#         </script>

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:25 | Processing images using 8 cores
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:25 | Running step 0: raw - OpenLayer
# [                                        ] | 0% Completed | 474.66 us
# [                                        ] | 0% Completed | 102.71 ms
# [                                        ] | 0% Completed | 205.26 ms
# [                                        ] | 0% Completed | 306.58 ms
# [                                        ] | 0% Completed | 407.54 ms
# [                                        ] | 0% Completed | 508.39 ms
# [                                        ] | 0% Completed | 610.08 ms
# [                                        ] | 0% Completed | 711.14 ms
# [                                        ] | 0% Completed | 812.33 ms
# [                                        ] | 0% Completed | 913.19 ms
# [                                        ] | 0% Completed | 1.01 s
# [                                        ] | 0% Completed | 1.12 s
# [                                        ] | 0% Completed | 1.22 s
# [                                        ] | 0% Completed | 1.32 s
# [                                        ] | 0% Completed | 1.42 s
# [                                        ] | 0% Completed | 1.52 s
# [                                        ] | 0% Completed | 1.62 s
# [                                        ] | 0% Completed | 1.72 s
# [                                        ] | 0% Completed | 1.82 s
# [                                        ] | 0% Completed | 1.93 s
# [                                        ] | 0% Completed | 2.03 s
# [                                        ] | 0% Completed | 2.13 s
# [                                        ] | 0% Completed | 2.23 s
# [                                        ] | 0% Completed | 2.33 s
# [####                                    ] | 10% Completed | 2.44 s
# [####                                    ] | 10% Completed | 2.54 s
# [####                                    ] | 10% Completed | 2.64 s
# [####                                    ] | 10% Completed | 2.74 s
# [####                                    ] | 10% Completed | 2.84 s
# [####                                    ] | 10% Completed | 2.94 s
# [########                                ] | 20% Completed | 3.05 s
# [########                                ] | 20% Completed | 3.15 s
# [########                                ] | 20% Completed | 3.25 s
# [########                                ] | 20% Completed | 3.35 s
# [########                                ] | 20% Completed | 3.46 s
# [########                                ] | 20% Completed | 3.56 s
# [############                            ] | 30% Completed | 3.66 s
# [############                            ] | 30% Completed | 3.76 s
# [############                            ] | 30% Completed | 3.87 s
# [####################                    ] | 50% Completed | 3.97 s
# [############################            ] | 70% Completed | 4.07 s
# [############################            ] | 70% Completed | 4.17 s
# [################################        ] | 80% Completed | 4.27 s
# [################################        ] | 80% Completed | 4.38 s
# [################################        ] | 80% Completed | 4.48 s
# [################################        ] | 80% Completed | 4.58 s
# [################################        ] | 80% Completed | 4.68 s
# [################################        ] | 80% Completed | 4.79 s
# [################################        ] | 80% Completed | 4.89 s
# [####################################    ] | 90% Completed | 4.99 s
# [####################################    ] | 90% Completed | 5.09 s
# [####################################    ] | 90% Completed | 5.20 s
# [####################################    ] | 90% Completed | 5.30 s
# [####################################    ] | 90% Completed | 5.40 s
# [####################################    ] | 90% Completed | 5.50 s
# [########################################] | 100% Completed | 5.60 s
# [                                        ] | 0% Completed | 729.03 us
# [                                        ] | 0% Completed | 106.08 ms
# WARNING:root:Unsupported output bits or image already within provided format: 8
# WARNING:root:Unsupported output bits or image already within provided format: 8
# WARNING:root:Unsupported output bits or image already within provided format: 8
# WARNING:root:Unsupported output bits or image already within provided format: 8
# [################                        ] | 40% Completed | 208.90 ms
# WARNING:root:Unsupported output bits or image already within provided format: 8
# [####################                    ] | 50% Completed | 311.43 ms
# WARNING:root:Unsupported output bits or image already within provided format: 8
# WARNING:root:Unsupported output bits or image already within provided format: 8
# WARNING:root:Unsupported output bits or image already within provided format: 8
# WARNING:root:Unsupported output bits or image already within provided format: 8
# [###################################     ] | 87% Completed | 418.26 ms
# WARNING:root:Unsupported output bits or image already within provided format: 8
# [########################################] | 100% Completed | 521.75 ms
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:32 | Step 0 completed
# INFO:paidiverpy:Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:32 | Running step 1: colour_correction - ColourLayer
# INFO:paidiverpy:Running step 1: colour_correction - ColourLayer
# [                                        ] | 0% Completed | 507.26 us
# [########################################] | 100% Completed | 103.62 ms
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:32 | Step 1 completed
# INFO:paidiverpy:Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:32 | Running step 2: datetime - ResampleLayer
# INFO:paidiverpy:Running step 2: datetime - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:32 | Number of photos to be removed: 0
# INFO:paidiverpy:Number of photos to be removed: 0
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:32 | Step 2 completed
# INFO:paidiverpy:Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:32 | Running step 3: colour_correction - ColourLayer
# INFO:paidiverpy:Running step 3: colour_correction - ColourLayer
# [                                        ] | 0% Completed | 942.82 us
# [######################################  ] | 95% Completed | 106.27 ms
# [########################################] | 100% Completed | 208.77 ms
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:33 | Step 3 completed
# INFO:paidiverpy:Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:33 | Running step 4: sharpen - ColourLayer
# INFO:paidiverpy:Running step 4: sharpen - ColourLayer
# [                                        ] | 0% Completed | 905.54 us
# [################                        ] | 40% Completed | 105.41 ms
# [################                        ] | 40% Completed | 210.69 ms
# [################                        ] | 40% Completed | 317.74 ms
# [################                        ] | 40% Completed | 425.99 ms
# [################                        ] | 40% Completed | 530.17 ms
# [################                        ] | 40% Completed | 636.72 ms
# [################                        ] | 40% Completed | 746.54 ms
# [################                        ] | 40% Completed | 849.02 ms
# [################                        ] | 40% Completed | 950.49 ms
# [################                        ] | 40% Completed | 1.06 s
# [####################                    ] | 50% Completed | 1.16 s
# [####################                    ] | 50% Completed | 1.26 s
# [########################                ] | 60% Completed | 1.36 s
# [########################                ] | 60% Completed | 1.46 s
# [##########################              ] | 65% Completed | 1.56 s
# [##########################              ] | 65% Completed | 1.67 s
# [##########################              ] | 65% Completed | 1.78 s
# [##########################              ] | 65% Completed | 1.88 s
# [##########################              ] | 65% Completed | 1.99 s
# [############################            ] | 70% Completed | 2.09 s
# [############################            ] | 70% Completed | 2.19 s
# [##############################          ] | 75% Completed | 2.30 s
# [##############################          ] | 75% Completed | 2.41 s
# [##############################          ] | 75% Completed | 2.51 s
# [################################        ] | 80% Completed | 2.62 s
# [################################        ] | 80% Completed | 2.73 s
# [################################        ] | 80% Completed | 2.84 s
# [####################################    ] | 90% Completed | 2.95 s
# [####################################    ] | 90% Completed | 3.06 s
# [####################################    ] | 90% Completed | 3.16 s
# [######################################  ] | 95% Completed | 3.26 s
# [######################################  ] | 95% Completed | 3.37 s
# [########################################] | 100% Completed | 3.47 s
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:37 | Step 4 completed
# INFO:paidiverpy:Step 4 completed

# %%
# See the images output
# pipeline.images

# %% [markdown]
# ## Get files with a private object store with credentials
#
# Get files from a private object store. In this case, you need to pass the credentials of the object store as env variables:
#
# ```
# OS_SECRET=
# OS_TOKEN=
# OS_ENDPOINT=
# ```
#
# Normally, in this case, the path starts with "s3://", like  in the example below:
#
# ```yaml
# general:
#   input_path: "s3://paidiverpy/data/lazy_load_benthic/"
#   output_path: "s3://paidiverpy/data/lazy_load_benthic/output2/"
#   metadata_path: "s3://paidiverpy/data/lazy_load_benthic/metadata_ifdo_hf.json"
# ```

# %%
pipeline = Pipeline(config_file_path="../config_files/config_object_store2.yml")
# Out:
# ☁ paidiverpy ☁  |    WARNING | 2025-03-06 10:30:38 | Failed to validate the IFDO metadata.
# You can continue, but some functions may not work properly.
# Please set verbose to 3 (DEBUG) to see the validation errors.
# WARNING:paidiverpy:Failed to validate the IFDO metadata.
# You can continue, but some functions may not work properly.
# Please set verbose to 3 (DEBUG) to see the validation errors.
# ☁ paidiverpy ☁  |    WARNING | 2025-03-06 10:30:38 | Metadata does not have a image-altitude-meters type column. It should have one of the following columns: ['image-altitude-meters', 'depth', 'depth_m', 'depth_metres', 'depth_metre', 'depth_meters', 'depth_meter']
# WARNING:paidiverpy:Metadata does not have a image-altitude-meters type column. It should have one of the following columns: ['image-altitude-meters', 'depth', 'depth_m', 'depth_metres', 'depth_metre', 'depth_meters', 'depth_meter']
# ☁ paidiverpy ☁  |    WARNING | 2025-03-06 10:30:38 | Some functions may not work properly.
# WARNING:paidiverpy:Some functions may not work properly.

# %%
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:38 | Processing images using 8 cores
# INFO:paidiverpy:Processing images using 8 cores
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:38 | Running step 0: raw - OpenLayer
# INFO:paidiverpy:Running step 0: raw - OpenLayer
# [                                        ] | 0% Completed | 545.35 us
# [                                        ] | 0% Completed | 105.43 ms
# [                                        ] | 0% Completed | 207.66 ms
# [                                        ] | 0% Completed | 309.91 ms
# [                                        ] | 0% Completed | 411.07 ms
# [                                        ] | 0% Completed | 512.09 ms
# [                                        ] | 0% Completed | 613.24 ms
# [                                        ] | 0% Completed | 716.45 ms
# [                                        ] | 0% Completed | 818.79 ms
# [                                        ] | 0% Completed | 919.87 ms
# [                                        ] | 0% Completed | 1.02 s
# [                                        ] | 0% Completed | 1.12 s
# [                                        ] | 0% Completed | 1.22 s
# [                                        ] | 0% Completed | 1.32 s
# [                                        ] | 0% Completed | 1.42 s
# [                                        ] | 0% Completed | 1.53 s
# [                                        ] | 0% Completed | 1.63 s
# [                                        ] | 0% Completed | 1.73 s
# [                                        ] | 0% Completed | 1.83 s
# [                                        ] | 0% Completed | 1.94 s
# [                                        ] | 0% Completed | 2.04 s
# [                                        ] | 0% Completed | 2.14 s
# [                                        ] | 0% Completed | 2.24 s
# [                                        ] | 0% Completed | 2.35 s
# [                                        ] | 0% Completed | 2.45 s
# [                                        ] | 0% Completed | 2.55 s
# [                                        ] | 0% Completed | 2.65 s
# [                                        ] | 0% Completed | 2.75 s
# [                                        ] | 0% Completed | 2.85 s
# [                                        ] | 0% Completed | 2.95 s
# [                                        ] | 0% Completed | 3.05 s
# [                                        ] | 0% Completed | 3.16 s
# [                                        ] | 0% Completed | 3.26 s
# [                                        ] | 0% Completed | 3.36 s
# [                                        ] | 0% Completed | 3.46 s
# [####                                    ] | 10% Completed | 3.56 s
# [####                                    ] | 10% Completed | 3.66 s
# [########                                ] | 20% Completed | 3.76 s
# [########                                ] | 20% Completed | 3.87 s
# [########                                ] | 20% Completed | 3.97 s
# [########                                ] | 20% Completed | 4.07 s
# [########                                ] | 20% Completed | 4.17 s
# [########                                ] | 20% Completed | 4.27 s
# [########                                ] | 20% Completed | 4.37 s
# [########                                ] | 20% Completed | 4.48 s
# [########                                ] | 20% Completed | 4.58 s
# [########                                ] | 20% Completed | 4.68 s
# [########                                ] | 20% Completed | 4.78 s
# [########                                ] | 20% Completed | 4.89 s
# [########                                ] | 20% Completed | 4.99 s
# [########                                ] | 20% Completed | 5.10 s
# [####################                    ] | 50% Completed | 5.23 s
# [########################                ] | 60% Completed | 5.34 s
# [################################        ] | 80% Completed | 5.44 s
# [################################        ] | 80% Completed | 5.55 s
# [################################        ] | 80% Completed | 5.65 s
# [################################        ] | 80% Completed | 5.75 s
# [################################        ] | 80% Completed | 5.85 s
# [####################################    ] | 90% Completed | 5.96 s
# [########################################] | 100% Completed | 6.06 s
# [                                        ] | 0% Completed | 533.88 us
# [                                        ] | 0% Completed | 105.12 ms
# [####                                    ] | 10% Completed | 207.80 ms
# [########                                ] | 20% Completed | 309.16 ms
# [####################                    ] | 50% Completed | 421.50 ms
# [########################                ] | 60% Completed | 524.68 ms
# [############################            ] | 70% Completed | 628.47 ms
# [########################################] | 100% Completed | 735.90 ms
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:46 | Step 0 completed
# INFO:paidiverpy:Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:46 | Running step 1: colour_correction - ColourLayer
# INFO:paidiverpy:Running step 1: colour_correction - ColourLayer
# [                                        ] | 0% Completed | 743.82 us
# [############################            ] | 70% Completed | 104.85 ms
# [########################################] | 100% Completed | 205.99 ms
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:47 | Step 1 completed
# INFO:paidiverpy:Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:47 | Running step 2: datetime - ResampleLayer
# INFO:paidiverpy:Running step 2: datetime - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:47 | Number of photos to be removed: 0
# INFO:paidiverpy:Number of photos to be removed: 0
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:47 | Step 2 completed
# INFO:paidiverpy:Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:47 | Running step 3: colour_correction - ColourLayer
# INFO:paidiverpy:Running step 3: colour_correction - ColourLayer
# [                                        ] | 0% Completed | 918.19 us
# [##########################              ] | 65% Completed | 105.14 ms
# [######################################  ] | 95% Completed | 210.42 ms
# [########################################] | 100% Completed | 313.18 ms
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:48 | Step 3 completed
# INFO:paidiverpy:Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:48 | Running step 4: sharpen - ColourLayer
# INFO:paidiverpy:Running step 4: sharpen - ColourLayer
# [                                        ] | 0% Completed | 1.07 ms
# [################                        ] | 40% Completed | 108.71 ms
# [################                        ] | 40% Completed | 211.00 ms
# [################                        ] | 40% Completed | 312.54 ms
# [################                        ] | 40% Completed | 416.42 ms
# [################                        ] | 40% Completed | 520.41 ms
# [################                        ] | 40% Completed | 624.22 ms
# [################                        ] | 40% Completed | 728.23 ms
# [################                        ] | 40% Completed | 832.15 ms
# [################                        ] | 40% Completed | 946.73 ms
# [################                        ] | 40% Completed | 1.05 s
# [########################                ] | 60% Completed | 1.16 s
# [##########################              ] | 65% Completed | 1.26 s
# [##########################              ] | 65% Completed | 1.37 s
# [##########################              ] | 65% Completed | 1.54 s
# [############################            ] | 70% Completed | 1.65 s
# [############################            ] | 70% Completed | 1.76 s
# [############################            ] | 70% Completed | 1.86 s
# [############################            ] | 70% Completed | 1.97 s
# [############################            ] | 70% Completed | 2.07 s
# [############################            ] | 70% Completed | 2.17 s
# [############################            ] | 70% Completed | 2.28 s
# [##############################          ] | 75% Completed | 2.39 s
# [##############################          ] | 75% Completed | 2.49 s
# [##############################          ] | 75% Completed | 2.60 s
# [##############################          ] | 75% Completed | 2.71 s
# [################################        ] | 80% Completed | 2.81 s
# [################################        ] | 80% Completed | 2.92 s
# [################################        ] | 80% Completed | 3.02 s
# [################################        ] | 80% Completed | 3.13 s
# [################################        ] | 80% Completed | 3.23 s
# [################################        ] | 80% Completed | 3.34 s
# [################################        ] | 80% Completed | 3.45 s
# [##################################      ] | 85% Completed | 3.55 s
# [##################################      ] | 85% Completed | 3.66 s
# [##################################      ] | 85% Completed | 3.76 s
# [##################################      ] | 85% Completed | 3.87 s
# [####################################    ] | 90% Completed | 3.98 s
# [####################################    ] | 90% Completed | 4.11 s
# [####################################    ] | 90% Completed | 4.21 s
# [######################################  ] | 95% Completed | 4.32 s
# [######################################  ] | 95% Completed | 4.43 s
# [########################################] | 100% Completed | 4.53 s
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:53 | Step 4 completed
# INFO:paidiverpy:Step 4 completed

# %%
pipeline.images
# Out:
# Step: raw
# Image: dask.array<array, shape=(10173, 1784, 3), dtype=uint8, chunksize=(10173, 1784, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865, 3), dtype=uint8, chunksize=(15615, 2865, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390, 3), dtype=uint8, chunksize=(10395, 2390, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28128, 2651, 3), dtype=uint8, chunksize=(16876, 2651, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10125, 2475, 3), dtype=uint8, chunksize=(10125, 2475, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476, 3), dtype=uint8, chunksize=(10369, 2476, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539, 3), dtype=uint8, chunksize=(17620, 2539, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10105, 2472, 3), dtype=uint8, chunksize=(10105, 2472, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354, 3), dtype=uint8, chunksize=(10532, 2354, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300, 3), dtype=uint8, chunksize=(10529, 2300, 3), chunktype=numpy.ndarray>
# Step: colour_correction
# Image: dask.array<array, shape=(10173, 1784), dtype=uint8, chunksize=(10173, 1784), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28128, 2651), dtype=uint8, chunksize=(28128, 2651), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10125, 2475), dtype=uint8, chunksize=(10125, 2475), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476), dtype=uint8, chunksize=(10369, 2476), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10105, 2472), dtype=uint8, chunksize=(10105, 2472), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354), dtype=uint8, chunksize=(10532, 2354), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300), dtype=uint8, chunksize=(10529, 2300), chunktype=numpy.ndarray>
# Step: datetime
# Image: dask.array<array, shape=(10173, 1784), dtype=uint8, chunksize=(10173, 1784), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28128, 2651), dtype=uint8, chunksize=(28128, 2651), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10125, 2475), dtype=uint8, chunksize=(10125, 2475), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476), dtype=uint8, chunksize=(10369, 2476), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10105, 2472), dtype=uint8, chunksize=(10105, 2472), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354), dtype=uint8, chunksize=(10532, 2354), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300), dtype=uint8, chunksize=(10529, 2300), chunktype=numpy.ndarray>
# Step: colour_correction
# Image: dask.array<array, shape=(10173, 1784), dtype=uint8, chunksize=(10173, 1784), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28128, 2651), dtype=uint8, chunksize=(28128, 2651), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10125, 2475), dtype=uint8, chunksize=(10125, 2475), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476), dtype=uint8, chunksize=(10369, 2476), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10105, 2472), dtype=uint8, chunksize=(10105, 2472), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354), dtype=uint8, chunksize=(10532, 2354), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300), dtype=uint8, chunksize=(10529, 2300), chunktype=numpy.ndarray>
# Step: sharpen
# Image: dask.array<array, shape=(10173, 1784), dtype=uint8, chunksize=(10173, 1784), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(25157, 2865), dtype=uint8, chunksize=(25157, 2865), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10395, 2390), dtype=uint8, chunksize=(10395, 2390), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(28128, 2651), dtype=uint8, chunksize=(28128, 2651), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10125, 2475), dtype=uint8, chunksize=(10125, 2475), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10369, 2476), dtype=uint8, chunksize=(10369, 2476), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(18378, 2539), dtype=uint8, chunksize=(18378, 2539), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10105, 2472), dtype=uint8, chunksize=(10105, 2472), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10532, 2354), dtype=uint8, chunksize=(10532, 2354), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(10529, 2300), dtype=uint8, chunksize=(10529, 2300), chunktype=numpy.ndarray>

# %% [markdown]
# # Export Images to file

# %% [markdown]
# In this case, the images will be saved in the object store, in the path provided

# %%
pipeline.save_images(image_format="png")
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:55 | Saving images from step: last
# INFO:paidiverpy:Saving images from step: last
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:30:55 | Uploading images to S3 using Dask
# INFO:paidiverpy:Uploading images to S3 using Dask
# [                                        ] | 0% Completed | 814.50 us
# [################                        ] | 40% Completed | 105.04 ms
# [################                        ] | 40% Completed | 207.59 ms
# [################                        ] | 40% Completed | 308.99 ms
# [################                        ] | 40% Completed | 411.45 ms
# [################                        ] | 40% Completed | 516.31 ms
# [################                        ] | 40% Completed | 618.95 ms
# [################                        ] | 40% Completed | 721.29 ms
# [################                        ] | 40% Completed | 828.55 ms
# [################                        ] | 40% Completed | 931.89 ms
# [################                        ] | 40% Completed | 1.03 s
# [################                        ] | 40% Completed | 1.13 s
# [################                        ] | 40% Completed | 1.24 s
# [################                        ] | 40% Completed | 1.34 s
# [################                        ] | 40% Completed | 1.44 s
# [################                        ] | 40% Completed | 1.54 s
# [################                        ] | 40% Completed | 1.65 s
# [################                        ] | 40% Completed | 1.75 s
# [################                        ] | 40% Completed | 1.85 s
# [################                        ] | 40% Completed | 1.96 s
# [################                        ] | 40% Completed | 2.06 s
# [################                        ] | 40% Completed | 2.16 s
# [################                        ] | 40% Completed | 2.26 s
# [################                        ] | 40% Completed | 2.37 s
# [################                        ] | 40% Completed | 2.47 s
# [################                        ] | 40% Completed | 2.57 s
# [################                        ] | 40% Completed | 2.67 s
# [################                        ] | 40% Completed | 2.77 s
# [################                        ] | 40% Completed | 2.87 s
# [################                        ] | 40% Completed | 2.97 s
# [################                        ] | 40% Completed | 3.07 s
# [################                        ] | 40% Completed | 3.17 s
# [################                        ] | 40% Completed | 3.27 s
# [################                        ] | 40% Completed | 3.38 s
# [################                        ] | 40% Completed | 3.48 s
# [################                        ] | 40% Completed | 3.58 s
# [################                        ] | 40% Completed | 3.68 s
# [################                        ] | 40% Completed | 3.78 s
# [################                        ] | 40% Completed | 3.89 s
# [################                        ] | 40% Completed | 3.99 s
# [################                        ] | 40% Completed | 4.09 s
# [################                        ] | 40% Completed | 4.19 s
# [################                        ] | 40% Completed | 4.29 s
# [################                        ] | 40% Completed | 4.39 s
# [################                        ] | 40% Completed | 4.49 s
# [################                        ] | 40% Completed | 4.59 s
# [################                        ] | 40% Completed | 4.70 s
# [################                        ] | 40% Completed | 4.80 s
# [################                        ] | 40% Completed | 4.90 s
# [################                        ] | 40% Completed | 5.00 s
# [################                        ] | 40% Completed | 5.10 s
# [################                        ] | 40% Completed | 5.20 s
# [################                        ] | 40% Completed | 5.31 s
# [################                        ] | 40% Completed | 5.41 s
# [################                        ] | 40% Completed | 5.51 s
# [################                        ] | 40% Completed | 5.61 s
# [################                        ] | 40% Completed | 5.71 s
# [################                        ] | 40% Completed | 5.81 s
# [################                        ] | 40% Completed | 5.91 s
# [################                        ] | 40% Completed | 6.02 s
# [################                        ] | 40% Completed | 6.12 s
# [################                        ] | 40% Completed | 6.22 s
# [################                        ] | 40% Completed | 6.32 s
# [################                        ] | 40% Completed | 6.42 s
# [################                        ] | 40% Completed | 6.52 s
# [################                        ] | 40% Completed | 6.62 s
# [################                        ] | 40% Completed | 6.72 s
# [################                        ] | 40% Completed | 6.83 s
# [################                        ] | 40% Completed | 6.93 s
# [################                        ] | 40% Completed | 7.03 s
# [################                        ] | 40% Completed | 7.14 s
# [################                        ] | 40% Completed | 7.25 s
# [################                        ] | 40% Completed | 7.35 s
# [################                        ] | 40% Completed | 7.46 s
# [################                        ] | 40% Completed | 7.56 s
# [################                        ] | 40% Completed | 7.67 s
# [################                        ] | 40% Completed | 7.77 s
# [################                        ] | 40% Completed | 7.87 s
# [################                        ] | 40% Completed | 7.97 s
# [################                        ] | 40% Completed | 8.07 s
# [################                        ] | 40% Completed | 8.17 s
# [################                        ] | 40% Completed | 8.27 s
# [################                        ] | 40% Completed | 8.38 s
# [################                        ] | 40% Completed | 8.48 s
# [################                        ] | 40% Completed | 8.58 s
# [################                        ] | 40% Completed | 8.68 s
# [################                        ] | 40% Completed | 8.78 s
# [################                        ] | 40% Completed | 8.88 s
# [################                        ] | 40% Completed | 8.98 s
# [################                        ] | 40% Completed | 9.08 s
# [################                        ] | 40% Completed | 9.18 s
# [################                        ] | 40% Completed | 9.28 s
# [################                        ] | 40% Completed | 9.39 s
# [################                        ] | 40% Completed | 9.49 s
# [################                        ] | 40% Completed | 9.59 s
# [################                        ] | 40% Completed | 9.69 s
# [################                        ] | 40% Completed | 9.79 s
# [################                        ] | 40% Completed | 9.89 s
# [################                        ] | 40% Completed | 10.00 s
# [################                        ] | 40% Completed | 10.10 s
# [################                        ] | 40% Completed | 10.21 s
# [################                        ] | 40% Completed | 10.31 s
# [################                        ] | 40% Completed | 10.41 s
# [################                        ] | 40% Completed | 10.51 s
# [################                        ] | 40% Completed | 10.61 s
# [################                        ] | 40% Completed | 10.72 s
# [################                        ] | 40% Completed | 10.82 s
# [################                        ] | 40% Completed | 10.92 s
# [################                        ] | 40% Completed | 11.02 s
# [################                        ] | 40% Completed | 11.13 s
# [################                        ] | 40% Completed | 11.23 s
# [################                        ] | 40% Completed | 11.33 s
# [################                        ] | 40% Completed | 11.43 s
# [################                        ] | 40% Completed | 11.53 s
# [################                        ] | 40% Completed | 11.63 s
# [################                        ] | 40% Completed | 11.73 s
# [################                        ] | 40% Completed | 11.83 s
# [################                        ] | 40% Completed | 11.93 s
# [################                        ] | 40% Completed | 12.04 s
# [################                        ] | 40% Completed | 12.14 s
# [################                        ] | 40% Completed | 12.24 s
# [################                        ] | 40% Completed | 12.34 s
# [################                        ] | 40% Completed | 12.44 s
# [################                        ] | 40% Completed | 12.54 s
# [################                        ] | 40% Completed | 12.64 s
# [################                        ] | 40% Completed | 12.74 s
# [################                        ] | 40% Completed | 12.85 s
# [################                        ] | 40% Completed | 12.95 s
# [################                        ] | 40% Completed | 13.05 s
# [################                        ] | 40% Completed | 13.15 s
# [################                        ] | 40% Completed | 13.25 s
# [################                        ] | 40% Completed | 13.35 s
# [################                        ] | 40% Completed | 13.45 s
# [################                        ] | 40% Completed | 13.55 s
# [################                        ] | 40% Completed | 13.65 s
# [################                        ] | 40% Completed | 13.75 s
# [################                        ] | 40% Completed | 13.86 s
# [################                        ] | 40% Completed | 13.96 s
# [################                        ] | 40% Completed | 14.06 s
# [################                        ] | 40% Completed | 14.16 s
# [################                        ] | 40% Completed | 14.26 s
# [################                        ] | 40% Completed | 14.36 s
# [################                        ] | 40% Completed | 14.46 s
# [################                        ] | 40% Completed | 14.57 s
# [################                        ] | 40% Completed | 14.67 s
# [################                        ] | 40% Completed | 14.77 s
# [################                        ] | 40% Completed | 14.87 s
# [################                        ] | 40% Completed | 14.97 s
# [################                        ] | 40% Completed | 15.07 s
# [################                        ] | 40% Completed | 15.18 s
# [################                        ] | 40% Completed | 15.28 s
# [################                        ] | 40% Completed | 15.38 s
# [################                        ] | 40% Completed | 15.48 s
# [################                        ] | 40% Completed | 15.58 s
# [################                        ] | 40% Completed | 15.68 s
# [################                        ] | 40% Completed | 15.78 s
# [################                        ] | 40% Completed | 15.88 s
# [################                        ] | 40% Completed | 15.98 s
# [################                        ] | 40% Completed | 16.09 s
# [################                        ] | 40% Completed | 16.19 s
# [################                        ] | 40% Completed | 16.29 s
# [################                        ] | 40% Completed | 16.39 s
# [################                        ] | 40% Completed | 16.49 s
# [################                        ] | 40% Completed | 16.60 s
# [################                        ] | 40% Completed | 16.70 s
# [################                        ] | 40% Completed | 16.80 s
# [################                        ] | 40% Completed | 16.90 s
# [################                        ] | 40% Completed | 17.00 s
# [################                        ] | 40% Completed | 17.11 s
# [################                        ] | 40% Completed | 17.21 s
# [################                        ] | 40% Completed | 17.31 s
# [################                        ] | 40% Completed | 17.41 s
# [################                        ] | 40% Completed | 17.52 s
# [################                        ] | 40% Completed | 17.62 s
# [################                        ] | 40% Completed | 17.72 s
# [################                        ] | 40% Completed | 17.82 s
# [################                        ] | 40% Completed | 17.92 s
# [################                        ] | 40% Completed | 18.02 s
# [################                        ] | 40% Completed | 18.12 s
# [################                        ] | 40% Completed | 18.23 s
# [################                        ] | 40% Completed | 18.33 s
# [################                        ] | 40% Completed | 18.43 s
# [################                        ] | 40% Completed | 18.53 s
# [################                        ] | 40% Completed | 18.63 s
# [################                        ] | 40% Completed | 18.73 s
# [################                        ] | 40% Completed | 18.83 s
# [################                        ] | 40% Completed | 18.93 s
# [################                        ] | 40% Completed | 19.04 s
# [################                        ] | 40% Completed | 19.14 s
# [################                        ] | 40% Completed | 19.24 s
# [################                        ] | 40% Completed | 19.34 s
# [################                        ] | 40% Completed | 19.44 s
# [################                        ] | 40% Completed | 19.55 s
# [################                        ] | 40% Completed | 19.65 s
# [################                        ] | 40% Completed | 19.75 s
# [################                        ] | 40% Completed | 19.86 s
# [################                        ] | 40% Completed | 19.96 s
# [################                        ] | 40% Completed | 20.06 s
# [################                        ] | 40% Completed | 20.16 s
# [################                        ] | 40% Completed | 20.26 s
# [################                        ] | 40% Completed | 20.36 s
# [################                        ] | 40% Completed | 20.46 s
# [################                        ] | 40% Completed | 20.56 s
# [################                        ] | 40% Completed | 20.67 s
# [################                        ] | 40% Completed | 20.77 s
# [################                        ] | 40% Completed | 20.87 s
# [################                        ] | 40% Completed | 20.97 s
# [################                        ] | 40% Completed | 21.07 s
# [################                        ] | 40% Completed | 21.17 s
# [################                        ] | 40% Completed | 21.27 s
# [################                        ] | 40% Completed | 21.38 s
# [################                        ] | 40% Completed | 21.48 s
# [################                        ] | 40% Completed | 21.58 s
# [################                        ] | 40% Completed | 21.68 s
# [################                        ] | 40% Completed | 21.78 s
# [################                        ] | 40% Completed | 21.88 s
# [################                        ] | 40% Completed | 21.98 s
# [################                        ] | 40% Completed | 22.09 s
# [################                        ] | 40% Completed | 22.19 s
# [################                        ] | 40% Completed | 22.29 s
# [################                        ] | 40% Completed | 22.39 s
# [################                        ] | 40% Completed | 22.49 s
# [################                        ] | 40% Completed | 22.60 s
# [################                        ] | 40% Completed | 22.70 s
# [################                        ] | 40% Completed | 22.80 s
# [################                        ] | 40% Completed | 22.90 s
# [################                        ] | 40% Completed | 23.00 s
# [################                        ] | 40% Completed | 23.11 s
# [################                        ] | 40% Completed | 23.21 s
# [################                        ] | 40% Completed | 23.31 s
# [################                        ] | 40% Completed | 23.41 s
# [################                        ] | 40% Completed | 23.51 s
# [################                        ] | 40% Completed | 23.62 s
# [################                        ] | 40% Completed | 23.72 s
# [################                        ] | 40% Completed | 23.82 s
# [####################                    ] | 50% Completed | 23.92 s
# [####################                    ] | 50% Completed | 24.02 s
# [####################                    ] | 50% Completed | 24.12 s
# [####################                    ] | 50% Completed | 24.22 s
# [####################                    ] | 50% Completed | 24.32 s
# [####################                    ] | 50% Completed | 24.43 s
# [####################                    ] | 50% Completed | 24.53 s
# [####################                    ] | 50% Completed | 24.64 s
# [####################                    ] | 50% Completed | 24.74 s
# [####################                    ] | 50% Completed | 24.85 s
# [########################                ] | 60% Completed | 24.95 s
# [########################                ] | 60% Completed | 25.05 s
# [########################                ] | 60% Completed | 25.15 s
# [########################                ] | 60% Completed | 25.26 s
# [########################                ] | 60% Completed | 25.36 s
# [########################                ] | 60% Completed | 25.46 s
# [########################                ] | 60% Completed | 25.56 s
# [##########################              ] | 65% Completed | 25.66 s
# [############################            ] | 70% Completed | 25.76 s
# [############################            ] | 70% Completed | 25.86 s
# [############################            ] | 70% Completed | 25.96 s
# [############################            ] | 70% Completed | 26.07 s
# [############################            ] | 70% Completed | 26.17 s
# [############################            ] | 70% Completed | 26.27 s
# [############################            ] | 70% Completed | 26.37 s
# [############################            ] | 70% Completed | 26.47 s
# [############################            ] | 70% Completed | 26.57 s
# [############################            ] | 70% Completed | 26.68 s
# [############################            ] | 70% Completed | 26.78 s
# [############################            ] | 70% Completed | 26.88 s
# [############################            ] | 70% Completed | 26.98 s
# [############################            ] | 70% Completed | 27.09 s
# [############################            ] | 70% Completed | 27.19 s
# [############################            ] | 70% Completed | 27.29 s
# [############################            ] | 70% Completed | 27.39 s
# [############################            ] | 70% Completed | 27.50 s
# [############################            ] | 70% Completed | 27.60 s
# [############################            ] | 70% Completed | 27.70 s
# [############################            ] | 70% Completed | 27.80 s
# [############################            ] | 70% Completed | 27.91 s
# [############################            ] | 70% Completed | 28.01 s
# [############################            ] | 70% Completed | 28.11 s
# [############################            ] | 70% Completed | 28.21 s
# [############################            ] | 70% Completed | 28.31 s
# [############################            ] | 70% Completed | 28.42 s
# [############################            ] | 70% Completed | 28.52 s
# [############################            ] | 70% Completed | 28.62 s
# [############################            ] | 70% Completed | 28.72 s
# [############################            ] | 70% Completed | 28.82 s
# [############################            ] | 70% Completed | 28.92 s
# [############################            ] | 70% Completed | 29.02 s
# [############################            ] | 70% Completed | 29.12 s
# [##############################          ] | 75% Completed | 29.22 s
# [##################################      ] | 85% Completed | 29.33 s
# [##################################      ] | 85% Completed | 29.43 s
# [##################################      ] | 85% Completed | 29.53 s
# [##################################      ] | 85% Completed | 29.63 s
# [##################################      ] | 85% Completed | 29.73 s
# [##################################      ] | 85% Completed | 29.83 s
# [##################################      ] | 85% Completed | 29.93 s
# [##################################      ] | 85% Completed | 30.03 s
# [##################################      ] | 85% Completed | 30.13 s
# [##################################      ] | 85% Completed | 30.23 s
# [##################################      ] | 85% Completed | 30.34 s
# [##################################      ] | 85% Completed | 30.44 s
# [##################################      ] | 85% Completed | 30.54 s
# [##################################      ] | 85% Completed | 30.64 s
# [##################################      ] | 85% Completed | 30.74 s
# [##################################      ] | 85% Completed | 30.84 s
# [####################################    ] | 90% Completed | 30.94 s
# [####################################    ] | 90% Completed | 31.04 s
# [####################################    ] | 90% Completed | 31.14 s
# [####################################    ] | 90% Completed | 31.25 s
# [####################################    ] | 90% Completed | 31.35 s
# [######################################  ] | 95% Completed | 31.45 s
# [######################################  ] | 95% Completed | 31.55 s
# [######################################  ] | 95% Completed | 31.65 s
# [######################################  ] | 95% Completed | 31.75 s
# [######################################  ] | 95% Completed | 31.85 s
# [######################################  ] | 95% Completed | 31.95 s
# [######################################  ] | 95% Completed | 32.05 s
# [######################################  ] | 95% Completed | 32.15 s
# [######################################  ] | 95% Completed | 32.26 s
# [######################################  ] | 95% Completed | 32.36 s
# [######################################  ] | 95% Completed | 32.46 s
# [######################################  ] | 95% Completed | 32.56 s
# [######################################  ] | 95% Completed | 32.66 s
# [######################################  ] | 95% Completed | 32.76 s
# [######################################  ] | 95% Completed | 32.86 s
# [######################################  ] | 95% Completed | 32.96 s
# [########################################] | 100% Completed | 33.06 s
# ☁ paidiverpy ☁  |       INFO | 2025-03-06 10:31:28 | Images are saved to: s3://paidiverpy/data/lazy_load_benthic/output2/
# INFO:paidiverpy:Images are saved to: s3://paidiverpy/data/lazy_load_benthic/output2/
