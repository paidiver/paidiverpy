# %% [markdown]
# ## Generate the pipeline without a describing the steps in the config file

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline
from paidiverpy.open_layer import OpenLayer
from paidiverpy.color_layer import ColorLayer
from paidiverpy.resample_layer import ResampleLayer

# %%
# creating the steps by hand
open_layer_params = {
    'convert': [
        {
            'mode': 'bits', 'params': {
                'output_bits': 8,
                'autoscale': True
            }
        }
    ],
    'sampling': [
        {
            'mode': 'percent',
            'params': {
                'value': 0.3
            }
        }
    ]
}
pipeline_steps = [('raw', OpenLayer, open_layer_params)]

# %%
# Instantiate the pipeline class and see the step described in the pipeline_steps variable
pipeline = Pipeline(config_file_path='../config_files/config_1.yaml', steps = pipeline_steps)
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square" style="float:left; cursor: pointer; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Raw</h2>
#         </div>
#
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "input_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen",
#     "output_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data",
#     "catalog_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/catalog/catalog_jen.csv",
#     "catalog_type": "CSV",
# ...

# %%
# Run your pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 10:24:49 | Running step 0: raw - OpenLayer
# ...
# Processing Images: 100%|███████████████████████████████| 30/30 [00:09<00:00,  3.05it/s]
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 10:25:06 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 10:25:06 | Step 0 saved

# %%
# see the outputs
pipeline.images
# Out:
# Step: raw
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5d270>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5d000>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5d150>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5ceb0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5cac0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5cb80>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5d3f0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5cc10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5d0c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5cd60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5c850>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5cd90>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5d510>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7e4727d5d780>
# ...

# %%
# Create a new pipeline with one more step
open_layer_params = {
    'convert': [
        {
            'mode': 'bits', 'params': {
                'output_bits': 8,
                'autoscale': True
            }
        }
    ],
    'sampling': [
        {
            'mode': 'percent',
            'params': {
                'value': 0.1
            }
        }
    ]
}
pipeline_steps = [
    ('raw', OpenLayer, open_layer_params),
    ('gray', ColorLayer, {'mode': 'grayscale'})
]

# %%
# Instantiate the pipeline class and see the step described in the pipeline_steps variable
pipeline = Pipeline(config_file_path='../config_files/config_1.yaml', steps = pipeline_steps)
pipeline.steps
# Out:
# [('raw',
#   paidiverpy.open_layer.open_layer.OpenLayer,
#   {'convert': [{'mode': 'bits',
#      'params': {'output_bits': 8, 'autoscale': True}}],
#    'sampling': [{'mode': 'percent', 'params': {'value': 0.1}}],
#    'name': 'raw',
#    'step_name': 'raw'}),
#  ('gray',
#   paidiverpy.color_layer.color_layer.ColorLayer,
#   {'mode': 'grayscale', 'name': 'gray', 'step_name': 'color'})]

# %%
# See the pipeline
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square" style="float:left; cursor: pointer; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Raw</h2>
#         </div>
#
#             <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Gray</h2>
# ...

# %%
# See the updated configuration file
pipeline.config
# Out:
# {
#     "general": {
#         "input_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen",
#         "output_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data",
#         "catalog_path": "/mnt/code/code/noc/paidiver/paidiverpy/examples/catalog/catalog_jen.csv",
#         "catalog_type": "CSV",
#         "append_data_to_catalog": "/mnt/code/code/noc/paidiver/paidiverpy/examples/data/jen/waypoints/scidata_20180610.csv",
#         "image_type": "JPG",
#         "sampling": [
#             {
#                 "mode": "percent",
#                 "params": {
#                     "value": 0.1
#                 }
#             }
#         ],
#         "convert": [
#             {
#                 "mode": "bits",
#                 "params": {
#                     "output_bits": 8,
#                     "autoscale": true
#                 }
#             }
#         ],
#         "name": "raw",
#         "step_name": "raw"
#     },
#     "steps": [
#         {
# ...

# %%
# Run your pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:03:02 | Running step 0: raw - OpenLayer
# ...
# Processing Images: 100%|███████████████████████████████| 10/10 [00:03<00:00,  2.80it/s]
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:03:09 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:03:09 | Step 0 saved
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:03:09 | Running step 1: gray - ColorLayer
# Processing Images: 100%|███████████████████████████████| 10/10 [00:00<00:00, 76.59it/s]
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:03:10 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:03:10 | Step 1 saved

# %%
# See the ouput images
pipeline.images
# Out:
# Step: raw
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f85ac0d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f85afbb0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f85afb50>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f85aeef0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f85af730>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f85ac490>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f85ac040>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f85afc10>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f85af8e0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f85ac6a0>
# Step: gray
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c0664d5b850>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c0664d598a0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c0664d5b400>
# ...

# %%
#plot images from a specific step
pipeline.images.images[1][0].show()

# %%
pipeline.images.show(index=8)

# %% [markdown]
# ## Export pipeline to configuration file

# %%
pipeline.export_config('new_config.yaml')

# %%
pipeline = Pipeline(config_file_path='new_config.yaml')

# %%
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square" style="float:left; cursor: pointer; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#
#             <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Gray</h2>
# ...

# %%
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:04:02 | Running step 0: raw - OpenLayer
# ...
# Processing Images: 100%|███████████████████████████████| 10/10 [00:03<00:00,  2.97it/s]
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:04:08 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:04:08 | Step 0 saved
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:04:08 | Running step 1: gray - ColorLayer
# Processing Images: 100%|███████████████████████████████| 10/10 [00:00<00:00, 81.57it/s]
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:04:09 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-10 11:04:09 | Step 1 saved

# %%
pipeline.images
# Out:
# Step: raw
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f8fdd300>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f8fddf60>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f8fddff0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f8fdf6d0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f8fde0b0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f8fde140>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f8fdd000>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f8fdd930>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f8fdefb0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c05f8fde1a0>
# Step: gray
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c06844f65c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c062ebb19c0>
# Image: <paidiverpy.image_layer.ImageLayer object at 0x7c062ebb1990>
# ...
