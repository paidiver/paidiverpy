# %% [markdown]
# ## Run a pipeline

# %% [markdown]
# This process will run the entire pipeline described in a configuration file

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline

# %%
pipeline = Pipeline(config_file_path="../config_files/config_custom_algorithm.yaml")

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square" style="float:left; cursor: pointer; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#
#             <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Colour_correction</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_1" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_1')">
#                     <h2 style="font-size:20px;">Min_max_data</h2>
#                     <h2 style="font-size:13px;">Type: Custom</h2>
#                 </div>
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#                 <div id="parameters_step_0" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "colour_correction",
#     "step_name": "colour",
#     "mode": "grayscale",
#     "test": false
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_1" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "min_max_data",
#     "step_name": "custom",
#     "file_path": "/mnt/noc/code/paidiver/paidiverpy/examples/custom_algorithms/custom_algorithm_example.py",
#     "class_name": "MyMethod",
#     "test": false,
#     "params": {
#         "feature_range": "(0, 1)"
#     }
# }</pre>
#                 </div>
#
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "name": "raw",
#     "step_name": "open",
#     "sample_data": "benthic_csv",
#     "input_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/images",
#     "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/metadata_benthic_csv.csv",
#     "metadata_type": "CSV_FILE",
#     "image_type": "PNG",
#     "append_data_to_metadata": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/appended_metadata_benthic_csv.csv",
#     "output_path": "output",
#     "n_jobs": 1,
#     "rename": "datetime",
#     "sampling": [
#         {
#             "name": "sampling",
#             "step_name": "sampling",
#             "mode": "percent",
#             "test": false,
#             "params": {
#                 "value": 0.1
#             }
#         }
#     ],
#     "convert": [
#         {
#             "name": "convert",
#             "step_name": "convert",
#             "mode": "bits",
#             "test": false,
#             "params": {
#                 "output_bits": 8
#             }
#         }
#     ]
# }</pre>
#             </div>
#         </div>
#         <script>
#             function showParameters(id) {
#                 // Hide all parameter sections
#                 var currentTarget = document.getElementById(id);
#                 var square = document.getElementsByClassName('square');
#                 var allParams = document.getElementsByClassName('parameters');
#                 var selectedParams = document.getElementById('parameters_' + id);
#                 var idWasVisible = false;
#                 if (selectedParams) {
#                     var idWasVisible = selectedParams.style.display === 'block';
#                 }
#                 for (var i = 0; i < square.length; i++) {
#                     square[i].style.color = 'black';
#                 }
#                 for (var i = 0; i < allParams.length; i++) {
#                     allParams[i].style.display = 'none';
#                 }
#                 // Show the selected parameter section
#                 if (selectedParams) {
#                     if (idWasVisible) {
#                         selectedParams.style.display = 'none';
#                         currentTarget.style.color = 'black';
#                     } else {
#                         selectedParams.style.display = 'block';
#                         currentTarget.style.color = 'red';
#                     }
#                 }
#             }
#         </script>

# %%
# See the pipeline steps in json format
# pipeline.steps

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-11-12 17:32:52 | Running step 0: raw - OpenLayer
# Open Images: 100%|████████████████████████████████| 5/5 [00:00<00:00, 18.63it/s]
# ☁ paidiverpy ☁  |       INFO | 2024-11-12 17:32:52 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2024-11-12 17:32:52 | Running step 1: colour_correction - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2024-11-12 17:32:52 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2024-11-12 17:32:52 | Running step 2: min_max_data - CustomLayer
# ☁ paidiverpy ☁  |       INFO | 2024-11-12 17:32:52 | Step 2 completed

# %%
pipeline.images
# Out:
# Step: raw
# Image: [[[77 59 71  1]
#   [77 60 73  1]
#   [79 58 69  1]
#   ...
#   [82 55 65  1]
#   [81 52 63  1]
#   [82 53 64  1]]
#
#  [[78 59 72  1]
#   [78 62 74  1]
#   [77 59 72  1]
#   ...
#   [82 53 61  1]
#   [81 55 64  1]
#   [80 54 66  1]]
#
#  [[76 58 72  1]
#   [76 59 71  1]
#   [76 61 72  1]
#   ...
#   [79 52 62  1]
#   [80 54 64  1]
#   [80 54 64  1]]
#
#  ...
#
#  [[76 63 71  1]
#   [78 62 70  1]
#   [78 60 66  1]
#   ...
#   [73 49 52  1]
#   [70 48 49  1]
#   [73 49 54  1]]
#
#  [[79 64 71  1]
#   [76 61 67  1]
#   [78 62 64  1]
#   ...
#   [73 50 53  1]
#   [72 49 51  1]
#   [72 49 51  1]]
#
#  [[78 62 70  1]
#   [77 61 67  1]
#   [78 63 66  1]
#   ...
#   [74 49 52  1]
#   [73 49 53  1]
#   [70 49 53  1]]]
# Image: [[[144 138 169   1]
#   [145 139 170   1]
#   [141 134 163   1]
#   ...
#   [ 99  85 112   1]
#   [101  88 113   1]
#   [ 99  88 113   1]]
#
#  [[142 137 167   1]
#   [140 135 164   1]
#   [141 136 167   1]
#   ...
#   [ 98  86 110   1]
#   [ 99  87 113   1]
#   [ 97  86 108   1]]
#
#  [[140 135 164   1]
#   [139 134 161   1]
#   [139 132 159   1]
#   ...
#   [ 96  84 109   1]
#   [ 96  86 110   1]
#   [ 99  89 113   1]]
#
#  ...
#
#  [[ 97  89 106   1]
#   [ 96  90 103   1]
#   [ 92  85  88   1]
#   ...
#   [124 122 150   1]
#   [125 122 150   1]
#   [123 120 149   1]]
#
#  [[ 96  90 102   1]
#   [ 95  88 100   1]
#   [ 93  83  86   1]
#   ...
#   [121 116 141   1]
#   [125 122 148   1]
#   [124 120 148   1]]
#
#  [[ 97  92 105   1]
#   [ 93  86  90   1]
#   [ 93  82  85   1]
#   ...
#   [121 118 146   1]
#   [122 120 149   1]
#   [124 120 145   1]]]
# Image: [[[164 161 203   1]
#   [163 161 200   1]
#   [164 160 200   1]
#   ...
#   [145 137 176   1]
#   [140 132 166   1]
#   [142 137 172   1]]
#
#  [[165 162 202   1]
#   [164 160 202   1]
#   [164 161 201   1]
#   ...
#   [138 134 169   1]
#   [146 141 179   1]
#   [140 135 167   1]]
#
#  [[162 161 200   1]
#   [161 160 199   1]
#   [167 165 202   1]
#   ...
#   [141 137 173   1]
#   [145 140 177   1]
#   [142 139 172   1]]
#
#  ...
#
#  [[172 171 203   1]
#   [168 168 198   1]
#   [134 127 110   1]
#   ...
#   [126 123 156   1]
#   [129 128 161   1]
#   [131 130 165   1]]
#
#  [[171 171 198   1]
#   [164 163 177   1]
#   [123 112  99   1]
#   ...
#   [128 127 162   1]
#   [128 128 161   1]
#   [128 126 160   1]]
#
#  [[171 173 201   1]
#   [128 121 102   1]
#   [121 107  91   1]
#   ...
#   [126 125 156   1]
#   [130 128 164   1]
#   [127 127 161   1]]]
# Image: [[[196 186 231   1]
#   [195 188 232   1]
#   [191 185 228   1]
#   ...
#   [183 173 217   1]
#   [180 172 218   1]
#   [178 169 215   1]]
#
#  [[191 184 228   1]
#   [194 185 228   1]
#   [192 186 228   1]
#   ...
#   [179 172 214   1]
#   [179 170 213   1]
#   [176 168 216   1]]
#
#  [[194 186 229   1]
#   [191 184 228   1]
#   [192 183 225   1]
#   ...
#   [182 172 220   1]
#   [179 172 215   1]
#   [174 166 211   1]]
#
#  ...
#
#  [[212 209 245   1]
#   [211 207 245   1]
#   [153 146 119   1]
#   ...
#   [203 199 236   1]
#   [198 196 230   1]
#   [200 195 234   1]]
#
#  [[209 207 238   1]
#   [207 204 219   1]
#   [129 120 102   1]
#   ...
#   [200 200 236   1]
#   [203 199 237   1]
#   [200 196 234   1]]
#
#  [[218 215 245   1]
#   [139 128 104   1]
#   [131 118  95   1]
#   ...
#   [201 199 236   1]
#   [204 202 237   1]
#   [201 199 234   1]]]
# Image: [[[207 209 253   1]
#   [208 211 255   1]
#   [208 211 255   1]
#   ...
#   [199 200 248   1]
#   [201 200 248   1]
#   [203 202 249   1]]
#
#  [[206 209 254   1]
#   [208 210   0   1]
#   [206 208 254   1]
#   ...
#   [201 200 247   1]
#   [198 199 248   1]
#   [199 200 245   1]]
#
#  [[209 216   0   1]
#   [203 207 252   1]
#   [206 208 252   1]
#   ...
#   [197 197 247   1]
#   [200 200 246   1]
#   [201 201 250   1]]
#
#  ...
#
#  [[220 226   0   1]
#   [219 223   0   1]
#   [155 150 127   1]
#   ...
#   [210 214 251   1]
#   [211 215 253   1]
#   [209 213 249   1]]
#
#  [[218 223 251   1]
#   [215 218 229   1]
#   [131 122 105   1]
#   ...
#   [211 214 251   1]
#   [207 215 253   1]
#   [212 217 253   1]]
#
#  [[226 231   0   1]
#   [136 126 102   1]
#   [130 119  97   1]
#   ...
#   [209 214 253   1]
#   [211 218 252   1]
#   [211 217 253   1]]]
# Step: colour_correction
# Image: [[65 66 64 ... 61 59 60]
#  [65 67 65 ... 59 61 61]
#  [64 65 66 ... 58 60 60]
#  ...
#  [67 66 64 ... 53 51 53]
#  [68 65 64 ... 54 52 52]
#  [66 65 66 ... 53 53 53]]
# Image: [[148 149 143 ...  95  97  97]
#  [147 144 146 ...  95  96  94]
#  [144 143 141 ...  93  94  97]
#  ...
#  [ 95  95  87 ... 131 131 129]
#  [ 94  92  85 ... 124 130 129]
#  [ 96  88  84 ... 127 129 128]]
# Image: [[174 173 172 ... 150 143 148]
#  [174 173 173 ... 145 153 145]
#  [173 172 176 ... 148 152 149]
#  ...
#  [181 177 123 ... 133 138 141]
#  [179 167 109 ... 138 138 136]
#  [181 116 104 ... 134 139 137]]
# Image: [[201 202 199 ... 187 187 184]
#  [198 199 199 ... 185 184 183]
#  [200 198 197 ... 187 186 180]
#  ...
#  [220 219 139 ... 211 206 207]
#  [216 209 116 ... 211 211 208]
#  [224 122 113 ... 210 213 210]]
# Image: [[222 224 224 ... 214 214 216]
#  [222 147 222 ... 214 214 213]
#  [151 220 221 ... 212 214 216]
#  ...
#  [158 156 144 ... 225 226 223]
#  [231 221 118 ... 225 225 227]
#  [161 120 114 ... 225 227 227]]
# Step: min_max_data
# Image: [[0.8        0.95454545 0.85714286 ... 1.         0.88888889 0.94736842]
#  [0.8        1.         0.9047619  ... 0.89473684 1.         1.        ]
#  [0.73333333 0.90909091 0.95238095 ... 0.84210526 0.94444444 0.94736842]
#  ...
#  [0.93333333 0.95454545 0.85714286 ... 0.57894737 0.44444444 0.57894737]
#  [1.         0.90909091 0.85714286 ... 0.63157895 0.5        0.52631579]
#  [0.86666667 0.90909091 0.95238095 ... 0.57894737 0.55555556 0.57894737]]
# Image: [[1.         1.         0.9516129  ... 0.13043478 0.18367347 0.16326531]
#  [0.98148148 0.91803279 1.         ... 0.13043478 0.16326531 0.10204082]
#  [0.92592593 0.90163934 0.91935484 ... 0.08695652 0.12244898 0.16326531]
#  ...
#  [0.01851852 0.1147541  0.0483871  ... 0.91304348 0.87755102 0.81632653]
#  [0.         0.06557377 0.01612903 ... 0.76086957 0.85714286 0.81632653]
#  [0.03703704 0.         0.         ... 0.82608696 0.83673469 0.79591837]]
# Image: [[0.49206349 0.63333333 0.70103093 ... 0.90625    0.73684211 0.82352941]
#  [0.49206349 0.63333333 0.71134021 ... 0.75       1.         0.73529412]
#  [0.47619048 0.62222222 0.74226804 ... 0.84375    0.97368421 0.85294118]
#  ...
#  [0.6031746  0.67777778 0.19587629 ... 0.375      0.60526316 0.61764706]
#  [0.57142857 0.56666667 0.05154639 ... 0.53125    0.60526316 0.47058824]
#  [0.6031746  0.         0.         ... 0.40625    0.63157895 0.5       ]]
# Image: [[0.5        0.70175439 0.671875   ... 0.45454545 0.40909091 0.31578947]
#  [0.45945946 0.6754386  0.671875   ... 0.40909091 0.34090909 0.28947368]
#  [0.48648649 0.66666667 0.65625    ... 0.45454545 0.38636364 0.21052632]
#  ...
#  [0.75675676 0.85087719 0.203125   ... 1.         0.84090909 0.92105263]
#  [0.7027027  0.76315789 0.0234375  ... 1.         0.95454545 0.94736842]
#  [0.81081081 0.         0.         ... 0.97727273 1.         1.        ]]
# Image: [[0.8172043  0.92035398 0.859375   ... 0.57692308 0.55172414 0.56      ]
#  [0.8172043  0.23893805 0.84375    ... 0.57692308 0.55172414 0.44      ]
#  [0.05376344 0.88495575 0.8359375  ... 0.5        0.55172414 0.56      ]
#  ...
#  [0.12903226 0.31858407 0.234375   ... 1.         0.96551724 0.84      ]
#  [0.91397849 0.89380531 0.03125    ... 1.         0.93103448 1.        ]
#  [0.16129032 0.         0.         ... 1.         1.         1.        ]]
