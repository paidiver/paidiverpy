# %% [markdown]
# ## Run a pipeline

# %% [markdown]
# This process will run the entire pipeline described in a configuration file

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline

# %%
pipeline = Pipeline(config_file_path="../config_files/config_benthic_dask.yaml")

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square" style="float:left; cursor: pointer; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#
#             <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Grayscale</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_1" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_1')">
#                     <h2 style="font-size:20px;">Datetime</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_2" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_2')">
#                     <h2 style="font-size:20px;">Overlapping</h2>
#                     <h2 style="font-size:13px;">Type: Sampling</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_3" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_3')">
#                     <h2 style="font-size:20px;">Colour_alteration</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#                 <div style="clear:both;"></div>
#                 <div id="step_4" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_4')">
#                     <h2 style="font-size:20px;">Gaussian_blur</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_5" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_5')">
#                     <h2 style="font-size:20px;">Sharpen</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_6" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_6')">
#                     <h2 style="font-size:20px;">Contrast</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#                 <div id="parameters_step_0" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "grayscale",
#     "step_name": "colour",
#     "mode": "grayscale",
#     "test": false
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_1" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "datetime",
#     "step_name": "sampling",
#     "mode": "datetime",
#     "test": false,
#     "params": {
#         "min": "2018-06-11 04:14:00",
#         "max": "2018-06-11 04:20:00"
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_2" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "overlapping",
#     "step_name": "sampling",
#     "mode": "overlapping",
#     "test": false,
#     "params": {
#         "omega": 57,
#         "theta": 40,
#         "threshold": 0.5,
#         "camera_distance": 1.12
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_3" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "colour_alteration",
#     "step_name": "colour",
#     "mode": "colour_alteration",
#     "test": false,
#     "params": {
#         "method": "white_balance"
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_4" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "gaussian_blur",
#     "step_name": "colour",
#     "mode": "gaussian_blur",
#     "test": false,
#     "params": {
#         "sigma": 1.0
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_5" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "sharpen",
#     "step_name": "colour",
#     "mode": "sharpen",
#     "test": false,
#     "params": {
#         "alpha": 1.5,
#         "beta": -0.5
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_6" class="parameters" style="display: none;">
#                     <pre>{
#     "name": "contrast",
#     "step_name": "colour",
#     "mode": "contrast",
#     "test": false
# }</pre>
#                 </div>
#
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "name": "raw",
#     "step_name": "open",
#     "sample_data": "benthic_csv",
#     "input_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/images",
#     "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/metadata_benthic_csv.csv",
#     "metadata_type": "CSV_FILE",
#     "image_type": "PNG",
#     "append_data_to_metadata": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/appended_metadata_benthic_csv.csv",
#     "output_path": "output",
#     "n_jobs": -1,
#     "track_changes": true,
#     "rename": null,
#     "sampling": [
#         {
#             "name": "sampling",

# %%
# See the pipeline steps in json format
# pipeline.steps

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:49 | Processing images using 16 cores
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:49 | Running step 0: raw - OpenLayer
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:49 | Setting variables from the paidiverpy object.
# [########################################] | 100% Completed | 1.52 sms
# [########################################] | 100% Completed | 212.52 ms
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Running step 1: grayscale - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Setting variables from the paidiverpy object.
# [########################################] | 100% Completed | 105.57 ms
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Running step 2: datetime - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Setting variables from the paidiverpy object.
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Number of photos to be removed: 6
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Running step 3: overlapping - ResampleLayer
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Setting variables from the paidiverpy object.
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Number of photos to be removed: 5
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Running step 4: colour_alteration - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Setting variables from the paidiverpy object.
# [                                        ] | 0% Completed | 928.46 us☁ paidiverpy ☁  |      ERROR | 2024-12-02 15:09:52 | Error applying colour alteration: not enough values to unpack (expected 3, got 1)
# ☁ paidiverpy ☁  |      ERROR | 2024-12-02 15:09:52 | Error applying colour alteration: not enough values to unpack (expected 3, got 1)
# ☁ paidiverpy ☁  |      ERROR | 2024-12-02 15:09:52 | Error applying colour alteration: not enough values to unpack (expected 3, got 1)
# ☁ paidiverpy ☁  |      ERROR | 2024-12-02 15:09:52 | Error applying colour alteration: not enough values to unpack (expected 3, got 1)
# ☁ paidiverpy ☁  |      ERROR | 2024-12-02 15:09:52 | Error applying colour alteration: not enough values to unpack (expected 3, got 1)
# ☁ paidiverpy ☁  |      ERROR | 2024-12-02 15:09:52 | Error applying colour alteration: not enough values to unpack (expected 3, got 1)
# ☁ paidiverpy ☁  |      ERROR | 2024-12-02 15:09:52 | Error applying colour alteration: not enough values to unpack (expected 3, got 1)
# ☁ paidiverpy ☁  |      ERROR | 2024-12-02 15:09:52 | Error applying colour alteration: not enough values to unpack (expected 3, got 1)
# ☁ paidiverpy ☁  |      ERROR | 2024-12-02 15:09:52 | Error applying colour alteration: not enough values to unpack (expected 3, got 1)
# [########################################] | 100% Completed | 103.81 ms
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:52 | Step 4 completed
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:53 | Running step 5: gaussian_blur - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:53 | Setting variables from the paidiverpy object.
# [########################################] | 100% Completed | 108.22 ms
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:53 | Step 5 completed
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:53 | Running step 6: sharpen - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:53 | Setting variables from the paidiverpy object.
# [########################################] | 100% Completed | 109.12 ms
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:53 | Step 6 completed
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:53 | Running step 7: contrast - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:53 | Setting variables from the paidiverpy object.
# [########################################] | 100% Completed | 220.59 ms
# ☁ paidiverpy ☁  |       INFO | 2024-12-02 15:09:53 | Step 7 completed

# %%
pipeline.images
# Out:
# Step: raw
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 4), dtype=uint8, chunksize=(128, 128, 4), chunktype=numpy.ndarray>
# Step: grayscale
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Step: datetime
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Step: overlapping
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Step: colour_alteration
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Step: gaussian_blur
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Step: sharpen
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Step: contrast
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128), dtype=uint8, chunksize=(128, 128), chunktype=numpy.ndarray>
