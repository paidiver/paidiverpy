# %% [markdown]
# ## Run a pipeline

# %% [markdown]
# This process will run the entire pipeline described in a configuration file

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pipeline = Pipeline(config_file_path='../config_files/config_jen_dask.yaml')

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square" style="float:left; cursor: pointer; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#
#             <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information" class="square" style="cursor: pointer; float:left; padding: 10px; width: max-content; height: 80px; margin: 10px; border: 1px solid #000; text-align: center; line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Grayscale</h2>
# ...

# %%
# See the pipeline steps in json format
# pipeline.steps

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2024-09-20 17:55:52 | Running step 0: raw - OpenLayer
# ☁ paidiverpy ☁  |       INFO | 2024-09-20 17:55:52 | Processing images using 16 cores
# [########################################] | 100% Completed | 23.06 s
# ☁ paidiverpy ☁  |       INFO | 2024-09-20 17:56:16 | Processing images using 16 cores
# [########################################] | 100% Completed | 3.60 ss
# 20 (4000, 6000, 3) <class 'dask.array.core.Array'>
# ☁ paidiverpy ☁  |       INFO | 2024-09-20 17:56:22 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2024-09-20 17:56:22 | Step 0 saved
# ☁ paidiverpy ☁  |       INFO | 2024-09-20 17:56:23 | Running step 1: grayscale - ColorLayer
# ☁ paidiverpy ☁  |       INFO | 2024-09-20 17:56:23 | Processing images using 16 cores
# [########################################] | 100% Completed | 209.90 ms
# 20 (4000, 6000) <class 'dask.array.core.Array'>
# ☁ paidiverpy ☁  |       INFO | 2024-09-20 17:56:24 | Step 1 completed
# ...

# %%
# See the images output
plt.imshow(pipeline.images.images[0][10])

# %%
import numpy as np
bool_list = np.array([True, False, True, False, True])
number_list = np.array([10, 20, 30, 40, 50])

# Subset using boolean indexing
subset = number_list[bool_list]

print(subset)
# Out:
# [10 30 50]

# %%
subse
# Out:
# [np.int64(10), np.int64(30), np.int64(50)]
